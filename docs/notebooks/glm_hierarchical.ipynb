# %% [markdown]
# #The best of both worlds: Hierarchical Linear Regression in PyMC3

# %% [markdown]
# Today's blog post is co-written by my student [Danne Elbers](http://www.linkedin.com/pub/danne-elbers/69/3a2/7ba) who is doing her masters thesis with me on computational psychiatry using Bayesian methods. This post also borrows heavily from a [Notebook](http://nbviewer.ipython.org/github/fonnesbeck/multilevel_modeling/blob/master/multilevel_modeling.ipynb?create=1) by [Chris Fonnesbeck](http://biostat.mc.vanderbilt.edu/wiki/Main/ChrisFonnesbeck).
#
# The power of Bayesian modelling really clicked for me when I was first introduced to hierarchical modelling. In this blog post we will highlight the advantage of using hierarchical Bayesian modelling as opposed to non-hierarchical Bayesian modelling. This hierachical modelling is especially advantageous when multi-level data is used, making the most of all information available by its 'shrinkage-effect', which will be explained below.
#
# Having multiple sets of measurements comes up all the time, in Psychology for example you test multiple subjects on the same task. You then might want to estimate a model that describes the behavior as a set of parameters relating to mental functioning. Often we are interested in individual differences of these parameters but also assume that subjects share similarities (being human and all). Software from our lab, [HDDM](http://ski.cog.brown.edu/hddm_docs/), allows hierarchical Bayesian estimation of a widely used decision making model but we will use a more classical example of hierarchical linear regression here to predict radon levels in houses.
#
# This is the 3rd blog post on the topic of Bayesian modeling in PyMC3, see here for the previous two:
#
#   * [The Inference Button: Bayesian GLMs made easy with PyMC3](http://twiecki.github.io/blog/2013/08/12/bayesian-glms-1/)
#   * [This world is far from Normal(ly distributed): Bayesian Robust Regression in PyMC3](http://twiecki.github.io/blog/2013/08/27/bayesian-glms-2/)
#
# ## The data set
# Gelman et al.'s (2007) radon dataset is a classic for hierarchical modeling. In this dataset the amount of the radioactive gas radon has been measured among different households in all county's of several states. Radon gas is known to be the highest cause of lung cancer in non-smokers. It is believed to be more strongly present in households containing a basement and to differ in amount present among types of soil.
# Here we'll investigate this differences and try to make predictions of radonlevels in different county's based on the county itself and the presence of a basement. In this example we'll look at Minnesota, a state that contains 85 county's in which different measurements are taken, ranging from 2 till 80 measurements per county.
#
# ![radon](http://www.fix-your-radon.com/images/how_radon_enters.jpg)

# %% [markdown]
# First, we'll load the data:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm 
import pandas as pd

data = pd.read_csv('radon.csv')

county_names = data.county.unique()
county_idx = data['county_code'].values

# %% [markdown]
# The relevant part of the data we will model looks as follows:

# %%
data[['county', 'log_radon', 'floor']].head()
# Out:
#    county  log_radon  floor
# 0  AITKIN   0.832909      1
# 1  AITKIN   0.832909      0
# 2  AITKIN   1.098612      0
# 3  AITKIN   0.095310      0
# 4   ANOKA   1.163151      0
#
# [5 rows x 3 columns]

# %% [markdown]
# As you can see, we have multiple `radon` measurements (log-converted to be on the real line) in a `county` and whether the house has a basement (`floor` == 0) or not (`floor` == 1). We are interested in whether having a basement increases the `radon` measured in the house.

# %% [markdown]
# #The Models
#
# ## Pooling of measurements
# Now you might say: "That's easy! I'll just pool all my data and estimate one big regression to asses the influence of a basement across all counties". In math-speak that model would be:
#
# $$radon_{i, c} = \alpha + \beta*\text{floor}_{i, c} + \epsilon$$
#
# Where $i$ represents the measurement, $c$ the county and floor contains a yes (1) or no (0) to the question if the household has a basement. If you need a refresher on Linear Regressions in `PyMC`, check out my [previous blog post](http://twiecki.github.io/blog/2013/08/12/bayesian-glms-1/). Critically, we are only estimating *one* intercept and *one* slope for all measurements over all counties.
#
# ## Separate regressions
# But what if we are interested whether different counties actually have different relationships (slope) and different base-rates of radon (intercept)? Then you might say "OK then, I'll just estimate $n$ (number of counties) different regresseions -- one for each county". In math-speak that model would be:
#
# $$radon_{i, c} = \alpha_{c} + \beta_{c}*\text{floor}_{i, c} + \epsilon_c$$
#
# Note that we added the subindex $c$ so we are estimating $n$ different $\alpha$s and $\beta$s -- one for each county.
#
# This is the extreme opposite model, where above we assumed all counties are exactly the same, here we are saying that they share no similarities whatsoever which ultimately is also unsatisifying.
#
# ## Hierarchical Regression: The best of both worlds
#
# Fortunately there is a middle ground to both of these extreme views. Specifically, we may assume that while $\alpha$s and $\beta$s are different for each county, the coefficients all come from a common group distribution:
#
# $$\alpha_{c} \sim \mathcal{N}(\mu_{\alpha}, \sigma_{\alpha}^2)$$
# $$\beta_{c} \sim \mathcal{N}(\mu_{\beta}, \sigma_{\beta}^2)$$
#
# We thus assume the intercepts $\alpha$ and slopes $\beta$ to come from a normal distribution centered around their respective group mean $\mu$ with a certain standard deviation $\sigma^2$, the values (or rather posteriors) of which we also estimate. That's why this is called multilevel or hierarchical modeling.
#
# How do we estimate such a complex model with all these parameters you might ask? Well, that's the beauty of Probabilistic Programming -- we just formulate the model we want and press our [Inference Button(TM)](http://twiecki.github.io/blog/2013/08/12/bayesian-glms-1/).
#
# Note that the above is not a complete Bayesian model specification as we haven't defined priors or hyperpriors (i.e. priors for the group distribution, $\mu$ and $\sigma$). These will be used in the model implementation below but only distract here.

# %% [markdown]
# # Probabilistic Programming
#
# ## Individual/non-hierarchical model
#
# To really highlight the effect of the hierarchical linear regression we'll first estimate the non-hierarchical Bayesian model from above (separate regressions). For each county a new estimate of the parameters is initiated. As we have no prior information on what the intercept or regressions could be we are placing a Normal distribution centered around 0 with a wide standard-deviation. We'll assume the measurements are normally distributed with noise $\epsilon$ on which we place a Uniform distribution.

# %%
# takes about 45 minutes
indiv_traces = {}
for county_name in county_names:
    # Select subset of data belonging to county
    c_data = data.ix[data.county == county_name]
    c_data = c_data.reset_index(drop=True)
    
    c_log_radon = c_data.log_radon
    c_floor_measure = c_data.floor.values
    
    with pm.Model() as individual_model:
        # Intercept prior
        a = pm.Normal('alpha', mu=0, sd=100**2)
        # Slope prior
        b = pm.Normal('beta', mu=0, sd=100**2)
    
        # Model error prior
        eps = pm.Uniform('eps', lower=0, upper=100)
    
        # Linear model
        radon_est = a + b * c_floor_measure
    
        # Data likelihood
        y_like = pm.Normal('y_like', mu=radon_est, sd=eps, observed=c_log_radon)

        # Inference button (TM)!
        step = pm.NUTS()
        trace = pm.sample(2000, step=step)
        
    indiv_traces[county_name] = trace
# Out:
#  [                  2%                  ] 44 of 2000 complete in 0.5 sec
#  [-                 4%                  ] 97 of 2000 complete in 1.0 sec
#  [--                7%                  ] 145 of 2000 complete in 1.5 sec
#  [---               9%                  ] 192 of 2000 complete in 2.0 sec
#  [----             12%                  ] 243 of 2000 complete in 2.5 sec
#  [-----            14%                  ] 298 of 2000 complete in 3.0 sec
#  [------           17%                  ] 349 of 2000 complete in 3.5 sec
#  [-------          19%                  ] 397 of 2000 complete in 4.0 sec
#  [--------         22%                  ] 449 of 2000 complete in 4.5 sec
#  [---------        25%                  ] 512 of 2000 complete in 5.0 sec
#  [----------       27%                  ] 558 of 2000 complete in 5.6 sec
#  [-----------      30%                  ] 606 of 2000 complete in 6.1 sec
#  [------------     33%                  ] 670 of 2000 complete in 6.6 sec
#  [-------------    36%                  ] 722 of 2000 complete in 7.1 sec
#  [--------------   38%                  ] 761 of 2000 complete in 7.6 sec
#  [---------------  40%                  ] 806 of 2000 complete in 8.1 sec
#  [---------------- 43%                  ] 876 of 2000 complete in 8.6 sec
#  [-----------------47%                  ] 955 of 2000 complete in 9.1 sec
#  [-----------------50%                  ] 1015 of 2000 complete in 9.6 sec
#  [-----------------53%                  ] 1062 of 2000 complete in 10.1 sec
#  [-----------------56%-                 ] 1126 of 2000 complete in 10.6 sec
#  [-----------------58%--                ] 1176 of 2000 complete in 11.2 sec
#  [-----------------61%---               ] 1231 of 2000 complete in 11.7 sec
#  [-----------------63%----              ] 1276 of 2000 complete in 12.2 sec
#  [-----------------66%-----             ] 1334 of 2000 complete in 12.7 sec
#  [-----------------69%------            ] 1399 of 2000 complete in 13.2 sec
#  [-----------------73%-------           ] 1462 of 2000 complete in 13.7 sec
#  [-----------------75%--------          ] 1518 of 2000 complete in 14.2 sec
#  [-----------------78%---------         ] 1574 of 2000 complete in 14.7 sec
#  [-----------------82%-----------       ] 1643 of 2000 complete in 15.3 sec
#  [-----------------84%------------      ] 1686 of 2000 complete in 15.8 sec
#  [-----------------86%-------------     ] 1738 of 2000 complete in 16.3 sec
#  [-----------------90%--------------    ] 1818 of 2000 complete in 16.8 sec
#  [-----------------91%--------------    ] 1835 of 2000 complete in 17.3 sec
#  [-----------------93%---------------   ] 1879 of 2000 complete in 17.8 sec
#  [-----------------96%----------------  ] 1927 of 2000 complete in 18.3 sec
#  [-----------------97%----------------- ] 1950 of 2000 complete in 18.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 19.2 sec
#  [                  2%                  ] 44 of 2000 complete in 0.5 sec
#  [--                6%                  ] 125 of 2000 complete in 1.0 sec
#  [---              10%                  ] 207 of 2000 complete in 1.5 sec
#  [-----            15%                  ] 315 of 2000 complete in 2.0 sec
#  [-------          20%                  ] 408 of 2000 complete in 2.5 sec
#  [---------        25%                  ] 518 of 2000 complete in 3.0 sec
#  [------------     32%                  ] 644 of 2000 complete in 3.5 sec
#  [--------------   38%                  ] 767 of 2000 complete in 4.0 sec
#  [---------------- 43%                  ] 878 of 2000 complete in 4.5 sec
#  [-----------------49%                  ] 984 of 2000 complete in 5.0 sec
#  [-----------------55%                  ] 1105 of 2000 complete in 5.5 sec
#  [-----------------61%---               ] 1229 of 2000 complete in 6.0 sec
#  [-----------------66%-----             ] 1338 of 2000 complete in 6.5 sec
#  [-----------------72%-------           ] 1458 of 2000 complete in 7.0 sec
#  [-----------------78%---------         ] 1569 of 2000 complete in 7.5 sec
#  [-----------------84%------------      ] 1687 of 2000 complete in 8.0 sec
#  [-----------------90%--------------    ] 1812 of 2000 complete in 8.5 sec
#  [-----------------96%----------------  ] 1928 of 2000 complete in 9.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 9.4 sec
#  [                  1%                  ] 29 of 2000 complete in 0.5 sec
#  [-                 2%                  ] 57 of 2000 complete in 1.0 sec
#  [-                 4%                  ] 88 of 2000 complete in 1.5 sec
#  [--                6%                  ] 122 of 2000 complete in 2.0 sec
#  [---               7%                  ] 159 of 2000 complete in 2.7 sec
#  [---               9%                  ] 193 of 2000 complete in 3.2 sec
#  [----             11%                  ] 222 of 2000 complete in 3.7 sec
#  [----             13%                  ] 263 of 2000 complete in 4.2 sec
#  [-----            14%                  ] 295 of 2000 complete in 4.7 sec
#  [------           16%                  ] 320 of 2000 complete in 5.2 sec
#  [------           17%                  ] 347 of 2000 complete in 5.7 sec
#  [-------          19%                  ] 395 of 2000 complete in 6.2 sec
#  [--------         21%                  ] 424 of 2000 complete in 6.8 sec
#  [--------         22%                  ] 441 of 2000 complete in 7.3 sec
#  [---------        23%                  ] 475 of 2000 complete in 7.8 sec
#  [---------        24%                  ] 493 of 2000 complete in 8.7 sec
#  [---------        24%                  ] 495 of 2000 complete in 9.3 sec
#  [---------        25%                  ] 503 of 2000 complete in 9.8 sec
#  [---------        26%                  ] 526 of 2000 complete in 10.3 sec
#  [----------       28%                  ] 575 of 2000 complete in 10.8 sec
#  [-----------      30%                  ] 617 of 2000 complete in 11.3 sec
#  [-----------      31%                  ] 626 of 2000 complete in 11.9 sec
#  [------------     32%                  ] 651 of 2000 complete in 12.4 sec
#  [------------     34%                  ] 682 of 2000 complete in 12.9 sec
#  [-------------    36%                  ] 721 of 2000 complete in 13.4 sec
#  [--------------   38%                  ] 763 of 2000 complete in 13.9 sec
#  [---------------  41%                  ] 821 of 2000 complete in 14.4 sec
#  [---------------- 43%                  ] 862 of 2000 complete in 14.9 sec
#  [-----------------45%                  ] 919 of 2000 complete in 15.4 sec
#  [-----------------48%                  ] 961 of 2000 complete in 15.9 sec
#  [-----------------50%                  ] 1005 of 2000 complete in 16.4 sec
#  [-----------------51%                  ] 1029 of 2000 complete in 16.9 sec
#  [-----------------53%                  ] 1078 of 2000 complete in 17.5 sec
#  [-----------------55%-                 ] 1119 of 2000 complete in 18.0 sec
#  [-----------------57%-                 ] 1152 of 2000 complete in 18.5 sec
#  [-----------------60%--                ] 1206 of 2000 complete in 19.0 sec
#  [-----------------62%---               ] 1254 of 2000 complete in 19.5 sec
#  [-----------------65%----              ] 1304 of 2000 complete in 20.0 sec
#  [-----------------67%-----             ] 1353 of 2000 complete in 20.5 sec
#  [-----------------70%------            ] 1409 of 2000 complete in 21.0 sec
#  [-----------------72%-------           ] 1440 of 2000 complete in 21.5 sec
#  [-----------------74%--------          ] 1482 of 2000 complete in 22.0 sec
#  [-----------------75%--------          ] 1500 of 2000 complete in 22.6 sec
#  [-----------------77%---------         ] 1543 of 2000 complete in 23.1 sec
#  [-----------------78%---------         ] 1577 of 2000 complete in 23.6 sec
#  [-----------------81%-----------       ] 1632 of 2000 complete in 24.1 sec
#  [-----------------83%-----------       ] 1661 of 2000 complete in 24.6 sec
#  [-----------------84%------------      ] 1694 of 2000 complete in 25.2 sec
#  [-----------------86%------------      ] 1734 of 2000 complete in 25.7 sec
#  [-----------------88%-------------     ] 1762 of 2000 complete in 26.2 sec
#  [-----------------90%--------------    ] 1805 of 2000 complete in 26.7 sec
#  [-----------------92%---------------   ] 1856 of 2000 complete in 27.2 sec
#  [-----------------94%---------------   ] 1881 of 2000 complete in 27.7 sec
#  [-----------------95%----------------  ] 1907 of 2000 complete in 28.2 sec
#  [-----------------97%----------------- ] 1955 of 2000 complete in 28.7 sec
#  [-----------------99%----------------- ] 1982 of 2000 complete in 29.2 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 29.5 sec
#  [                  2%                  ] 40 of 2000 complete in 0.5 sec
#  [-                 4%                  ] 91 of 2000 complete in 1.0 sec
#  [--                7%                  ] 150 of 2000 complete in 1.5 sec
#  [---              10%                  ] 203 of 2000 complete in 2.0 sec
#  [-----            13%                  ] 276 of 2000 complete in 2.5 sec
#  [------           16%                  ] 333 of 2000 complete in 3.0 sec
#  [-------          19%                  ] 390 of 2000 complete in 3.5 sec
#  [--------         21%                  ] 430 of 2000 complete in 4.0 sec
#  [---------        25%                  ] 502 of 2000 complete in 4.6 sec
#  [----------       28%                  ] 577 of 2000 complete in 5.1 sec
#  [------------     31%                  ] 634 of 2000 complete in 5.6 sec
#  [-------------    34%                  ] 698 of 2000 complete in 6.1 sec
#  [--------------   38%                  ] 772 of 2000 complete in 6.6 sec
#  [---------------  41%                  ] 822 of 2000 complete in 7.1 sec
#  [---------------- 44%                  ] 892 of 2000 complete in 7.6 sec
#  [-----------------47%                  ] 948 of 2000 complete in 8.1 sec
#  [-----------------50%                  ] 1008 of 2000 complete in 8.6 sec
#  [-----------------53%                  ] 1075 of 2000 complete in 9.1 sec
#  [-----------------56%-                 ] 1136 of 2000 complete in 9.7 sec
#  [-----------------60%--                ] 1204 of 2000 complete in 10.2 sec
#  [-----------------63%---               ] 1263 of 2000 complete in 10.7 sec
#  [-----------------66%-----             ] 1331 of 2000 complete in 11.2 sec
#  [-----------------70%------            ] 1403 of 2000 complete in 11.7 sec
#  [-----------------73%-------           ] 1472 of 2000 complete in 12.3 sec
#  [-----------------77%---------         ] 1547 of 2000 complete in 12.8 sec
#  [-----------------80%----------        ] 1615 of 2000 complete in 13.3 sec
#  [-----------------84%-----------       ] 1681 of 2000 complete in 13.8 sec
#  [-----------------87%-------------     ] 1744 of 2000 complete in 14.3 sec
#  [-----------------90%--------------    ] 1813 of 2000 complete in 14.8 sec
#  [-----------------94%---------------   ] 1885 of 2000 complete in 15.3 sec
#  [-----------------98%----------------- ] 1960 of 2000 complete in 15.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 16.2 sec
#  [                  2%                  ] 47 of 2000 complete in 0.5 sec
#  [--                5%                  ] 111 of 2000 complete in 1.0 sec
#  [---               8%                  ] 171 of 2000 complete in 1.5 sec
#  [----             11%                  ] 234 of 2000 complete in 2.0 sec
#  [-----            14%                  ] 295 of 2000 complete in 2.5 sec
#  [-----            15%                  ] 310 of 2000 complete in 3.0 sec
#  [------           17%                  ] 359 of 2000 complete in 3.5 sec
#  [--------         21%                  ] 428 of 2000 complete in 4.0 sec
#  [---------        24%                  ] 490 of 2000 complete in 4.5 sec
#  [----------       27%                  ] 553 of 2000 complete in 5.0 sec
#  [-----------      30%                  ] 600 of 2000 complete in 5.5 sec
#  [------------     33%                  ] 673 of 2000 complete in 6.0 sec
#  [-------------    36%                  ] 728 of 2000 complete in 6.5 sec
#  [---------------  39%                  ] 799 of 2000 complete in 7.0 sec
#  [---------------- 42%                  ] 857 of 2000 complete in 7.5 sec
#  [-----------------46%                  ] 930 of 2000 complete in 8.1 sec
#  [-----------------49%                  ] 986 of 2000 complete in 8.6 sec
#  [-----------------52%                  ] 1045 of 2000 complete in 9.2 sec
#  [-----------------54%                  ] 1098 of 2000 complete in 9.7 sec
#  [-----------------57%-                 ] 1155 of 2000 complete in 10.2 sec
#  [-----------------59%--                ] 1183 of 2000 complete in 10.7 sec
#  [-----------------62%---               ] 1247 of 2000 complete in 11.2 sec
#  [-----------------65%----              ] 1300 of 2000 complete in 11.7 sec
#  [-----------------68%-----             ] 1368 of 2000 complete in 12.2 sec
#  [-----------------70%------            ] 1417 of 2000 complete in 12.8 sec
#  [-----------------73%--------          ] 1476 of 2000 complete in 13.3 sec
#  [-----------------77%---------         ] 1545 of 2000 complete in 13.8 sec
#  [-----------------80%----------        ] 1605 of 2000 complete in 14.3 sec
#  [-----------------82%-----------       ] 1657 of 2000 complete in 14.8 sec
#  [-----------------85%------------      ] 1711 of 2000 complete in 15.3 sec
#  [-----------------88%-------------     ] 1766 of 2000 complete in 15.8 sec
#  [-----------------91%--------------    ] 1832 of 2000 complete in 16.3 sec
#  [-----------------93%---------------   ] 1865 of 2000 complete in 16.9 sec
#  [-----------------95%----------------  ] 1906 of 2000 complete in 17.4 sec
#  [-----------------98%----------------- ] 1960 of 2000 complete in 17.9 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 18.1 sec
#  [                  0%                  ] 19 of 2000 complete in 0.6 sec
#  [                  2%                  ] 49 of 2000 complete in 1.1 sec
#  [-                 2%                  ] 56 of 2000 complete in 1.7 sec
#  [-                 3%                  ] 63 of 2000 complete in 2.5 sec
#  [-                 3%                  ] 70 of 2000 complete in 3.0 sec
#  [-                 4%                  ] 94 of 2000 complete in 3.6 sec
#  [--                5%                  ] 117 of 2000 complete in 4.3 sec
#  [--                6%                  ] 138 of 2000 complete in 4.8 sec
#  [---               8%                  ] 169 of 2000 complete in 5.3 sec
#  [---               8%                  ] 174 of 2000 complete in 5.8 sec
#  [---               8%                  ] 179 of 2000 complete in 6.7 sec
#  [---               9%                  ] 186 of 2000 complete in 7.2 sec
#  [---               9%                  ] 188 of 2000 complete in 7.9 sec
#  [---               9%                  ] 199 of 2000 complete in 8.5 sec
#  [---              10%                  ] 205 of 2000 complete in 9.7 sec
#  [----             10%                  ] 215 of 2000 complete in 10.2 sec
#  [----             11%                  ] 220 of 2000 complete in 11.1 sec
#  [----             11%                  ] 223 of 2000 complete in 11.8 sec
#  [----             11%                  ] 228 of 2000 complete in 12.3 sec
#  [----             11%                  ] 239 of 2000 complete in 13.0 sec
#  [----             12%                  ] 244 of 2000 complete in 13.6 sec
#  [----             12%                  ] 252 of 2000 complete in 14.1 sec
#  [----             12%                  ] 257 of 2000 complete in 14.6 sec
#  [-----            13%                  ] 267 of 2000 complete in 15.3 sec
#  [-----            14%                  ] 288 of 2000 complete in 15.9 sec
#  [-----            14%                  ] 292 of 2000 complete in 16.7 sec
#  [-----            14%                  ] 298 of 2000 complete in 17.3 sec
#  [-----            15%                  ] 305 of 2000 complete in 18.1 sec
#  [------           16%                  ] 320 of 2000 complete in 18.7 sec
#  [------           17%                  ] 348 of 2000 complete in 19.2 sec
#  [-------          19%                  ] 383 of 2000 complete in 19.8 sec
#  [-------          19%                  ] 399 of 2000 complete in 20.3 sec
#  [-------          20%                  ] 417 of 2000 complete in 20.8 sec
#  [--------         21%                  ] 428 of 2000 complete in 21.4 sec
#  [--------         23%                  ] 463 of 2000 complete in 22.2 sec
#  [---------        23%                  ] 479 of 2000 complete in 22.7 sec
#  [---------        24%                  ] 480 of 2000 complete in 23.3 sec
#  [---------        24%                  ] 482 of 2000 complete in 23.9 sec
#  [---------        24%                  ] 488 of 2000 complete in 24.4 sec
#  [---------        25%                  ] 518 of 2000 complete in 24.9 sec
#  [----------       27%                  ] 541 of 2000 complete in 25.5 sec
#  [----------       27%                  ] 553 of 2000 complete in 26.2 sec
#  [----------       28%                  ] 573 of 2000 complete in 26.7 sec
#  [-----------      29%                  ] 593 of 2000 complete in 27.4 sec
#  [-----------      30%                  ] 617 of 2000 complete in 27.9 sec
#  [------------     32%                  ] 641 of 2000 complete in 28.4 sec
#  [------------     33%                  ] 670 of 2000 complete in 28.9 sec
#  [-------------    34%                  ] 686 of 2000 complete in 29.4 sec
#  [-------------    36%                  ] 720 of 2000 complete in 30.2 sec
#  [-------------    36%                  ] 736 of 2000 complete in 30.9 sec
#  [--------------   37%                  ] 753 of 2000 complete in 31.4 sec
#  [---------------  39%                  ] 792 of 2000 complete in 32.4 sec
#  [---------------  40%                  ] 808 of 2000 complete in 32.9 sec
#  [---------------  41%                  ] 832 of 2000 complete in 33.4 sec
#  [---------------- 42%                  ] 855 of 2000 complete in 34.1 sec
#  [---------------- 42%                  ] 859 of 2000 complete in 34.9 sec
#  [---------------- 43%                  ] 860 of 2000 complete in 35.7 sec
#  [---------------- 43%                  ] 872 of 2000 complete in 36.2 sec
#  [---------------- 44%                  ] 882 of 2000 complete in 36.8 sec
#  [---------------- 44%                  ] 888 of 2000 complete in 37.5 sec
#  [-----------------44%                  ] 897 of 2000 complete in 38.1 sec
#  [-----------------45%                  ] 912 of 2000 complete in 38.7 sec
#  [-----------------45%                  ] 916 of 2000 complete in 39.2 sec
#  [-----------------46%                  ] 933 of 2000 complete in 39.7 sec
#  [-----------------47%                  ] 943 of 2000 complete in 40.3 sec
#  [-----------------48%                  ] 966 of 2000 complete in 40.9 sec
#  [-----------------48%                  ] 973 of 2000 complete in 41.5 sec
#  [-----------------48%                  ] 977 of 2000 complete in 42.2 sec
#  [-----------------49%                  ] 997 of 2000 complete in 42.7 sec
#  [-----------------50%                  ] 1011 of 2000 complete in 43.5 sec
#  [-----------------51%                  ] 1026 of 2000 complete in 44.6 sec
#  [-----------------51%                  ] 1027 of 2000 complete in 45.2 sec
#  [-----------------52%                  ] 1040 of 2000 complete in 45.8 sec
#  [-----------------52%                  ] 1044 of 2000 complete in 46.9 sec
#  [-----------------52%                  ] 1048 of 2000 complete in 47.4 sec
#  [-----------------53%                  ] 1061 of 2000 complete in 47.9 sec
#  [-----------------53%                  ] 1077 of 2000 complete in 48.7 sec
#  [-----------------55%-                 ] 1111 of 2000 complete in 49.2 sec
#  [-----------------57%-                 ] 1144 of 2000 complete in 49.8 sec
#  [-----------------57%-                 ] 1155 of 2000 complete in 50.4 sec
#  [-----------------58%--                ] 1172 of 2000 complete in 50.9 sec
#  [-----------------58%--                ] 1177 of 2000 complete in 51.4 sec
#  [-----------------59%--                ] 1195 of 2000 complete in 51.9 sec
#  [-----------------59%--                ] 1199 of 2000 complete in 52.5 sec
#  [-----------------60%---               ] 1215 of 2000 complete in 53.2 sec
#  [-----------------60%---               ] 1217 of 2000 complete in 53.9 sec
#  [-----------------61%---               ] 1238 of 2000 complete in 54.4 sec
#  [-----------------62%---               ] 1258 of 2000 complete in 54.9 sec
#  [-----------------63%----              ] 1265 of 2000 complete in 55.6 sec
#  [-----------------63%----              ] 1269 of 2000 complete in 56.1 sec
#  [-----------------63%----              ] 1277 of 2000 complete in 56.6 sec
#  [-----------------64%----              ] 1291 of 2000 complete in 57.1 sec
#  [-----------------65%----              ] 1308 of 2000 complete in 57.7 sec
#  [-----------------65%----              ] 1313 of 2000 complete in 58.2 sec
#  [-----------------65%-----             ] 1317 of 2000 complete in 58.9 sec
#  [-----------------66%-----             ] 1331 of 2000 complete in 59.4 sec
#  [-----------------68%-----             ] 1368 of 2000 complete in 59.9 sec
#  [-----------------70%------            ] 1409 of 2000 complete in 60.4 sec
#  [-----------------71%-------           ] 1427 of 2000 complete in 60.9 sec
#  [-----------------72%-------           ] 1445 of 2000 complete in 61.5 sec
#  [-----------------73%-------           ] 1461 of 2000 complete in 62.1 sec
#  [-----------------73%--------          ] 1479 of 2000 complete in 62.8 sec
#  [-----------------74%--------          ] 1489 of 2000 complete in 63.3 sec
#  [-----------------74%--------          ] 1494 of 2000 complete in 64.0 sec
#  [-----------------74%--------          ] 1499 of 2000 complete in 64.8 sec
#  [-----------------75%--------          ] 1513 of 2000 complete in 65.3 sec
#  [-----------------76%---------         ] 1528 of 2000 complete in 65.9 sec
#  [-----------------77%---------         ] 1543 of 2000 complete in 66.4 sec
#  [-----------------78%---------         ] 1562 of 2000 complete in 67.0 sec
#  [-----------------78%---------         ] 1572 of 2000 complete in 67.5 sec
#  [-----------------79%----------        ] 1582 of 2000 complete in 68.1 sec
#  [-----------------79%----------        ] 1598 of 2000 complete in 68.8 sec
#  [-----------------80%----------        ] 1608 of 2000 complete in 69.5 sec
#  [-----------------81%----------        ] 1631 of 2000 complete in 70.0 sec
#  [-----------------82%-----------       ] 1643 of 2000 complete in 71.1 sec
#  [-----------------82%-----------       ] 1652 of 2000 complete in 72.0 sec
#  [-----------------83%-----------       ] 1669 of 2000 complete in 72.6 sec
#  [-----------------84%-----------       ] 1681 of 2000 complete in 73.1 sec
#  [-----------------84%------------      ] 1695 of 2000 complete in 73.7 sec
#  [-----------------86%------------      ] 1733 of 2000 complete in 74.2 sec
#  [-----------------87%-------------     ] 1742 of 2000 complete in 74.8 sec
#  [-----------------88%-------------     ] 1773 of 2000 complete in 75.3 sec
#  [-----------------89%--------------    ] 1796 of 2000 complete in 75.9 sec
#  [-----------------91%--------------    ] 1825 of 2000 complete in 76.4 sec
#  [-----------------91%--------------    ] 1833 of 2000 complete in 76.9 sec
#  [-----------------93%---------------   ] 1872 of 2000 complete in 77.4 sec
#  [-----------------95%----------------  ] 1908 of 2000 complete in 78.1 sec
#  [-----------------95%----------------  ] 1917 of 2000 complete in 78.6 sec
#  [-----------------96%----------------  ] 1928 of 2000 complete in 79.2 sec
#  [-----------------97%----------------- ] 1948 of 2000 complete in 79.7 sec
#  [-----------------98%----------------- ] 1964 of 2000 complete in 80.3 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 80.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 80.8 sec
#  [-                 3%                  ] 69 of 2000 complete in 0.5 sec
#  [--                7%                  ] 154 of 2000 complete in 1.0 sec
#  [----             12%                  ] 241 of 2000 complete in 1.5 sec
#  [------           16%                  ] 338 of 2000 complete in 2.0 sec
#  [--------         21%                  ] 432 of 2000 complete in 2.5 sec
#  [---------        25%                  ] 511 of 2000 complete in 3.0 sec
#  [-----------      29%                  ] 590 of 2000 complete in 3.5 sec
#  [------------     34%                  ] 683 of 2000 complete in 4.0 sec
#  [--------------   38%                  ] 776 of 2000 complete in 4.5 sec
#  [---------------- 43%                  ] 877 of 2000 complete in 5.0 sec
#  [-----------------48%                  ] 960 of 2000 complete in 5.5 sec
#  [-----------------53%                  ] 1061 of 2000 complete in 6.0 sec
#  [-----------------58%--                ] 1169 of 2000 complete in 6.5 sec
#  [-----------------63%----              ] 1266 of 2000 complete in 7.0 sec
#  [-----------------68%-----             ] 1364 of 2000 complete in 7.5 sec
#  [-----------------72%-------           ] 1455 of 2000 complete in 8.0 sec
#  [-----------------77%---------         ] 1540 of 2000 complete in 8.5 sec
#  [-----------------82%-----------       ] 1641 of 2000 complete in 9.0 sec
#  [-----------------87%-------------     ] 1742 of 2000 complete in 9.6 sec
#  [-----------------92%--------------    ] 1840 of 2000 complete in 10.1 sec
#  [-----------------96%----------------  ] 1934 of 2000 complete in 10.6 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 10.9 sec
#  [                  1%                  ] 36 of 2000 complete in 0.5 sec
#  [-                 4%                  ] 86 of 2000 complete in 1.1 sec
#  [--                7%                  ] 140 of 2000 complete in 1.6 sec
#  [---               9%                  ] 189 of 2000 complete in 2.1 sec
#  [----             12%                  ] 244 of 2000 complete in 2.6 sec
#  [-----            14%                  ] 297 of 2000 complete in 3.1 sec
#  [------           17%                  ] 345 of 2000 complete in 3.7 sec
#  [-------          20%                  ] 400 of 2000 complete in 4.2 sec
#  [--------         22%                  ] 455 of 2000 complete in 4.7 sec
#  [---------        24%                  ] 486 of 2000 complete in 5.2 sec
#  [----------       26%                  ] 538 of 2000 complete in 5.7 sec
#  [-----------      29%                  ] 595 of 2000 complete in 6.2 sec
#  [------------     32%                  ] 646 of 2000 complete in 6.7 sec
#  [-------------    34%                  ] 694 of 2000 complete in 7.2 sec
#  [--------------   38%                  ] 768 of 2000 complete in 7.7 sec
#  [---------------  40%                  ] 817 of 2000 complete in 8.2 sec
#  [---------------- 43%                  ] 874 of 2000 complete in 8.7 sec
#  [-----------------45%                  ] 914 of 2000 complete in 9.3 sec
#  [-----------------48%                  ] 961 of 2000 complete in 9.8 sec
#  [-----------------51%                  ] 1024 of 2000 complete in 10.3 sec
#  [-----------------53%                  ] 1074 of 2000 complete in 10.8 sec
#  [-----------------55%-                 ] 1111 of 2000 complete in 11.4 sec
#  [-----------------58%--                ] 1171 of 2000 complete in 11.9 sec
#  [-----------------61%---               ] 1225 of 2000 complete in 12.4 sec
#  [-----------------64%----              ] 1297 of 2000 complete in 12.9 sec
#  [-----------------66%-----             ] 1339 of 2000 complete in 13.4 sec
#  [-----------------69%------            ] 1397 of 2000 complete in 13.9 sec
#  [-----------------72%-------           ] 1444 of 2000 complete in 14.4 sec
#  [-----------------74%--------          ] 1489 of 2000 complete in 14.9 sec
#  [-----------------77%---------         ] 1540 of 2000 complete in 15.4 sec
#  [-----------------77%---------         ] 1550 of 2000 complete in 16.0 sec
#  [-----------------79%----------        ] 1580 of 2000 complete in 16.5 sec
#  [-----------------82%-----------       ] 1650 of 2000 complete in 17.0 sec
#  [-----------------84%------------      ] 1685 of 2000 complete in 17.5 sec
#  [-----------------87%-------------     ] 1751 of 2000 complete in 18.0 sec
#  [-----------------88%-------------     ] 1765 of 2000 complete in 18.8 sec
#  [-----------------91%--------------    ] 1822 of 2000 complete in 19.3 sec
#  [-----------------93%---------------   ] 1877 of 2000 complete in 19.8 sec
#  [-----------------97%----------------  ] 1941 of 2000 complete in 20.3 sec
#  [-----------------99%----------------- ] 1980 of 2000 complete in 20.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 21.0 sec
#  [                  2%                  ] 44 of 2000 complete in 0.5 sec
#  [--                5%                  ] 117 of 2000 complete in 1.0 sec
#  [---               9%                  ] 187 of 2000 complete in 1.5 sec
#  [-----            13%                  ] 279 of 2000 complete in 2.0 sec
#  [------           18%                  ] 361 of 2000 complete in 2.5 sec
#  [--------         22%                  ] 446 of 2000 complete in 3.0 sec
#  [----------       26%                  ] 536 of 2000 complete in 3.5 sec
#  [-----------      30%                  ] 616 of 2000 complete in 4.0 sec
#  [-------------    35%                  ] 710 of 2000 complete in 4.5 sec
#  [---------------  39%                  ] 790 of 2000 complete in 5.0 sec
#  [---------------- 44%                  ] 888 of 2000 complete in 5.5 sec
#  [-----------------48%                  ] 970 of 2000 complete in 6.0 sec
#  [-----------------52%                  ] 1053 of 2000 complete in 6.5 sec
#  [-----------------57%-                 ] 1156 of 2000 complete in 7.0 sec
#  [-----------------61%---               ] 1239 of 2000 complete in 7.6 sec
#  [-----------------66%-----             ] 1324 of 2000 complete in 8.1 sec
#  [-----------------70%------            ] 1404 of 2000 complete in 8.6 sec
#  [-----------------74%--------          ] 1489 of 2000 complete in 9.1 sec
#  [-----------------78%---------         ] 1576 of 2000 complete in 9.6 sec
#  [-----------------82%-----------       ] 1644 of 2000 complete in 10.1 sec
#  [-----------------87%-------------     ] 1748 of 2000 complete in 10.6 sec
#  [-----------------91%--------------    ] 1838 of 2000 complete in 11.1 sec
#  [-----------------96%----------------  ] 1927 of 2000 complete in 11.6 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 12.0 sec
#  [                  2%                  ] 40 of 2000 complete in 0.5 sec
#  [-                 4%                  ] 93 of 2000 complete in 1.0 sec
#  [---               8%                  ] 166 of 2000 complete in 1.5 sec
#  [----             11%                  ] 235 of 2000 complete in 2.0 sec
#  [-----            14%                  ] 291 of 2000 complete in 2.5 sec
#  [------           17%                  ] 349 of 2000 complete in 3.0 sec
#  [-------          19%                  ] 395 of 2000 complete in 3.5 sec
#  [--------         21%                  ] 428 of 2000 complete in 4.1 sec
#  [---------        24%                  ] 488 of 2000 complete in 4.6 sec
#  [----------       27%                  ] 541 of 2000 complete in 5.1 sec
#  [-----------      29%                  ] 599 of 2000 complete in 5.6 sec
#  [------------     33%                  ] 662 of 2000 complete in 6.1 sec
#  [-------------    36%                  ] 721 of 2000 complete in 6.6 sec
#  [--------------   39%                  ] 786 of 2000 complete in 7.1 sec
#  [---------------- 42%                  ] 858 of 2000 complete in 7.6 sec
#  [-----------------45%                  ] 908 of 2000 complete in 8.1 sec
#  [-----------------49%                  ] 981 of 2000 complete in 8.6 sec
#  [-----------------52%                  ] 1044 of 2000 complete in 9.1 sec
#  [-----------------54%                  ] 1096 of 2000 complete in 9.6 sec
#  [-----------------58%--                ] 1160 of 2000 complete in 10.1 sec
#  [-----------------62%---               ] 1241 of 2000 complete in 10.6 sec
#  [-----------------65%----              ] 1306 of 2000 complete in 11.1 sec
#  [-----------------68%------            ] 1378 of 2000 complete in 11.6 sec
#  [-----------------72%-------           ] 1452 of 2000 complete in 12.2 sec
#  [-----------------75%--------          ] 1519 of 2000 complete in 12.7 sec
#  [-----------------79%----------        ] 1581 of 2000 complete in 13.2 sec
#  [-----------------82%-----------       ] 1641 of 2000 complete in 13.7 sec
#  [-----------------85%------------      ] 1706 of 2000 complete in 14.2 sec
#  [-----------------88%-------------     ] 1771 of 2000 complete in 14.7 sec
#  [-----------------91%--------------    ] 1828 of 2000 complete in 15.2 sec
#  [-----------------93%---------------   ] 1879 of 2000 complete in 15.7 sec
#  [-----------------97%----------------  ] 1943 of 2000 complete in 16.2 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 16.6 sec
#  [                  1%                  ] 29 of 2000 complete in 0.5 sec
#  [-                 2%                  ] 55 of 2000 complete in 1.1 sec
#  [-                 3%                  ] 65 of 2000 complete in 1.9 sec
#  [-                 3%                  ] 67 of 2000 complete in 2.7 sec
#  [-                 3%                  ] 68 of 2000 complete in 3.3 sec
#  [-                 3%                  ] 77 of 2000 complete in 4.3 sec
#  [-                 5%                  ] 103 of 2000 complete in 4.8 sec
#  [-                 5%                  ] 104 of 2000 complete in 5.4 sec
#  [--                6%                  ] 121 of 2000 complete in 6.2 sec
#  [--                6%                  ] 131 of 2000 complete in 6.9 sec
#  [--                6%                  ] 137 of 2000 complete in 7.4 sec
#  [--                7%                  ] 143 of 2000 complete in 9.7 sec
#  [--                7%                  ] 148 of 2000 complete in 10.4 sec
#  [--                7%                  ] 153 of 2000 complete in 10.9 sec
#  [---               8%                  ] 165 of 2000 complete in 11.8 sec
#  [---               8%                  ] 167 of 2000 complete in 12.3 sec
#  [---               8%                  ] 172 of 2000 complete in 13.4 sec
#  [---               9%                  ] 183 of 2000 complete in 13.9 sec
#  [---               9%                  ] 194 of 2000 complete in 14.8 sec
#  [---              10%                  ] 200 of 2000 complete in 15.3 sec
#  [---              10%                  ] 209 of 2000 complete in 15.9 sec
#  [----             10%                  ] 217 of 2000 complete in 16.5 sec
#  [----             12%                  ] 242 of 2000 complete in 17.1 sec
#  [----             12%                  ] 252 of 2000 complete in 17.6 sec
#  [-----            13%                  ] 273 of 2000 complete in 19.1 sec
#  [-----            14%                  ] 283 of 2000 complete in 20.0 sec
#  [-----            14%                  ] 294 of 2000 complete in 20.6 sec
#  [-----            15%                  ] 312 of 2000 complete in 21.2 sec
#  [------           15%                  ] 318 of 2000 complete in 21.8 sec
#  [------           15%                  ] 319 of 2000 complete in 22.5 sec
#  [------           16%                  ] 323 of 2000 complete in 23.1 sec
#  [------           16%                  ] 333 of 2000 complete in 23.7 sec
#  [------           16%                  ] 336 of 2000 complete in 24.3 sec
#  [------           17%                  ] 352 of 2000 complete in 24.8 sec
#  [------           18%                  ] 364 of 2000 complete in 25.4 sec
#  [------           18%                  ] 368 of 2000 complete in 25.9 sec
#  [-------          19%                  ] 392 of 2000 complete in 26.5 sec
#  [-------          20%                  ] 403 of 2000 complete in 27.0 sec
#  [-------          20%                  ] 414 of 2000 complete in 27.7 sec
#  [--------         21%                  ] 422 of 2000 complete in 28.4 sec
#  [--------         21%                  ] 425 of 2000 complete in 29.4 sec
#  [--------         21%                  ] 430 of 2000 complete in 30.5 sec
#  [--------         22%                  ] 441 of 2000 complete in 31.1 sec
#  [--------         23%                  ] 468 of 2000 complete in 31.6 sec
#  [---------        24%                  ] 482 of 2000 complete in 32.1 sec
#  [---------        24%                  ] 489 of 2000 complete in 32.7 sec
#  [---------        24%                  ] 493 of 2000 complete in 33.2 sec
#  [---------        25%                  ] 504 of 2000 complete in 33.8 sec
#  [----------       26%                  ] 537 of 2000 complete in 34.4 sec
#  [----------       27%                  ] 549 of 2000 complete in 34.9 sec
#  [----------       28%                  ] 562 of 2000 complete in 35.8 sec
#  [-----------      29%                  ] 599 of 2000 complete in 36.3 sec
#  [-----------      30%                  ] 604 of 2000 complete in 36.8 sec
#  [-----------      31%                  ] 624 of 2000 complete in 37.5 sec
#  [-----------      31%                  ] 631 of 2000 complete in 38.0 sec
#  [------------     31%                  ] 632 of 2000 complete in 38.6 sec
#  [------------     32%                  ] 646 of 2000 complete in 39.4 sec
#  [------------     33%                  ] 661 of 2000 complete in 39.9 sec
#  [------------     33%                  ] 670 of 2000 complete in 40.5 sec
#  [-------------    34%                  ] 694 of 2000 complete in 41.2 sec
#  [-------------    34%                  ] 699 of 2000 complete in 41.7 sec
#  [-------------    35%                  ] 711 of 2000 complete in 42.4 sec
#  [-------------    35%                  ] 714 of 2000 complete in 43.3 sec
#  [-------------    36%                  ] 729 of 2000 complete in 44.0 sec
#  [--------------   36%                  ] 739 of 2000 complete in 44.7 sec
#  [--------------   37%                  ] 754 of 2000 complete in 45.2 sec
#  [--------------   39%                  ] 788 of 2000 complete in 45.8 sec
#  [---------------  39%                  ] 795 of 2000 complete in 46.5 sec
#  [---------------  40%                  ] 804 of 2000 complete in 47.2 sec
#  [---------------  41%                  ] 827 of 2000 complete in 48.2 sec
#  [---------------  41%                  ] 834 of 2000 complete in 48.8 sec
#  [---------------  42%                  ] 842 of 2000 complete in 49.3 sec
#  [---------------- 42%                  ] 853 of 2000 complete in 50.3 sec
#  [---------------- 43%                  ] 866 of 2000 complete in 51.0 sec
#  [---------------- 44%                  ] 890 of 2000 complete in 51.6 sec
#  [-----------------45%                  ] 910 of 2000 complete in 52.2 sec
#  [-----------------46%                  ] 929 of 2000 complete in 52.8 sec
#  [-----------------47%                  ] 945 of 2000 complete in 53.4 sec
#  [-----------------47%                  ] 954 of 2000 complete in 54.0 sec
#  [-----------------48%                  ] 961 of 2000 complete in 54.5 sec
#  [-----------------48%                  ] 974 of 2000 complete in 55.1 sec
#  [-----------------49%                  ] 993 of 2000 complete in 55.6 sec
#  [-----------------51%                  ] 1032 of 2000 complete in 56.1 sec
#  [-----------------52%                  ] 1041 of 2000 complete in 56.6 sec
#  [-----------------52%                  ] 1046 of 2000 complete in 57.3 sec
#  [-----------------52%                  ] 1056 of 2000 complete in 57.9 sec
#  [-----------------53%                  ] 1064 of 2000 complete in 58.4 sec
#  [-----------------54%                  ] 1080 of 2000 complete in 58.9 sec
#  [-----------------54%                  ] 1083 of 2000 complete in 59.6 sec
#  [-----------------54%                  ] 1084 of 2000 complete in 60.2 sec
#  [-----------------54%                  ] 1099 of 2000 complete in 60.7 sec
#  [-----------------55%-                 ] 1119 of 2000 complete in 61.2 sec
#  [-----------------56%-                 ] 1134 of 2000 complete in 62.0 sec
#  [-----------------57%-                 ] 1146 of 2000 complete in 62.5 sec
#  [-----------------58%--                ] 1176 of 2000 complete in 63.0 sec
#  [-----------------59%--                ] 1185 of 2000 complete in 63.7 sec
#  [-----------------59%--                ] 1189 of 2000 complete in 64.2 sec
#  [-----------------59%--                ] 1195 of 2000 complete in 64.9 sec
#  [-----------------60%--                ] 1209 of 2000 complete in 65.4 sec
#  [-----------------61%---               ] 1222 of 2000 complete in 65.9 sec
#  [-----------------61%---               ] 1225 of 2000 complete in 66.4 sec
#  [-----------------61%---               ] 1236 of 2000 complete in 67.3 sec
#  [-----------------62%---               ] 1250 of 2000 complete in 67.9 sec
#  [-----------------63%----              ] 1276 of 2000 complete in 68.4 sec
#  [-----------------65%----              ] 1315 of 2000 complete in 69.1 sec
#  [-----------------66%-----             ] 1325 of 2000 complete in 69.7 sec
#  [-----------------67%-----             ] 1340 of 2000 complete in 70.2 sec
#  [-----------------67%-----             ] 1359 of 2000 complete in 70.8 sec
#  [-----------------68%-----             ] 1368 of 2000 complete in 71.3 sec
#  [-----------------68%------            ] 1375 of 2000 complete in 72.4 sec
#  [-----------------69%------            ] 1389 of 2000 complete in 73.0 sec
#  [-----------------69%------            ] 1392 of 2000 complete in 73.5 sec
#  [-----------------70%------            ] 1406 of 2000 complete in 74.2 sec
#  [-----------------71%-------           ] 1428 of 2000 complete in 75.1 sec
#  [-----------------72%-------           ] 1452 of 2000 complete in 75.8 sec
#  [-----------------74%--------          ] 1481 of 2000 complete in 76.3 sec
#  [-----------------74%--------          ] 1495 of 2000 complete in 76.9 sec
#  [-----------------75%--------          ] 1502 of 2000 complete in 77.8 sec
#  [-----------------75%--------          ] 1514 of 2000 complete in 78.3 sec
#  [-----------------76%--------          ] 1524 of 2000 complete in 78.9 sec
#  [-----------------76%---------         ] 1533 of 2000 complete in 79.4 sec
#  [-----------------76%---------         ] 1538 of 2000 complete in 80.0 sec
#  [-----------------77%---------         ] 1550 of 2000 complete in 80.5 sec
#  [-----------------78%---------         ] 1561 of 2000 complete in 81.0 sec
#  [-----------------79%----------        ] 1581 of 2000 complete in 82.0 sec
#  [-----------------79%----------        ] 1586 of 2000 complete in 82.5 sec
#  [-----------------79%----------        ] 1598 of 2000 complete in 83.0 sec
#  [-----------------80%----------        ] 1603 of 2000 complete in 83.8 sec
#  [-----------------81%----------        ] 1630 of 2000 complete in 84.3 sec
#  [-----------------81%-----------       ] 1639 of 2000 complete in 84.8 sec
#  [-----------------82%-----------       ] 1641 of 2000 complete in 85.5 sec
#  [-----------------82%-----------       ] 1652 of 2000 complete in 86.1 sec
#  [-----------------83%-----------       ] 1662 of 2000 complete in 86.7 sec
#  [-----------------83%-----------       ] 1666 of 2000 complete in 87.6 sec
#  [-----------------83%-----------       ] 1677 of 2000 complete in 88.1 sec
#  [-----------------84%------------      ] 1689 of 2000 complete in 88.6 sec
#  [-----------------85%------------      ] 1708 of 2000 complete in 89.2 sec
#  [-----------------85%------------      ] 1713 of 2000 complete in 89.7 sec
#  [-----------------86%------------      ] 1725 of 2000 complete in 90.3 sec
#  [-----------------87%-------------     ] 1744 of 2000 complete in 90.8 sec
#  [-----------------88%-------------     ] 1768 of 2000 complete in 91.7 sec
#  [-----------------89%--------------    ] 1790 of 2000 complete in 92.6 sec
#  [-----------------90%--------------    ] 1803 of 2000 complete in 93.1 sec
#  [-----------------90%--------------    ] 1808 of 2000 complete in 93.6 sec
#  [-----------------91%--------------    ] 1820 of 2000 complete in 94.1 sec
#  [-----------------91%--------------    ] 1824 of 2000 complete in 94.7 sec
#  [-----------------91%--------------    ] 1836 of 2000 complete in 95.2 sec
#  [-----------------92%---------------   ] 1846 of 2000 complete in 96.0 sec
#  [-----------------92%---------------   ] 1852 of 2000 complete in 96.7 sec
#  [-----------------94%---------------   ] 1885 of 2000 complete in 97.3 sec
#  [-----------------95%----------------  ] 1917 of 2000 complete in 97.9 sec
#  [-----------------97%----------------  ] 1941 of 2000 complete in 98.4 sec
#  [-----------------97%----------------  ] 1944 of 2000 complete in 99.1 sec
#  [-----------------97%----------------- ] 1953 of 2000 complete in 99.8 sec
#  [-----------------97%----------------- ] 1959 of 2000 complete in 100.3 sec
#  [-----------------98%----------------- ] 1961 of 2000 complete in 101.0 sec
#  [-----------------98%----------------- ] 1967 of 2000 complete in 101.7 sec
#  [-----------------99%----------------- ] 1981 of 2000 complete in 102.5 sec
#  [-----------------99%----------------- ] 1996 of 2000 complete in 103.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 103.3 sec
#  [                  1%                  ] 25 of 2000 complete in 0.5 sec
#  [                  1%                  ] 32 of 2000 complete in 1.2 sec
#  [                  1%                  ] 34 of 2000 complete in 1.8 sec
#  [                  2%                  ] 43 of 2000 complete in 2.7 sec
#  [                  2%                  ] 49 of 2000 complete in 3.5 sec
#  [-                 3%                  ] 61 of 2000 complete in 4.3 sec
#  [-                 3%                  ] 68 of 2000 complete in 4.8 sec
#  [-                 4%                  ] 84 of 2000 complete in 5.4 sec
#  [-                 4%                  ] 91 of 2000 complete in 6.1 sec
#  [--                5%                  ] 113 of 2000 complete in 6.6 sec
#  [--                7%                  ] 152 of 2000 complete in 7.2 sec
#  [---               8%                  ] 165 of 2000 complete in 7.8 sec
#  [---               8%                  ] 171 of 2000 complete in 8.3 sec
#  [---               9%                  ] 183 of 2000 complete in 8.8 sec
#  [---               9%                  ] 188 of 2000 complete in 9.5 sec
#  [---              10%                  ] 200 of 2000 complete in 10.3 sec
#  [---              10%                  ] 206 of 2000 complete in 10.9 sec
#  [----             11%                  ] 222 of 2000 complete in 11.6 sec
#  [----             11%                  ] 227 of 2000 complete in 12.1 sec
#  [----             11%                  ] 235 of 2000 complete in 12.6 sec
#  [----             12%                  ] 246 of 2000 complete in 13.2 sec
#  [-----            13%                  ] 272 of 2000 complete in 13.8 sec
#  [-----            15%                  ] 307 of 2000 complete in 14.3 sec
#  [------           16%                  ] 327 of 2000 complete in 14.8 sec
#  [------           16%                  ] 330 of 2000 complete in 15.4 sec
#  [------           16%                  ] 334 of 2000 complete in 16.1 sec
#  [------           17%                  ] 340 of 2000 complete in 16.6 sec
#  [------           17%                  ] 346 of 2000 complete in 17.2 sec
#  [------           17%                  ] 354 of 2000 complete in 17.8 sec
#  [------           18%                  ] 361 of 2000 complete in 18.4 sec
#  [-------          18%                  ] 378 of 2000 complete in 19.1 sec
#  [-------          19%                  ] 387 of 2000 complete in 19.8 sec
#  [-------          19%                  ] 393 of 2000 complete in 20.4 sec
#  [-------          20%                  ] 408 of 2000 complete in 21.0 sec
#  [-------          20%                  ] 414 of 2000 complete in 21.7 sec
#  [-------          20%                  ] 418 of 2000 complete in 22.2 sec
#  [-------          21%                  ] 421 of 2000 complete in 22.9 sec
#  [--------         21%                  ] 430 of 2000 complete in 23.4 sec
#  [--------         21%                  ] 436 of 2000 complete in 23.9 sec
#  [--------         21%                  ] 439 of 2000 complete in 24.4 sec
#  [--------         22%                  ] 448 of 2000 complete in 24.9 sec
#  [--------         22%                  ] 455 of 2000 complete in 25.5 sec
#  [--------         23%                  ] 471 of 2000 complete in 26.0 sec
#  [---------        24%                  ] 493 of 2000 complete in 26.6 sec
# ...
#  [--------         22%                  ] 457 of 2000 complete in 23.3 sec
#  [---------        24%                  ] 494 of 2000 complete in 23.8 sec
#  [----------       26%                  ] 532 of 2000 complete in 24.3 sec
#  [----------       28%                  ] 563 of 2000 complete in 24.9 sec
#  [----------       28%                  ] 574 of 2000 complete in 25.4 sec
#  [-----------      29%                  ] 583 of 2000 complete in 26.1 sec
#  [-----------      30%                  ] 602 of 2000 complete in 26.6 sec
#  [------------     32%                  ] 641 of 2000 complete in 27.1 sec
#  [------------     33%                  ] 664 of 2000 complete in 27.6 sec
#  [------------     34%                  ] 681 of 2000 complete in 28.1 sec
#  [-------------    34%                  ] 696 of 2000 complete in 28.6 sec
#  [-------------    36%                  ] 726 of 2000 complete in 29.1 sec
#  [--------------   37%                  ] 755 of 2000 complete in 29.6 sec
#  [--------------   39%                  ] 785 of 2000 complete in 30.2 sec
#  [---------------  41%                  ] 828 of 2000 complete in 30.7 sec
#  [---------------- 42%                  ] 856 of 2000 complete in 31.2 sec
#  [---------------- 42%                  ] 858 of 2000 complete in 31.8 sec
#  [---------------- 43%                  ] 869 of 2000 complete in 32.3 sec
#  [-----------------44%                  ] 898 of 2000 complete in 32.8 sec
#  [-----------------45%                  ] 919 of 2000 complete in 33.3 sec
#  [-----------------48%                  ] 962 of 2000 complete in 33.9 sec
#  [-----------------48%                  ] 977 of 2000 complete in 34.4 sec
#  [-----------------50%                  ] 1007 of 2000 complete in 34.9 sec
#  [-----------------52%                  ] 1040 of 2000 complete in 35.5 sec
#  [-----------------53%                  ] 1060 of 2000 complete in 36.0 sec
#  [-----------------54%                  ] 1092 of 2000 complete in 36.5 sec
#  [-----------------55%                  ] 1102 of 2000 complete in 37.0 sec
#  [-----------------55%                  ] 1104 of 2000 complete in 37.9 sec
#  [-----------------55%-                 ] 1112 of 2000 complete in 38.6 sec
#  [-----------------55%-                 ] 1117 of 2000 complete in 39.2 sec
#  [-----------------57%-                 ] 1140 of 2000 complete in 39.7 sec
#  [-----------------58%--                ] 1168 of 2000 complete in 40.2 sec
#  [-----------------60%--                ] 1205 of 2000 complete in 40.7 sec
#  [-----------------61%---               ] 1237 of 2000 complete in 41.2 sec
#  [-----------------63%---               ] 1260 of 2000 complete in 41.8 sec
#  [-----------------63%----              ] 1266 of 2000 complete in 42.4 sec
#  [-----------------63%----              ] 1271 of 2000 complete in 42.9 sec
#  [-----------------64%----              ] 1298 of 2000 complete in 43.4 sec
#  [-----------------66%-----             ] 1328 of 2000 complete in 43.9 sec
#  [-----------------67%-----             ] 1356 of 2000 complete in 44.4 sec
#  [-----------------69%------            ] 1381 of 2000 complete in 44.9 sec
#  [-----------------70%------            ] 1402 of 2000 complete in 45.4 sec
#  [-----------------71%-------           ] 1428 of 2000 complete in 45.9 sec
#  [-----------------72%-------           ] 1457 of 2000 complete in 46.5 sec
#  [-----------------75%--------          ] 1503 of 2000 complete in 47.0 sec
#  [-----------------76%---------         ] 1532 of 2000 complete in 47.5 sec
#  [-----------------77%---------         ] 1558 of 2000 complete in 48.0 sec
#  [-----------------78%---------         ] 1568 of 2000 complete in 48.5 sec
#  [-----------------79%----------        ] 1589 of 2000 complete in 49.0 sec
#  [-----------------81%-----------       ] 1635 of 2000 complete in 49.6 sec
#  [-----------------82%-----------       ] 1647 of 2000 complete in 50.1 sec
#  [-----------------82%-----------       ] 1653 of 2000 complete in 50.6 sec
#  [-----------------83%-----------       ] 1663 of 2000 complete in 51.1 sec
#  [-----------------83%-----------       ] 1669 of 2000 complete in 51.6 sec
#  [-----------------83%-----------       ] 1679 of 2000 complete in 52.1 sec
#  [-----------------85%------------      ] 1704 of 2000 complete in 52.7 sec
#  [-----------------87%-------------     ] 1741 of 2000 complete in 53.2 sec
#  [-----------------89%-------------     ] 1785 of 2000 complete in 53.7 sec
#  [-----------------89%--------------    ] 1799 of 2000 complete in 54.2 sec
#  [-----------------90%--------------    ] 1804 of 2000 complete in 54.7 sec
#  [-----------------91%--------------    ] 1822 of 2000 complete in 55.2 sec
#  [-----------------92%---------------   ] 1847 of 2000 complete in 55.7 sec
#  [-----------------93%---------------   ] 1872 of 2000 complete in 56.2 sec
#  [-----------------95%----------------  ] 1912 of 2000 complete in 56.7 sec
#  [-----------------97%----------------- ] 1952 of 2000 complete in 57.2 sec
#  [-----------------99%----------------- ] 1981 of 2000 complete in 57.7 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 58.2 sec
#  [-                 3%                  ] 77 of 2000 complete in 0.5 sec
#  [---               8%                  ] 162 of 2000 complete in 1.0 sec
#  [----             12%                  ] 248 of 2000 complete in 1.5 sec
#  [------           16%                  ] 339 of 2000 complete in 2.0 sec
#  [--------         21%                  ] 431 of 2000 complete in 2.5 sec
#  [---------        25%                  ] 515 of 2000 complete in 3.0 sec
#  [-----------      30%                  ] 606 of 2000 complete in 3.5 sec
#  [-------------    34%                  ] 693 of 2000 complete in 4.0 sec
#  [--------------   38%                  ] 773 of 2000 complete in 4.5 sec
#  [---------------- 43%                  ] 862 of 2000 complete in 5.0 sec
#  [-----------------48%                  ] 965 of 2000 complete in 5.5 sec
#  [-----------------52%                  ] 1048 of 2000 complete in 6.0 sec
#  [-----------------56%-                 ] 1134 of 2000 complete in 6.6 sec
#  [-----------------60%---               ] 1219 of 2000 complete in 7.1 sec
#  [-----------------66%-----             ] 1325 of 2000 complete in 7.6 sec
#  [-----------------70%------            ] 1415 of 2000 complete in 8.1 sec
#  [-----------------75%--------          ] 1505 of 2000 complete in 8.6 sec
#  [-----------------80%----------        ] 1612 of 2000 complete in 9.1 sec
#  [-----------------85%------------      ] 1709 of 2000 complete in 9.6 sec
#  [-----------------89%--------------    ] 1797 of 2000 complete in 10.1 sec
#  [-----------------94%---------------   ] 1893 of 2000 complete in 10.6 sec
#  [-----------------99%----------------- ] 1985 of 2000 complete in 11.1 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 11.2 sec
#  [-                 3%                  ] 63 of 2000 complete in 0.5 sec
#  [--                6%                  ] 133 of 2000 complete in 1.0 sec
#  [----             10%                  ] 214 of 2000 complete in 1.5 sec
#  [-----            14%                  ] 294 of 2000 complete in 2.0 sec
#  [------           17%                  ] 359 of 2000 complete in 2.5 sec
#  [--------         23%                  ] 462 of 2000 complete in 3.0 sec
#  [----------       27%                  ] 554 of 2000 complete in 3.5 sec
#  [------------     32%                  ] 650 of 2000 complete in 4.0 sec
#  [--------------   37%                  ] 743 of 2000 complete in 4.5 sec
#  [---------------  41%                  ] 833 of 2000 complete in 5.0 sec
#  [-----------------45%                  ] 911 of 2000 complete in 5.5 sec
#  [-----------------49%                  ] 989 of 2000 complete in 6.0 sec
#  [-----------------54%                  ] 1081 of 2000 complete in 6.5 sec
#  [-----------------58%--                ] 1176 of 2000 complete in 7.0 sec
#  [-----------------63%----              ] 1274 of 2000 complete in 7.6 sec
#  [-----------------68%-----             ] 1365 of 2000 complete in 8.1 sec
#  [-----------------72%-------           ] 1457 of 2000 complete in 8.6 sec
#  [-----------------77%---------         ] 1552 of 2000 complete in 9.1 sec
#  [-----------------82%-----------       ] 1642 of 2000 complete in 9.6 sec
#  [-----------------86%------------      ] 1734 of 2000 complete in 10.1 sec
#  [-----------------91%--------------    ] 1826 of 2000 complete in 10.6 sec
#  [-----------------95%----------------  ] 1903 of 2000 complete in 11.1 sec
#  [-----------------99%----------------- ] 1996 of 2000 complete in 11.6 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 11.6 sec
#  [                  1%                  ] 22 of 2000 complete in 0.5 sec
#  [                  2%                  ] 42 of 2000 complete in 1.1 sec
#  [-                 3%                  ] 66 of 2000 complete in 1.6 sec
#  [--                5%                  ] 107 of 2000 complete in 2.1 sec
#  [--                6%                  ] 130 of 2000 complete in 2.7 sec
#  [--                7%                  ] 146 of 2000 complete in 3.2 sec
#  [---               8%                  ] 166 of 2000 complete in 3.7 sec
#  [---              10%                  ] 205 of 2000 complete in 4.2 sec
#  [----             11%                  ] 237 of 2000 complete in 4.8 sec
#  [-----            13%                  ] 265 of 2000 complete in 5.3 sec
#  [-----            15%                  ] 300 of 2000 complete in 5.8 sec
#  [------           16%                  ] 322 of 2000 complete in 6.9 sec
#  [------           16%                  ] 329 of 2000 complete in 7.7 sec
#  [------           16%                  ] 330 of 2000 complete in 8.5 sec
#  [------           17%                  ] 347 of 2000 complete in 9.3 sec
#  [------           18%                  ] 364 of 2000 complete in 9.8 sec
#  [-------          19%                  ] 394 of 2000 complete in 10.3 sec
#  [-------          20%                  ] 419 of 2000 complete in 10.8 sec
#  [--------         22%                  ] 459 of 2000 complete in 11.3 sec
#  [--------         23%                  ] 468 of 2000 complete in 11.8 sec
#  [---------        25%                  ] 501 of 2000 complete in 12.4 sec
#  [---------        25%                  ] 516 of 2000 complete in 12.9 sec
#  [----------       26%                  ] 531 of 2000 complete in 13.4 sec
#  [----------       28%                  ] 569 of 2000 complete in 13.9 sec
#  [-----------      30%                  ] 609 of 2000 complete in 14.5 sec
#  [-----------      31%                  ] 624 of 2000 complete in 15.1 sec
#  [------------     31%                  ] 636 of 2000 complete in 15.6 sec
#  [------------     33%                  ] 665 of 2000 complete in 16.1 sec
#  [-------------    34%                  ] 691 of 2000 complete in 16.7 sec
#  [-------------    35%                  ] 702 of 2000 complete in 17.3 sec
#  [-------------    35%                  ] 708 of 2000 complete in 18.0 sec
#  [-------------    36%                  ] 721 of 2000 complete in 18.5 sec
#  [-------------    36%                  ] 735 of 2000 complete in 19.1 sec
#  [--------------   36%                  ] 739 of 2000 complete in 20.3 sec
#  [--------------   37%                  ] 743 of 2000 complete in 21.7 sec
#  [--------------   37%                  ] 748 of 2000 complete in 22.2 sec
#  [--------------   37%                  ] 752 of 2000 complete in 22.7 sec
#  [--------------   38%                  ] 763 of 2000 complete in 23.3 sec
#  [---------------  40%                  ] 805 of 2000 complete in 23.8 sec
#  [---------------  41%                  ] 838 of 2000 complete in 24.3 sec
#  [---------------- 44%                  ] 880 of 2000 complete in 24.8 sec
#  [-----------------45%                  ] 912 of 2000 complete in 25.3 sec
#  [-----------------47%                  ] 944 of 2000 complete in 25.8 sec
#  [-----------------47%                  ] 959 of 2000 complete in 26.4 sec
#  [-----------------48%                  ] 979 of 2000 complete in 28.0 sec
#  [-----------------49%                  ] 986 of 2000 complete in 29.0 sec
#  [-----------------49%                  ] 995 of 2000 complete in 29.6 sec
#  [-----------------50%                  ] 1001 of 2000 complete in 30.3 sec
#  [-----------------50%                  ] 1005 of 2000 complete in 30.9 sec
#  [-----------------50%                  ] 1013 of 2000 complete in 31.4 sec
#  [-----------------52%                  ] 1049 of 2000 complete in 31.9 sec
#  [-----------------53%                  ] 1077 of 2000 complete in 32.4 sec
#  [-----------------55%                  ] 1104 of 2000 complete in 32.9 sec
#  [-----------------55%-                 ] 1112 of 2000 complete in 33.6 sec
#  [-----------------55%-                 ] 1116 of 2000 complete in 35.6 sec
#  [-----------------56%-                 ] 1122 of 2000 complete in 36.9 sec
#  [-----------------56%-                 ] 1123 of 2000 complete in 37.4 sec
#  [-----------------56%-                 ] 1139 of 2000 complete in 38.3 sec
#  [-----------------57%-                 ] 1154 of 2000 complete in 38.8 sec
#  [-----------------58%--                ] 1162 of 2000 complete in 39.6 sec
#  [-----------------58%--                ] 1166 of 2000 complete in 41.0 sec
#  [-----------------58%--                ] 1171 of 2000 complete in 41.6 sec
#  [-----------------58%--                ] 1179 of 2000 complete in 42.5 sec
#  [-----------------59%--                ] 1188 of 2000 complete in 43.2 sec
#  [-----------------59%--                ] 1193 of 2000 complete in 43.7 sec
#  [-----------------60%--                ] 1202 of 2000 complete in 44.3 sec
#  [-----------------61%---               ] 1237 of 2000 complete in 44.8 sec
#  [-----------------63%----              ] 1270 of 2000 complete in 45.3 sec
#  [-----------------65%----              ] 1301 of 2000 complete in 45.8 sec
#  [-----------------66%-----             ] 1335 of 2000 complete in 46.3 sec
#  [-----------------69%------            ] 1383 of 2000 complete in 46.8 sec
#  [-----------------70%------            ] 1414 of 2000 complete in 47.3 sec
#  [-----------------72%-------           ] 1451 of 2000 complete in 47.8 sec
#  [-----------------73%-------           ] 1469 of 2000 complete in 48.3 sec
#  [-----------------74%--------          ] 1484 of 2000 complete in 49.2 sec
#  [-----------------75%--------          ] 1506 of 2000 complete in 50.0 sec
#  [-----------------76%---------         ] 1537 of 2000 complete in 50.9 sec
#  [-----------------77%---------         ] 1547 of 2000 complete in 51.4 sec
#  [-----------------77%---------         ] 1552 of 2000 complete in 51.9 sec
#  [-----------------77%---------         ] 1556 of 2000 complete in 52.4 sec
#  [-----------------78%----------        ] 1579 of 2000 complete in 53.2 sec
#  [-----------------79%----------        ] 1581 of 2000 complete in 53.8 sec
#  [-----------------80%----------        ] 1604 of 2000 complete in 54.3 sec
#  [-----------------80%----------        ] 1613 of 2000 complete in 54.8 sec
#  [-----------------81%-----------       ] 1636 of 2000 complete in 55.4 sec
#  [-----------------82%-----------       ] 1655 of 2000 complete in 55.9 sec
#  [-----------------84%------------      ] 1691 of 2000 complete in 56.5 sec
#  [-----------------85%------------      ] 1702 of 2000 complete in 57.1 sec
#  [-----------------85%------------      ] 1719 of 2000 complete in 57.6 sec
#  [-----------------87%-------------     ] 1745 of 2000 complete in 58.1 sec
#  [-----------------88%-------------     ] 1768 of 2000 complete in 58.7 sec
#  [-----------------89%-------------     ] 1784 of 2000 complete in 59.2 sec
#  [-----------------90%--------------    ] 1812 of 2000 complete in 59.7 sec
#  [-----------------92%---------------   ] 1858 of 2000 complete in 60.2 sec
#  [-----------------94%---------------   ] 1886 of 2000 complete in 60.8 sec
#  [-----------------96%----------------  ] 1934 of 2000 complete in 61.3 sec
#  [-----------------98%----------------- ] 1978 of 2000 complete in 61.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 62.0 sec

# %% [markdown]
# ## Hierarchical Model
# Instead of initiating the parameters separatly, the hierarchical model initiates group parameters that consider the county's not as completely different but as having an underlying similarity. These distributions are subsequently used to influence the distribution of each county's $\alpha$ and $\beta$.

# %%
with pm.Model() as hierarchical_model:
    # Hyperpriors
    mu_a = pm.Normal('mu_alpha', mu=0., sd=100**2)
    sigma_a = pm.Uniform('sigma_alpha', lower=0, upper=100)
    mu_b = pm.Normal('mu_beta', mu=0., sd=100**2)
    sigma_b = pm.Uniform('sigma_beta', lower=0, upper=100)
    
    # Intercept for each county, distributed around group mean mu_a
    a = pm.Normal('alpha', mu=mu_a, sd=sigma_a, shape=len(data.county.unique()))
    # Intercept for each county, distributed around group mean mu_a
    b = pm.Normal('beta', mu=mu_b, sd=sigma_b, shape=len(data.county.unique()))
    
    # Model error
    eps = pm.Uniform('eps', lower=0, upper=100)
    
    # Expected value
    radon_est = a[county_idx.values] + b[county_idx.values] * data.floor.values
    
    # Data likelihood
    y_like = pm.Normal('y_like', mu=radon_est, sd=eps, observed=data.log_radon)

# %%
with hierarchical_model:
    start = pm.find_MAP()
    step = pm.NUTS(scaling=start)
    hierarchical_trace = pm.sample(2000, step, start=start)
# Out:
#  [                  0%                  ] 6 of 2000 complete in 3.4 sec
#  [                  0%                  ] 7 of 2000 complete in 6.6 sec
#  [                  0%                  ] 10 of 2000 complete in 10.0 sec
#  [                  0%                  ] 11 of 2000 complete in 10.8 sec
#  [                  0%                  ] 12 of 2000 complete in 12.2 sec
#  [                  0%                  ] 14 of 2000 complete in 15.5 sec
#  [                  0%                  ] 15 of 2000 complete in 17.1 sec
#  [                  0%                  ] 17 of 2000 complete in 20.3 sec
#  [                  0%                  ] 18 of 2000 complete in 21.1 sec
#  [                  1%                  ] 20 of 2000 complete in 24.6 sec
#  [                  1%                  ] 22 of 2000 complete in 26.4 sec
#  [                  1%                  ] 24 of 2000 complete in 29.9 sec
#  [                  1%                  ] 25 of 2000 complete in 30.7 sec
#  [                  1%                  ] 27 of 2000 complete in 32.3 sec
#  [                  1%                  ] 28 of 2000 complete in 33.1 sec
#  [                  1%                  ] 29 of 2000 complete in 34.0 sec
#  [                  1%                  ] 31 of 2000 complete in 37.5 sec
#  [                  1%                  ] 32 of 2000 complete in 38.3 sec
#  [                  1%                  ] 34 of 2000 complete in 39.9 sec
#  [                  1%                  ] 35 of 2000 complete in 40.7 sec
#  [                  1%                  ] 37 of 2000 complete in 44.1 sec
#  [                  1%                  ] 38 of 2000 complete in 45.7 sec
#  [                  2%                  ] 40 of 2000 complete in 48.9 sec
#  [                  2%                  ] 41 of 2000 complete in 49.7 sec
#  [                  2%                  ] 43 of 2000 complete in 51.5 sec
#  [                  2%                  ] 44 of 2000 complete in 53.0 sec
#  [                  2%                  ] 46 of 2000 complete in 54.6 sec
#  [                  2%                  ] 47 of 2000 complete in 55.4 sec
#  [                  2%                  ] 48 of 2000 complete in 56.2 sec
#  [                  2%                  ] 50 of 2000 complete in 57.8 sec
#  [                  2%                  ] 52 of 2000 complete in 61.3 sec
#  [-                 2%                  ] 53 of 2000 complete in 62.8 sec
#  [-                 2%                  ] 55 of 2000 complete in 64.4 sec
#  [-                 2%                  ] 56 of 2000 complete in 65.2 sec
#  [-                 2%                  ] 58 of 2000 complete in 67.0 sec
#  [-                 2%                  ] 59 of 2000 complete in 67.9 sec
#  [-                 3%                  ] 61 of 2000 complete in 71.4 sec
#  [-                 3%                  ] 62 of 2000 complete in 73.1 sec
#  [-                 3%                  ] 64 of 2000 complete in 75.1 sec
#  [-                 3%                  ] 65 of 2000 complete in 75.9 sec
#  [-                 3%                  ] 67 of 2000 complete in 77.8 sec
#  [-                 3%                  ] 69 of 2000 complete in 81.3 sec
#  [-                 3%                  ] 70 of 2000 complete in 83.1 sec
#  [-                 3%                  ] 71 of 2000 complete in 83.9 sec
#  [-                 3%                  ] 73 of 2000 complete in 85.6 sec
#  [-                 3%                  ] 74 of 2000 complete in 86.4 sec
#  [-                 3%                  ] 75 of 2000 complete in 89.7 sec
#  [-                 3%                  ] 76 of 2000 complete in 91.3 sec
#  [-                 3%                  ] 78 of 2000 complete in 94.7 sec
#  [-                 3%                  ] 79 of 2000 complete in 95.5 sec
#  [-                 4%                  ] 80 of 2000 complete in 96.3 sec
#  [-                 4%                  ] 81 of 2000 complete in 97.1 sec
#  [-                 4%                  ] 83 of 2000 complete in 99.1 sec
#  [-                 4%                  ] 84 of 2000 complete in 99.9 sec
#  [-                 4%                  ] 85 of 2000 complete in 101.5 sec
#  [-                 4%                  ] 86 of 2000 complete in 102.3 sec
#  [-                 4%                  ] 88 of 2000 complete in 104.1 sec
#  [-                 4%                  ] 89 of 2000 complete in 104.9 sec
#  [-                 4%                  ] 91 of 2000 complete in 106.7 sec
#  [-                 4%                  ] 92 of 2000 complete in 107.6 sec
#  [-                 4%                  ] 93 of 2000 complete in 111.1 sec
#  [-                 4%                  ] 94 of 2000 complete in 112.7 sec
#  [-                 4%                  ] 96 of 2000 complete in 114.7 sec
#  [-                 4%                  ] 97 of 2000 complete in 116.3 sec
#  [-                 4%                  ] 98 of 2000 complete in 117.1 sec
#  [-                 5%                  ] 100 of 2000 complete in 118.9 sec
#  [-                 5%                  ] 101 of 2000 complete in 119.7 sec
#  [-                 5%                  ] 103 of 2000 complete in 121.3 sec
#  [-                 5%                  ] 104 of 2000 complete in 122.1 sec
#  [--                5%                  ] 106 of 2000 complete in 124.2 sec
#  [--                5%                  ] 107 of 2000 complete in 125.1 sec
#  [--                5%                  ] 108 of 2000 complete in 125.8 sec
#  [--                5%                  ] 110 of 2000 complete in 127.4 sec
#  [--                5%                  ] 111 of 2000 complete in 127.9 sec
#  [--                5%                  ] 112 of 2000 complete in 129.4 sec
#  [--                5%                  ] 113 of 2000 complete in 131.0 sec
#  [--                5%                  ] 115 of 2000 complete in 132.9 sec
#  [--                5%                  ] 116 of 2000 complete in 134.5 sec
#  [--                5%                  ] 117 of 2000 complete in 135.4 sec
#  [--                5%                  ] 118 of 2000 complete in 137.0 sec
#  [--                5%                  ] 119 of 2000 complete in 138.5 sec
#  [--                6%                  ] 121 of 2000 complete in 140.4 sec
#  [--                6%                  ] 122 of 2000 complete in 141.3 sec
#  [--                6%                  ] 123 of 2000 complete in 142.1 sec
#  [--                6%                  ] 125 of 2000 complete in 143.7 sec
#  [--                6%                  ] 127 of 2000 complete in 145.6 sec
#  [--                6%                  ] 128 of 2000 complete in 146.4 sec
#  [--                6%                  ] 129 of 2000 complete in 147.2 sec
#  [--                6%                  ] 131 of 2000 complete in 148.8 sec
#  [--                6%                  ] 132 of 2000 complete in 149.6 sec
#  [--                6%                  ] 134 of 2000 complete in 151.3 sec
#  [--                6%                  ] 135 of 2000 complete in 152.2 sec
#  [--                6%                  ] 136 of 2000 complete in 153.0 sec
#  [--                6%                  ] 138 of 2000 complete in 154.6 sec
#  [--                6%                  ] 139 of 2000 complete in 155.4 sec
#  [--                7%                  ] 141 of 2000 complete in 157.1 sec
#  [--                7%                  ] 142 of 2000 complete in 157.8 sec
#  [--                7%                  ] 144 of 2000 complete in 159.7 sec
#  [--                7%                  ] 145 of 2000 complete in 161.4 sec
#  [--                7%                  ] 147 of 2000 complete in 163.3 sec
#  [--                7%                  ] 148 of 2000 complete in 164.9 sec
#  [--                7%                  ] 149 of 2000 complete in 165.7 sec
#  [--                7%                  ] 150 of 2000 complete in 168.9 sec
#  [--                7%                  ] 151 of 2000 complete in 170.4 sec
#  [--                7%                  ] 152 of 2000 complete in 172.0 sec
#  [--                7%                  ] 154 of 2000 complete in 173.7 sec
#  [--                7%                  ] 155 of 2000 complete in 174.5 sec
#  [--                7%                  ] 156 of 2000 complete in 176.0 sec
#  [--                7%                  ] 157 of 2000 complete in 176.8 sec
#  [---               7%                  ] 158 of 2000 complete in 177.6 sec
#  [---               8%                  ] 160 of 2000 complete in 179.4 sec
#  [---               8%                  ] 161 of 2000 complete in 180.4 sec
#  [---               8%                  ] 162 of 2000 complete in 181.3 sec
#  [---               8%                  ] 163 of 2000 complete in 182.9 sec
#  [---               8%                  ] 164 of 2000 complete in 183.7 sec
#  [---               8%                  ] 165 of 2000 complete in 184.5 sec
#  [---               8%                  ] 166 of 2000 complete in 185.3 sec
#  [---               8%                  ] 168 of 2000 complete in 187.6 sec
#  [---               8%                  ] 169 of 2000 complete in 188.4 sec
#  [---               8%                  ] 170 of 2000 complete in 190.0 sec
#  [---               8%                  ] 171 of 2000 complete in 190.8 sec
#  [---               8%                  ] 172 of 2000 complete in 191.5 sec
#  [---               8%                  ] 173 of 2000 complete in 193.0 sec
#  [---               8%                  ] 174 of 2000 complete in 194.7 sec
#  [---               8%                  ] 175 of 2000 complete in 195.6 sec
#  [---               8%                  ] 177 of 2000 complete in 197.4 sec
#  [---               8%                  ] 179 of 2000 complete in 199.5 sec
#  [---               9%                  ] 180 of 2000 complete in 201.1 sec
#  [---               9%                  ] 181 of 2000 complete in 202.8 sec
#  [---               9%                  ] 182 of 2000 complete in 203.7 sec
#  [---               9%                  ] 184 of 2000 complete in 205.9 sec
#  [---               9%                  ] 186 of 2000 complete in 207.8 sec
#  [---               9%                  ] 187 of 2000 complete in 209.6 sec
#  [---               9%                  ] 188 of 2000 complete in 211.4 sec
#  [---               9%                  ] 189 of 2000 complete in 212.4 sec
#  [---               9%                  ] 190 of 2000 complete in 214.2 sec
#  [---               9%                  ] 191 of 2000 complete in 215.1 sec
#  [---               9%                  ] 192 of 2000 complete in 215.9 sec
#  [---               9%                  ] 193 of 2000 complete in 216.5 sec
#  [---               9%                  ] 194 of 2000 complete in 218.1 sec
#  [---               9%                  ] 195 of 2000 complete in 219.6 sec
#  [---               9%                  ] 196 of 2000 complete in 220.4 sec
#  [---               9%                  ] 197 of 2000 complete in 222.0 sec
#  [---               9%                  ] 198 of 2000 complete in 222.8 sec
#  [---              10%                  ] 200 of 2000 complete in 224.5 sec
#  [---              10%                  ] 201 of 2000 complete in 225.4 sec
#  [---              10%                  ] 202 of 2000 complete in 227.2 sec
#  [---              10%                  ] 203 of 2000 complete in 228.0 sec
#  [---              10%                  ] 204 of 2000 complete in 228.7 sec
#  [---              10%                  ] 205 of 2000 complete in 230.4 sec
#  [---              10%                  ] 206 of 2000 complete in 231.2 sec
#  [---              10%                  ] 207 of 2000 complete in 233.1 sec
#  [---              10%                  ] 208 of 2000 complete in 234.9 sec
#  [---              10%                  ] 209 of 2000 complete in 235.7 sec
#  [---              10%                  ] 210 of 2000 complete in 237.4 sec
#  [----             10%                  ] 211 of 2000 complete in 240.6 sec
#  [----             10%                  ] 212 of 2000 complete in 242.2 sec
#  [----             10%                  ] 213 of 2000 complete in 244.0 sec
#  [----             10%                  ] 214 of 2000 complete in 245.6 sec
#  [----             10%                  ] 215 of 2000 complete in 247.2 sec
#  [----             10%                  ] 216 of 2000 complete in 251.9 sec
#  [----             10%                  ] 217 of 2000 complete in 255.1 sec
#  [----             10%                  ] 218 of 2000 complete in 258.2 sec
#  [----             10%                  ] 219 of 2000 complete in 259.8 sec
#  [----             11%                  ] 220 of 2000 complete in 261.4 sec
#  [----             11%                  ] 221 of 2000 complete in 264.8 sec
#  [----             11%                  ] 223 of 2000 complete in 268.4 sec
#  [----             11%                  ] 224 of 2000 complete in 270.0 sec
#  [----             11%                  ] 225 of 2000 complete in 271.6 sec
#  [----             11%                  ] 226 of 2000 complete in 272.3 sec
#  [----             11%                  ] 227 of 2000 complete in 273.2 sec
#  [----             11%                  ] 228 of 2000 complete in 274.0 sec
#  [----             11%                  ] 229 of 2000 complete in 277.7 sec
#  [----             11%                  ] 230 of 2000 complete in 279.5 sec
#  [----             11%                  ] 231 of 2000 complete in 281.3 sec
#  [----             11%                  ] 232 of 2000 complete in 282.4 sec
#  [----             11%                  ] 233 of 2000 complete in 284.2 sec
#  [----             11%                  ] 234 of 2000 complete in 286.0 sec
#  [----             11%                  ] 235 of 2000 complete in 287.0 sec
#  [----             11%                  ] 236 of 2000 complete in 287.7 sec
#  [----             11%                  ] 237 of 2000 complete in 291.4 sec
#  [----             11%                  ] 238 of 2000 complete in 293.3 sec
#  [----             11%                  ] 239 of 2000 complete in 295.1 sec
#  [----             12%                  ] 241 of 2000 complete in 297.2 sec
#  [----             12%                  ] 242 of 2000 complete in 298.0 sec
#  [----             12%                  ] 243 of 2000 complete in 298.9 sec
#  [----             12%                  ] 244 of 2000 complete in 300.8 sec
#  [----             12%                  ] 245 of 2000 complete in 302.6 sec
#  [----             12%                  ] 246 of 2000 complete in 303.4 sec
#  [----             12%                  ] 248 of 2000 complete in 305.4 sec
#  [----             12%                  ] 249 of 2000 complete in 306.1 sec
#  [----             12%                  ] 250 of 2000 complete in 307.8 sec
#  [----             12%                  ] 251 of 2000 complete in 309.5 sec
#  [----             12%                  ] 252 of 2000 complete in 310.3 sec
#  [----             12%                  ] 253 of 2000 complete in 312.1 sec
#  [----             12%                  ] 254 of 2000 complete in 313.9 sec
#  [----             12%                  ] 255 of 2000 complete in 314.8 sec
#  [----             12%                  ] 256 of 2000 complete in 316.6 sec
#  [----             12%                  ] 257 of 2000 complete in 318.7 sec
#  [----             12%                  ] 258 of 2000 complete in 319.6 sec
#  [----             13%                  ] 260 of 2000 complete in 321.7 sec
#  [----             13%                  ] 261 of 2000 complete in 323.7 sec
#  [----             13%                  ] 262 of 2000 complete in 325.7 sec
#  [----             13%                  ] 263 of 2000 complete in 327.6 sec
#  [-----            13%                  ] 264 of 2000 complete in 328.6 sec
#  [-----            13%                  ] 265 of 2000 complete in 330.5 sec
#  [-----            13%                  ] 266 of 2000 complete in 331.5 sec
#  [-----            13%                  ] 267 of 2000 complete in 332.4 sec
#  [-----            13%                  ] 269 of 2000 complete in 334.7 sec
#  [-----            13%                  ] 270 of 2000 complete in 336.8 sec
#  [-----            13%                  ] 271 of 2000 complete in 337.8 sec
#  [-----            13%                  ] 272 of 2000 complete in 339.8 sec
#  [-----            13%                  ] 273 of 2000 complete in 341.8 sec
#  [-----            13%                  ] 274 of 2000 complete in 342.8 sec
#  [-----            13%                  ] 276 of 2000 complete in 345.4 sec
#  [-----            13%                  ] 278 of 2000 complete in 348.3 sec
#  [-----            13%                  ] 279 of 2000 complete in 349.8 sec
#  [-----            14%                  ] 280 of 2000 complete in 355.2 sec
#  [-----            14%                  ] 281 of 2000 complete in 358.1 sec
#  [-----            14%                  ] 282 of 2000 complete in 363.2 sec
#  [-----            14%                  ] 283 of 2000 complete in 368.5 sec
#  [-----            14%                  ] 284 of 2000 complete in 373.8 sec
#  [-----            14%                  ] 285 of 2000 complete in 374.3 sec
#  [-----            14%                  ] 286 of 2000 complete in 379.6 sec
#  [-----            14%                  ] 287 of 2000 complete in 382.1 sec
#  [-----            14%                  ] 288 of 2000 complete in 384.5 sec
#  [-----            14%                  ] 289 of 2000 complete in 387.0 sec
#  [-----            14%                  ] 290 of 2000 complete in 389.6 sec
#  [-----            14%                  ] 291 of 2000 complete in 392.2 sec
#  [-----            14%                  ] 292 of 2000 complete in 394.9 sec
#  [-----            14%                  ] 293 of 2000 complete in 396.2 sec
#  [-----            14%                  ] 294 of 2000 complete in 397.6 sec
#  [-----            14%                  ] 295 of 2000 complete in 400.0 sec
#  [-----            14%                  ] 296 of 2000 complete in 401.3 sec
#  [-----            14%                  ] 297 of 2000 complete in 404.0 sec
#  [-----            14%                  ] 298 of 2000 complete in 406.0 sec
#  [-----            14%                  ] 299 of 2000 complete in 408.4 sec
#  [-----            15%                  ] 300 of 2000 complete in 411.2 sec
#  [-----            15%                  ] 301 of 2000 complete in 413.4 sec
#  [-----            15%                  ] 302 of 2000 complete in 417.1 sec
#  [-----            15%                  ] 303 of 2000 complete in 418.9 sec
#  [-----            15%                  ] 304 of 2000 complete in 420.0 sec
#  [-----            15%                  ] 306 of 2000 complete in 423.5 sec
#  [-----            15%                  ] 307 of 2000 complete in 426.8 sec
#  [-----            15%                  ] 308 of 2000 complete in 430.1 sec
#  [-----            15%                  ] 309 of 2000 complete in 433.3 sec
#  [-----            15%                  ] 311 of 2000 complete in 436.7 sec
#  [-----            15%                  ] 312 of 2000 complete in 439.9 sec
#  [-----            15%                  ] 313 of 2000 complete in 441.6 sec
#  [-----            15%                  ] 314 of 2000 complete in 444.8 sec
#  [------           15%                  ] 316 of 2000 complete in 448.2 sec
#  [------           15%                  ] 317 of 2000 complete in 449.7 sec
#  [------           15%                  ] 318 of 2000 complete in 451.3 sec
#  [------           15%                  ] 319 of 2000 complete in 452.8 sec
#  [------           16%                  ] 321 of 2000 complete in 454.5 sec
#  [------           16%                  ] 322 of 2000 complete in 456.0 sec
#  [------           16%                  ] 323 of 2000 complete in 457.5 sec
#  [------           16%                  ] 324 of 2000 complete in 458.3 sec
#  [------           16%                  ] 325 of 2000 complete in 459.9 sec
#  [------           16%                  ] 326 of 2000 complete in 461.5 sec
#  [------           16%                  ] 327 of 2000 complete in 462.3 sec
#  [------           16%                  ] 328 of 2000 complete in 463.1 sec
#  [------           16%                  ] 329 of 2000 complete in 463.9 sec
#  [------           16%                  ] 331 of 2000 complete in 465.7 sec
#  [------           16%                  ] 332 of 2000 complete in 466.5 sec
#  [------           16%                  ] 333 of 2000 complete in 468.1 sec
#  [------           16%                  ] 334 of 2000 complete in 468.9 sec
#  [------           16%                  ] 336 of 2000 complete in 471.0 sec
#  [------           16%                  ] 337 of 2000 complete in 471.8 sec
#  [------           16%                  ] 339 of 2000 complete in 473.0 sec
#  [------           17%                  ] 340 of 2000 complete in 473.9 sec
#  [------           17%                  ] 342 of 2000 complete in 474.7 sec
#  [------           17%                  ] 343 of 2000 complete in 475.6 sec
#  [------           17%                  ] 344 of 2000 complete in 476.4 sec
#  [------           17%                  ] 345 of 2000 complete in 478.2 sec
#  [------           17%                  ] 346 of 2000 complete in 479.0 sec
#  [------           17%                  ] 347 of 2000 complete in 480.7 sec
#  [------           17%                  ] 348 of 2000 complete in 481.5 sec
#  [------           17%                  ] 349 of 2000 complete in 482.3 sec
#  [------           17%                  ] 351 of 2000 complete in 483.1 sec
#  [------           17%                  ] 352 of 2000 complete in 483.9 sec
#  [------           17%                  ] 353 of 2000 complete in 485.6 sec
#  [------           17%                  ] 354 of 2000 complete in 487.2 sec
#  [------           17%                  ] 355 of 2000 complete in 488.0 sec
#  [------           17%                  ] 356 of 2000 complete in 488.8 sec
#  [------           17%                  ] 357 of 2000 complete in 489.6 sec
#  [------           17%                  ] 358 of 2000 complete in 490.4 sec
#  [------           17%                  ] 359 of 2000 complete in 492.2 sec
#  [------           18%                  ] 360 of 2000 complete in 493.0 sec
#  [------           18%                  ] 361 of 2000 complete in 494.7 sec
#  [------           18%                  ] 362 of 2000 complete in 495.5 sec
#  [------           18%                  ] 363 of 2000 complete in 496.4 sec
#  [------           18%                  ] 364 of 2000 complete in 497.3 sec
#  [------           18%                  ] 365 of 2000 complete in 497.8 sec
#  [------           18%                  ] 366 of 2000 complete in 499.6 sec
#  [------           18%                  ] 367 of 2000 complete in 501.3 sec
#  [------           18%                  ] 368 of 2000 complete in 502.2 sec
#  [-------          18%                  ] 369 of 2000 complete in 503.8 sec
#  [-------          18%                  ] 370 of 2000 complete in 504.7 sec
#  [-------          18%                  ] 371 of 2000 complete in 506.4 sec
#  [-------          18%                  ] 372 of 2000 complete in 508.0 sec
#  [-------          18%                  ] 373 of 2000 complete in 508.8 sec
#  [-------          18%                  ] 374 of 2000 complete in 510.4 sec
#  [-------          18%                  ] 375 of 2000 complete in 511.3 sec
#  [-------          18%                  ] 376 of 2000 complete in 512.2 sec
#  [-------          18%                  ] 377 of 2000 complete in 513.0 sec
#  [-------          18%                  ] 378 of 2000 complete in 513.8 sec
#  [-------          19%                  ] 380 of 2000 complete in 515.6 sec
#  [-------          19%                  ] 381 of 2000 complete in 516.4 sec
#  [-------          19%                  ] 382 of 2000 complete in 517.1 sec
#  [-------          19%                  ] 383 of 2000 complete in 518.7 sec
#  [-------          19%                  ] 384 of 2000 complete in 519.5 sec
#  [-------          19%                  ] 386 of 2000 complete in 520.5 sec
#  [-------          19%                  ] 387 of 2000 complete in 521.4 sec
#  [-------          19%                  ] 388 of 2000 complete in 522.2 sec
#  [-------          19%                  ] 390 of 2000 complete in 523.9 sec
#  [-------          19%                  ] 391 of 2000 complete in 524.6 sec
#  [-------          19%                  ] 393 of 2000 complete in 526.3 sec
#  [-------          19%                  ] 394 of 2000 complete in 527.8 sec
#  [-------          19%                  ] 395 of 2000 complete in 529.4 sec
#  [-------          19%                  ] 396 of 2000 complete in 530.2 sec
#  [-------          19%                  ] 397 of 2000 complete in 531.0 sec
#  [-------          19%                  ] 398 of 2000 complete in 531.9 sec
#  [-------          19%                  ] 399 of 2000 complete in 532.9 sec
#  [-------          20%                  ] 401 of 2000 complete in 533.8 sec
#  [-------          20%                  ] 402 of 2000 complete in 534.6 sec
#  [-------          20%                  ] 403 of 2000 complete in 535.2 sec
#  [-------          20%                  ] 404 of 2000 complete in 536.0 sec
#  [-------          20%                  ] 405 of 2000 complete in 537.6 sec
#  [-------          20%                  ] 406 of 2000 complete in 538.5 sec
#  [-------          20%                  ] 407 of 2000 complete in 539.3 sec
#  [-------          20%                  ] 409 of 2000 complete in 540.9 sec
#  [-------          20%                  ] 410 of 2000 complete in 541.7 sec
#  [-------          20%                  ] 412 of 2000 complete in 543.9 sec
#  [-------          20%                  ] 413 of 2000 complete in 544.7 sec
#  [-------          20%                  ] 414 of 2000 complete in 545.6 sec
#  [-------          20%                  ] 416 of 2000 complete in 547.3 sec
#  [-------          20%                  ] 417 of 2000 complete in 549.0 sec
#  [-------          20%                  ] 418 of 2000 complete in 550.7 sec
#  [-------          20%                  ] 419 of 2000 complete in 552.3 sec
#  [-------          21%                  ] 420 of 2000 complete in 553.1 sec
#  [--------         21%                  ] 422 of 2000 complete in 554.9 sec
#  [--------         21%                  ] 423 of 2000 complete in 555.8 sec
#  [--------         21%                  ] 424 of 2000 complete in 556.6 sec
#  [--------         21%                  ] 425 of 2000 complete in 557.5 sec
#  [--------         21%                  ] 426 of 2000 complete in 558.3 sec
#  [--------         21%                  ] 427 of 2000 complete in 559.2 sec
#  [--------         21%                  ] 429 of 2000 complete in 560.0 sec
#  [--------         21%                  ] 430 of 2000 complete in 561.7 sec
#  [--------         21%                  ] 431 of 2000 complete in 563.2 sec
#  [--------         21%                  ] 432 of 2000 complete in 564.0 sec
#  [--------         21%                  ] 433 of 2000 complete in 565.6 sec
#  [--------         21%                  ] 434 of 2000 complete in 566.5 sec
#  [--------         21%                  ] 436 of 2000 complete in 568.5 sec
#  [--------         21%                  ] 437 of 2000 complete in 569.3 sec
#  [--------         21%                  ] 439 of 2000 complete in 570.8 sec
#  [--------         22%                  ] 440 of 2000 complete in 572.4 sec
#  [--------         22%                  ] 441 of 2000 complete in 573.2 sec
#  [--------         22%                  ] 442 of 2000 complete in 574.0 sec
#  [--------         22%                  ] 443 of 2000 complete in 574.8 sec
#  [--------         22%                  ] 444 of 2000 complete in 575.6 sec
#  [--------         22%                  ] 445 of 2000 complete in 576.5 sec
#  [--------         22%                  ] 446 of 2000 complete in 578.2 sec
#  [--------         22%                  ] 447 of 2000 complete in 579.0 sec
#  [--------         22%                  ] 449 of 2000 complete in 580.7 sec
#  [--------         22%                  ] 450 of 2000 complete in 581.5 sec
#  [--------         22%                  ] 451 of 2000 complete in 582.2 sec
#  [--------         22%                  ] 452 of 2000 complete in 583.0 sec
#  [--------         22%                  ] 453 of 2000 complete in 583.8 sec
#  [--------         22%                  ] 455 of 2000 complete in 584.6 sec
#  [--------         22%                  ] 456 of 2000 complete in 586.2 sec
#  [--------         22%                  ] 457 of 2000 complete in 587.0 sec
#  [--------         22%                  ] 459 of 2000 complete in 588.3 sec
#  [--------         23%                  ] 460 of 2000 complete in 588.8 sec
#  [--------         23%                  ] 461 of 2000 complete in 590.3 sec
#  [--------         23%                  ] 462 of 2000 complete in 591.1 sec
#  [--------         23%                  ] 463 of 2000 complete in 591.6 sec
#  [--------         23%                  ] 464 of 2000 complete in 592.4 sec
#  [--------         23%                  ] 466 of 2000 complete in 594.1 sec
#  [--------         23%                  ] 467 of 2000 complete in 594.8 sec
#  [--------         23%                  ] 468 of 2000 complete in 595.4 sec
#  [--------         23%                  ] 469 of 2000 complete in 596.9 sec
#  [--------         23%                  ] 470 of 2000 complete in 597.7 sec
#  [--------         23%                  ] 471 of 2000 complete in 598.4 sec
#  [--------         23%                  ] 472 of 2000 complete in 599.2 sec
#  [--------         23%                  ] 473 of 2000 complete in 600.0 sec
#  [---------        23%                  ] 475 of 2000 complete in 601.6 sec
#  [---------        23%                  ] 476 of 2000 complete in 602.4 sec
#  [---------        23%                  ] 477 of 2000 complete in 603.2 sec
#  [---------        23%                  ] 478 of 2000 complete in 604.7 sec
#  [---------        23%                  ] 479 of 2000 complete in 606.3 sec
#  [---------        24%                  ] 480 of 2000 complete in 607.9 sec
#  [---------        24%                  ] 481 of 2000 complete in 608.7 sec
#  [---------        24%                  ] 482 of 2000 complete in 609.2 sec
#  [---------        24%                  ] 483 of 2000 complete in 610.8 sec
#  [---------        24%                  ] 484 of 2000 complete in 611.3 sec
#  [---------        24%                  ] 485 of 2000 complete in 612.9 sec
#  [---------        24%                  ] 486 of 2000 complete in 614.4 sec
#  [---------        24%                  ] 487 of 2000 complete in 615.1 sec
#  [---------        24%                  ] 488 of 2000 complete in 616.7 sec
#  [---------        24%                  ] 489 of 2000 complete in 617.4 sec
#  [---------        24%                  ] 491 of 2000 complete in 619.2 sec
#  [---------        24%                  ] 492 of 2000 complete in 619.9 sec
#  [---------        24%                  ] 493 of 2000 complete in 621.5 sec
#  [---------        24%                  ] 494 of 2000 complete in 622.2 sec
#  [---------        24%                  ] 495 of 2000 complete in 623.0 sec
#  [---------        24%                  ] 497 of 2000 complete in 623.9 sec
#  [---------        24%                  ] 498 of 2000 complete in 624.7 sec
#  [---------        24%                  ] 499 of 2000 complete in 625.5 sec
#  [---------        25%                  ] 501 of 2000 complete in 627.2 sec
#  [---------        25%                  ] 502 of 2000 complete in 628.7 sec
#  [---------        25%                  ] 503 of 2000 complete in 629.5 sec
#  [---------        25%                  ] 505 of 2000 complete in 631.0 sec
#  [---------        25%                  ] 506 of 2000 complete in 631.8 sec
#  [---------        25%                  ] 507 of 2000 complete in 632.3 sec
#  [---------        25%                  ] 508 of 2000 complete in 633.9 sec
#  [---------        25%                  ] 509 of 2000 complete in 635.0 sec
#  [---------        25%                  ] 510 of 2000 complete in 635.9 sec
#  [---------        25%                  ] 511 of 2000 complete in 636.7 sec
#  [---------        25%                  ] 512 of 2000 complete in 638.3 sec
#  [---------        25%                  ] 513 of 2000 complete in 639.0 sec
#  [---------        25%                  ] 514 of 2000 complete in 639.8 sec
#  [---------        25%                  ] 515 of 2000 complete in 640.6 sec
#  [---------        25%                  ] 516 of 2000 complete in 641.5 sec
#  [---------        25%                  ] 518 of 2000 complete in 643.2 sec
#  [---------        25%                  ] 519 of 2000 complete in 644.8 sec
#  [---------        26%                  ] 520 of 2000 complete in 645.6 sec
#  [---------        26%                  ] 522 of 2000 complete in 647.3 sec
#  [---------        26%                  ] 523 of 2000 complete in 648.1 sec
#  [---------        26%                  ] 524 of 2000 complete in 648.9 sec
#  [---------        26%                  ] 526 of 2000 complete in 649.7 sec
#  [----------       26%                  ] 527 of 2000 complete in 650.5 sec
#  [----------       26%                  ] 528 of 2000 complete in 651.2 sec
#  [----------       26%                  ] 529 of 2000 complete in 652.8 sec
#  [----------       26%                  ] 531 of 2000 complete in 654.8 sec
#  [----------       26%                  ] 532 of 2000 complete in 656.4 sec
#  [----------       26%                  ] 533 of 2000 complete in 657.3 sec
#  [----------       26%                  ] 534 of 2000 complete in 658.1 sec
#  [----------       26%                  ] 535 of 2000 complete in 658.9 sec
#  [----------       26%                  ] 537 of 2000 complete in 660.8 sec
#  [----------       26%                  ] 538 of 2000 complete in 662.3 sec
#  [----------       26%                  ] 539 of 2000 complete in 663.1 sec
#  [----------       27%                  ] 541 of 2000 complete in 664.9 sec
#  [----------       27%                  ] 542 of 2000 complete in 665.7 sec
#  [----------       27%                  ] 544 of 2000 complete in 667.5 sec
#  [----------       27%                  ] 545 of 2000 complete in 669.1 sec
#  [----------       27%                  ] 546 of 2000 complete in 670.8 sec
#  [----------       27%                  ] 547 of 2000 complete in 671.6 sec
#  [----------       27%                  ] 549 of 2000 complete in 673.8 sec
#  [----------       27%                  ] 550 of 2000 complete in 675.4 sec
#  [----------       27%                  ] 551 of 2000 complete in 676.2 sec
#  [----------       27%                  ] 552 of 2000 complete in 677.0 sec
#  [----------       27%                  ] 553 of 2000 complete in 677.8 sec
#  [----------       27%                  ] 555 of 2000 complete in 679.8 sec
#  [----------       27%                  ] 556 of 2000 complete in 681.6 sec
#  [----------       27%                  ] 557 of 2000 complete in 682.4 sec
#  [----------       27%                  ] 558 of 2000 complete in 683.2 sec
#  [----------       27%                  ] 559 of 2000 complete in 684.0 sec
#  [----------       28%                  ] 560 of 2000 complete in 685.6 sec
#  [----------       28%                  ] 561 of 2000 complete in 687.1 sec
#  [----------       28%                  ] 562 of 2000 complete in 688.7 sec
#  [----------       28%                  ] 564 of 2000 complete in 690.7 sec
#  [----------       28%                  ] 565 of 2000 complete in 692.2 sec
#  [----------       28%                  ] 566 of 2000 complete in 693.8 sec
#  [----------       28%                  ] 567 of 2000 complete in 695.3 sec
#  [----------       28%                  ] 568 of 2000 complete in 696.1 sec
#  [----------       28%                  ] 569 of 2000 complete in 696.8 sec
#  [----------       28%                  ] 570 of 2000 complete in 697.6 sec
#  [----------       28%                  ] 571 of 2000 complete in 699.2 sec
#  [----------       28%                  ] 572 of 2000 complete in 700.8 sec
#  [----------       28%                  ] 573 of 2000 complete in 702.3 sec
#  [----------       28%                  ] 574 of 2000 complete in 703.8 sec
#  [----------       28%                  ] 575 of 2000 complete in 704.6 sec
#  [----------       28%                  ] 576 of 2000 complete in 705.4 sec
#  [----------       28%                  ] 577 of 2000 complete in 706.1 sec
#  [-----------      28%                  ] 579 of 2000 complete in 707.0 sec
#  [-----------      29%                  ] 580 of 2000 complete in 707.8 sec
#  [-----------      29%                  ] 582 of 2000 complete in 709.7 sec
#  [-----------      29%                  ] 583 of 2000 complete in 710.5 sec
#  [-----------      29%                  ] 584 of 2000 complete in 711.2 sec
#  [-----------      29%                  ] 585 of 2000 complete in 712.0 sec
#  [-----------      29%                  ] 586 of 2000 complete in 712.8 sec
#  [-----------      29%                  ] 587 of 2000 complete in 713.5 sec
#  [-----------      29%                  ] 589 of 2000 complete in 714.6 sec
#  [-----------      29%                  ] 590 of 2000 complete in 715.4 sec
#  [-----------      29%                  ] 591 of 2000 complete in 716.1 sec
#  [-----------      29%                  ] 592 of 2000 complete in 716.9 sec
#  [-----------      29%                  ] 593 of 2000 complete in 717.5 sec
#  [-----------      29%                  ] 594 of 2000 complete in 718.2 sec
#  [-----------      29%                  ] 595 of 2000 complete in 719.8 sec
#  [-----------      29%                  ] 596 of 2000 complete in 721.3 sec
#  [-----------      29%                  ] 597 of 2000 complete in 722.0 sec
#  [-----------      29%                  ] 598 of 2000 complete in 723.6 sec
#  [-----------      29%                  ] 599 of 2000 complete in 725.1 sec
#  [-----------      30%                  ] 600 of 2000 complete in 726.6 sec
#  [-----------      30%                  ] 601 of 2000 complete in 727.4 sec
#  [-----------      30%                  ] 602 of 2000 complete in 728.1 sec
#  [-----------      30%                  ] 603 of 2000 complete in 729.7 sec
#  [-----------      30%                  ] 604 of 2000 complete in 731.3 sec
#  [-----------      30%                  ] 605 of 2000 complete in 732.0 sec
#  [-----------      30%                  ] 606 of 2000 complete in 732.8 sec
#  [-----------      30%                  ] 607 of 2000 complete in 733.6 sec
#  [-----------      30%                  ] 608 of 2000 complete in 735.2 sec
#  [-----------      30%                  ] 609 of 2000 complete in 736.7 sec
#  [-----------      30%                  ] 610 of 2000 complete in 737.5 sec
#  [-----------      30%                  ] 611 of 2000 complete in 738.3 sec
#  [-----------      30%                  ] 612 of 2000 complete in 739.0 sec
#  [-----------      30%                  ] 613 of 2000 complete in 739.9 sec
#  [-----------      30%                  ] 615 of 2000 complete in 741.2 sec
#  [-----------      30%                  ] 616 of 2000 complete in 742.0 sec
#  [-----------      30%                  ] 617 of 2000 complete in 742.8 sec
#  [-----------      30%                  ] 618 of 2000 complete in 743.6 sec
#  [-----------      30%                  ] 619 of 2000 complete in 744.3 sec
#  [-----------      31%                  ] 620 of 2000 complete in 744.8 sec
#  [-----------      31%                  ] 621 of 2000 complete in 745.6 sec
#  [-----------      31%                  ] 622 of 2000 complete in 746.4 sec
#  [-----------      31%                  ] 623 of 2000 complete in 748.0 sec
#  [-----------      31%                  ] 624 of 2000 complete in 748.8 sec
#  [-----------      31%                  ] 625 of 2000 complete in 749.6 sec
#  [-----------      31%                  ] 626 of 2000 complete in 750.4 sec
#  [-----------      31%                  ] 627 of 2000 complete in 750.9 sec
#  [-----------      31%                  ] 628 of 2000 complete in 752.5 sec
#  [-----------      31%                  ] 629 of 2000 complete in 754.1 sec
#  [-----------      31%                  ] 630 of 2000 complete in 755.8 sec
#  [-----------      31%                  ] 631 of 2000 complete in 756.6 sec
#  [------------     31%                  ] 633 of 2000 complete in 758.5 sec
#  [------------     31%                  ] 634 of 2000 complete in 759.3 sec
#  [------------     31%                  ] 635 of 2000 complete in 760.1 sec
#  [------------     31%                  ] 636 of 2000 complete in 760.9 sec
#  [------------     31%                  ] 637 of 2000 complete in 761.7 sec
#  [------------     31%                  ] 638 of 2000 complete in 763.3 sec
#  [------------     32%                  ] 640 of 2000 complete in 764.3 sec
#  [------------     32%                  ] 641 of 2000 complete in 764.8 sec
#  [------------     32%                  ] 642 of 2000 complete in 766.3 sec
#  [------------     32%                  ] 643 of 2000 complete in 767.9 sec
#  [------------     32%                  ] 644 of 2000 complete in 768.7 sec
#  [------------     32%                  ] 645 of 2000 complete in 769.5 sec
#  [------------     32%                  ] 646 of 2000 complete in 770.3 sec
#  [------------     32%                  ] 647 of 2000 complete in 771.0 sec
#  [------------     32%                  ] 648 of 2000 complete in 771.7 sec
#  [------------     32%                  ] 649 of 2000 complete in 772.5 sec
#  [------------     32%                  ] 650 of 2000 complete in 774.0 sec
#  [------------     32%                  ] 652 of 2000 complete in 775.2 sec
#  [------------     32%                  ] 653 of 2000 complete in 776.7 sec
#  [------------     32%                  ] 654 of 2000 complete in 778.3 sec
#  [------------     32%                  ] 656 of 2000 complete in 780.0 sec
#  [------------     32%                  ] 657 of 2000 complete in 781.6 sec
#  [------------     32%                  ] 658 of 2000 complete in 783.2 sec
#  [------------     32%                  ] 659 of 2000 complete in 785.1 sec
#  [------------     33%                  ] 660 of 2000 complete in 786.8 sec
#  [------------     33%                  ] 661 of 2000 complete in 788.5 sec
#  [------------     33%                  ] 662 of 2000 complete in 790.2 sec
#  [------------     33%                  ] 663 of 2000 complete in 791.8 sec
#  [------------     33%                  ] 664 of 2000 complete in 793.5 sec
#  [------------     33%                  ] 665 of 2000 complete in 795.2 sec
#  [------------     33%                  ] 666 of 2000 complete in 796.8 sec
#  [------------     33%                  ] 667 of 2000 complete in 797.6 sec
#  [------------     33%                  ] 669 of 2000 complete in 799.7 sec
#  [------------     33%                  ] 670 of 2000 complete in 800.5 sec
#  [------------     33%                  ] 671 of 2000 complete in 801.5 sec
#  [------------     33%                  ] 672 of 2000 complete in 803.4 sec
#  [------------     33%                  ] 673 of 2000 complete in 805.0 sec
#  [------------     33%                  ] 674 of 2000 complete in 806.5 sec
#  [------------     33%                  ] 675 of 2000 complete in 807.4 sec
#  [------------     33%                  ] 676 of 2000 complete in 808.0 sec
#  [------------     33%                  ] 677 of 2000 complete in 809.6 sec
#  [------------     33%                  ] 678 of 2000 complete in 810.5 sec
#  [------------     33%                  ] 679 of 2000 complete in 811.3 sec
#  [------------     34%                  ] 680 of 2000 complete in 812.2 sec
#  [------------     34%                  ] 681 of 2000 complete in 812.9 sec
#  [------------     34%                  ] 682 of 2000 complete in 814.5 sec
#  [------------     34%                  ] 683 of 2000 complete in 815.2 sec
#  [------------     34%                  ] 684 of 2000 complete in 816.1 sec
#  [-------------    34%                  ] 685 of 2000 complete in 816.8 sec
#  [-------------    34%                  ] 686 of 2000 complete in 818.5 sec
#  [-------------    34%                  ] 687 of 2000 complete in 819.3 sec
#  [-------------    34%                  ] 689 of 2000 complete in 821.4 sec
#  [-------------    34%                  ] 690 of 2000 complete in 822.2 sec
#  [-------------    34%                  ] 691 of 2000 complete in 823.0 sec
#  [-------------    34%                  ] 692 of 2000 complete in 824.6 sec
#  [-------------    34%                  ] 693 of 2000 complete in 826.4 sec
#  [-------------    34%                  ] 694 of 2000 complete in 828.1 sec
#  [-------------    34%                  ] 695 of 2000 complete in 829.6 sec
#  [-------------    34%                  ] 696 of 2000 complete in 831.2 sec
#  [-------------    34%                  ] 697 of 2000 complete in 832.7 sec
#  [-------------    34%                  ] 698 of 2000 complete in 834.3 sec
#  [-------------    34%                  ] 699 of 2000 complete in 835.9 sec
#  [-------------    35%                  ] 700 of 2000 complete in 837.4 sec
#  [-------------    35%                  ] 701 of 2000 complete in 838.9 sec
#  [-------------    35%                  ] 702 of 2000 complete in 839.7 sec
#  [-------------    35%                  ] 703 of 2000 complete in 840.5 sec
#  [-------------    35%                  ] 704 of 2000 complete in 841.2 sec
#  [-------------    35%                  ] 706 of 2000 complete in 843.0 sec
#  [-------------    35%                  ] 707 of 2000 complete in 844.7 sec
#  [-------------    35%                  ] 708 of 2000 complete in 846.3 sec
#  [-------------    35%                  ] 709 of 2000 complete in 847.1 sec
#  [-------------    35%                  ] 710 of 2000 complete in 847.7 sec
#  [-------------    35%                  ] 711 of 2000 complete in 849.3 sec
#  [-------------    35%                  ] 712 of 2000 complete in 850.0 sec
#  [-------------    35%                  ] 713 of 2000 complete in 851.6 sec
#  [-------------    35%                  ] 714 of 2000 complete in 852.9 sec
#  [-------------    35%                  ] 715 of 2000 complete in 854.4 sec
#  [-------------    35%                  ] 716 of 2000 complete in 856.0 sec
#  [-------------    35%                  ] 717 of 2000 complete in 857.6 sec
#  [-------------    35%                  ] 718 of 2000 complete in 860.7 sec
#  [-------------    35%                  ] 719 of 2000 complete in 862.2 sec
#  [-------------    36%                  ] 720 of 2000 complete in 864.0 sec
#  [-------------    36%                  ] 721 of 2000 complete in 864.8 sec
#  [-------------    36%                  ] 722 of 2000 complete in 866.7 sec
#  [-------------    36%                  ] 723 of 2000 complete in 868.3 sec
#  [-------------    36%                  ] 724 of 2000 complete in 869.9 sec
#  [-------------    36%                  ] 725 of 2000 complete in 871.6 sec
#  [-------------    36%                  ] 726 of 2000 complete in 875.1 sec
#  [-------------    36%                  ] 727 of 2000 complete in 876.9 sec
#  [-------------    36%                  ] 728 of 2000 complete in 878.7 sec
#  [-------------    36%                  ] 729 of 2000 complete in 880.5 sec
#  [-------------    36%                  ] 730 of 2000 complete in 882.3 sec
#  [-------------    36%                  ] 731 of 2000 complete in 884.1 sec
#  [-------------    36%                  ] 732 of 2000 complete in 885.7 sec
#  [-------------    36%                  ] 733 of 2000 complete in 887.4 sec
#  [-------------    36%                  ] 734 of 2000 complete in 889.1 sec
#  [-------------    36%                  ] 735 of 2000 complete in 890.0 sec
#  [-------------    36%                  ] 736 of 2000 complete in 890.8 sec
#  [--------------   36%                  ] 737 of 2000 complete in 892.5 sec
#  [--------------   36%                  ] 738 of 2000 complete in 893.5 sec
#  [--------------   36%                  ] 739 of 2000 complete in 894.3 sec
#  [--------------   37%                  ] 740 of 2000 complete in 895.9 sec
#  [--------------   37%                  ] 741 of 2000 complete in 896.7 sec
#  [--------------   37%                  ] 742 of 2000 complete in 897.5 sec
#  [--------------   37%                  ] 743 of 2000 complete in 899.1 sec
#  [--------------   37%                  ] 744 of 2000 complete in 900.7 sec
#  [--------------   37%                  ] 745 of 2000 complete in 902.3 sec
#  [--------------   37%                  ] 746 of 2000 complete in 903.1 sec
# ...
#  [-----------------89%-------------     ] 1784 of 2000 complete in 2123.2 sec
#  [-----------------89%-------------     ] 1785 of 2000 complete in 2124.9 sec
#  [-----------------89%-------------     ] 1786 of 2000 complete in 2126.6 sec
#  [-----------------89%-------------     ] 1787 of 2000 complete in 2128.1 sec
#  [-----------------89%-------------     ] 1788 of 2000 complete in 2129.8 sec
#  [-----------------89%--------------    ] 1790 of 2000 complete in 2131.0 sec
#  [-----------------89%--------------    ] 1791 of 2000 complete in 2131.9 sec
#  [-----------------89%--------------    ] 1792 of 2000 complete in 2133.5 sec
#  [-----------------89%--------------    ] 1793 of 2000 complete in 2135.2 sec
#  [-----------------89%--------------    ] 1794 of 2000 complete in 2137.2 sec
#  [-----------------89%--------------    ] 1795 of 2000 complete in 2139.0 sec
#  [-----------------89%--------------    ] 1796 of 2000 complete in 2140.6 sec
#  [-----------------89%--------------    ] 1797 of 2000 complete in 2142.3 sec
#  [-----------------89%--------------    ] 1798 of 2000 complete in 2143.8 sec
#  [-----------------89%--------------    ] 1799 of 2000 complete in 2144.7 sec
#  [-----------------90%--------------    ] 1800 of 2000 complete in 2145.4 sec
#  [-----------------90%--------------    ] 1801 of 2000 complete in 2146.2 sec
#  [-----------------90%--------------    ] 1802 of 2000 complete in 2146.9 sec
#  [-----------------90%--------------    ] 1803 of 2000 complete in 2147.7 sec
#  [-----------------90%--------------    ] 1804 of 2000 complete in 2149.2 sec
#  [-----------------90%--------------    ] 1805 of 2000 complete in 2150.8 sec
#  [-----------------90%--------------    ] 1806 of 2000 complete in 2152.6 sec
#  [-----------------90%--------------    ] 1807 of 2000 complete in 2154.3 sec
#  [-----------------90%--------------    ] 1808 of 2000 complete in 2156.0 sec
#  [-----------------90%--------------    ] 1810 of 2000 complete in 2157.8 sec
#  [-----------------90%--------------    ] 1811 of 2000 complete in 2159.5 sec
#  [-----------------90%--------------    ] 1812 of 2000 complete in 2161.1 sec
#  [-----------------90%--------------    ] 1813 of 2000 complete in 2162.8 sec
#  [-----------------90%--------------    ] 1814 of 2000 complete in 2163.8 sec
#  [-----------------90%--------------    ] 1815 of 2000 complete in 2165.4 sec
#  [-----------------90%--------------    ] 1816 of 2000 complete in 2167.0 sec
#  [-----------------90%--------------    ] 1817 of 2000 complete in 2168.5 sec
#  [-----------------90%--------------    ] 1818 of 2000 complete in 2170.1 sec
#  [-----------------90%--------------    ] 1819 of 2000 complete in 2171.8 sec
#  [-----------------91%--------------    ] 1820 of 2000 complete in 2173.5 sec
#  [-----------------91%--------------    ] 1821 of 2000 complete in 2175.1 sec
#  [-----------------91%--------------    ] 1822 of 2000 complete in 2176.8 sec
#  [-----------------91%--------------    ] 1823 of 2000 complete in 2178.3 sec
#  [-----------------91%--------------    ] 1824 of 2000 complete in 2179.9 sec
#  [-----------------91%--------------    ] 1825 of 2000 complete in 2181.5 sec
#  [-----------------91%--------------    ] 1826 of 2000 complete in 2182.3 sec
#  [-----------------91%--------------    ] 1827 of 2000 complete in 2183.1 sec
#  [-----------------91%--------------    ] 1828 of 2000 complete in 2183.8 sec
#  [-----------------91%--------------    ] 1829 of 2000 complete in 2184.6 sec
#  [-----------------91%--------------    ] 1831 of 2000 complete in 2186.3 sec
#  [-----------------91%--------------    ] 1832 of 2000 complete in 2187.1 sec
#  [-----------------91%--------------    ] 1833 of 2000 complete in 2187.9 sec
#  [-----------------91%--------------    ] 1834 of 2000 complete in 2188.6 sec
#  [-----------------91%--------------    ] 1835 of 2000 complete in 2189.4 sec
#  [-----------------91%--------------    ] 1836 of 2000 complete in 2190.1 sec
#  [-----------------91%--------------    ] 1837 of 2000 complete in 2190.9 sec
#  [-----------------91%--------------    ] 1838 of 2000 complete in 2191.7 sec
#  [-----------------91%--------------    ] 1839 of 2000 complete in 2192.4 sec
#  [-----------------92%--------------    ] 1840 of 2000 complete in 2193.2 sec
#  [-----------------92%--------------    ] 1841 of 2000 complete in 2193.9 sec
#  [-----------------92%--------------    ] 1842 of 2000 complete in 2194.7 sec
#  [-----------------92%---------------   ] 1844 of 2000 complete in 2195.6 sec
#  [-----------------92%---------------   ] 1845 of 2000 complete in 2196.4 sec
#  [-----------------92%---------------   ] 1846 of 2000 complete in 2197.2 sec
#  [-----------------92%---------------   ] 1847 of 2000 complete in 2198.0 sec
#  [-----------------92%---------------   ] 1848 of 2000 complete in 2198.8 sec
#  [-----------------92%---------------   ] 1849 of 2000 complete in 2199.6 sec
#  [-----------------92%---------------   ] 1850 of 2000 complete in 2201.3 sec
#  [-----------------92%---------------   ] 1851 of 2000 complete in 2203.0 sec
#  [-----------------92%---------------   ] 1852 of 2000 complete in 2204.7 sec
#  [-----------------92%---------------   ] 1853 of 2000 complete in 2205.5 sec
#  [-----------------92%---------------   ] 1854 of 2000 complete in 2207.2 sec
#  [-----------------92%---------------   ] 1855 of 2000 complete in 2208.7 sec
#  [-----------------92%---------------   ] 1856 of 2000 complete in 2209.5 sec
#  [-----------------92%---------------   ] 1857 of 2000 complete in 2210.3 sec
#  [-----------------92%---------------   ] 1858 of 2000 complete in 2211.1 sec
#  [-----------------92%---------------   ] 1859 of 2000 complete in 2212.7 sec
#  [-----------------93%---------------   ] 1860 of 2000 complete in 2214.2 sec
#  [-----------------93%---------------   ] 1861 of 2000 complete in 2215.8 sec
#  [-----------------93%---------------   ] 1862 of 2000 complete in 2217.4 sec
#  [-----------------93%---------------   ] 1863 of 2000 complete in 2219.0 sec
#  [-----------------93%---------------   ] 1864 of 2000 complete in 2220.5 sec
#  [-----------------93%---------------   ] 1865 of 2000 complete in 2221.3 sec
#  [-----------------93%---------------   ] 1866 of 2000 complete in 2222.1 sec
#  [-----------------93%---------------   ] 1867 of 2000 complete in 2222.9 sec
#  [-----------------93%---------------   ] 1868 of 2000 complete in 2223.6 sec
#  [-----------------93%---------------   ] 1869 of 2000 complete in 2224.4 sec
#  [-----------------93%---------------   ] 1870 of 2000 complete in 2225.2 sec
#  [-----------------93%---------------   ] 1871 of 2000 complete in 2226.0 sec
#  [-----------------93%---------------   ] 1872 of 2000 complete in 2226.8 sec
#  [-----------------93%---------------   ] 1873 of 2000 complete in 2228.4 sec
#  [-----------------93%---------------   ] 1874 of 2000 complete in 2230.1 sec
#  [-----------------93%---------------   ] 1875 of 2000 complete in 2230.9 sec
#  [-----------------93%---------------   ] 1876 of 2000 complete in 2231.7 sec
#  [-----------------93%---------------   ] 1877 of 2000 complete in 2232.5 sec
#  [-----------------93%---------------   ] 1878 of 2000 complete in 2233.4 sec
#  [-----------------93%---------------   ] 1879 of 2000 complete in 2234.2 sec
#  [-----------------94%---------------   ] 1880 of 2000 complete in 2235.0 sec
#  [-----------------94%---------------   ] 1881 of 2000 complete in 2235.7 sec
#  [-----------------94%---------------   ] 1883 of 2000 complete in 2236.6 sec
#  [-----------------94%---------------   ] 1884 of 2000 complete in 2237.4 sec
#  [-----------------94%---------------   ] 1885 of 2000 complete in 2238.2 sec
#  [-----------------94%---------------   ] 1886 of 2000 complete in 2239.0 sec
#  [-----------------94%---------------   ] 1887 of 2000 complete in 2239.8 sec
#  [-----------------94%---------------   ] 1888 of 2000 complete in 2240.3 sec
#  [-----------------94%---------------   ] 1889 of 2000 complete in 2241.9 sec
#  [-----------------94%---------------   ] 1890 of 2000 complete in 2243.4 sec
#  [-----------------94%---------------   ] 1891 of 2000 complete in 2244.2 sec
#  [-----------------94%---------------   ] 1892 of 2000 complete in 2244.9 sec
#  [-----------------94%---------------   ] 1893 of 2000 complete in 2245.7 sec
#  [-----------------94%----------------  ] 1896 of 2000 complete in 2246.7 sec
#  [-----------------94%----------------  ] 1897 of 2000 complete in 2247.5 sec
#  [-----------------94%----------------  ] 1898 of 2000 complete in 2248.3 sec
#  [-----------------94%----------------  ] 1899 of 2000 complete in 2249.1 sec
#  [-----------------95%----------------  ] 1900 of 2000 complete in 2249.9 sec
#  [-----------------95%----------------  ] 1901 of 2000 complete in 2250.7 sec
#  [-----------------95%----------------  ] 1902 of 2000 complete in 2251.5 sec
#  [-----------------95%----------------  ] 1903 of 2000 complete in 2252.3 sec
#  [-----------------95%----------------  ] 1904 of 2000 complete in 2253.2 sec
#  [-----------------95%----------------  ] 1905 of 2000 complete in 2254.0 sec
#  [-----------------95%----------------  ] 1906 of 2000 complete in 2254.9 sec
#  [-----------------95%----------------  ] 1907 of 2000 complete in 2255.7 sec
#  [-----------------95%----------------  ] 1908 of 2000 complete in 2256.5 sec
#  [-----------------95%----------------  ] 1909 of 2000 complete in 2257.3 sec
#  [-----------------95%----------------  ] 1910 of 2000 complete in 2258.1 sec
#  [-----------------95%----------------  ] 1911 of 2000 complete in 2258.8 sec
#  [-----------------95%----------------  ] 1912 of 2000 complete in 2259.6 sec
#  [-----------------95%----------------  ] 1913 of 2000 complete in 2260.4 sec
#  [-----------------95%----------------  ] 1914 of 2000 complete in 2261.2 sec
#  [-----------------95%----------------  ] 1915 of 2000 complete in 2262.0 sec
#  [-----------------95%----------------  ] 1916 of 2000 complete in 2262.8 sec
#  [-----------------95%----------------  ] 1917 of 2000 complete in 2263.6 sec
#  [-----------------95%----------------  ] 1918 of 2000 complete in 2264.4 sec
#  [-----------------95%----------------  ] 1919 of 2000 complete in 2265.2 sec
#  [-----------------96%----------------  ] 1920 of 2000 complete in 2266.0 sec
#  [-----------------96%----------------  ] 1922 of 2000 complete in 2266.8 sec
#  [-----------------96%----------------  ] 1923 of 2000 complete in 2267.6 sec
#  [-----------------96%----------------  ] 1924 of 2000 complete in 2268.4 sec
#  [-----------------96%----------------  ] 1925 of 2000 complete in 2269.4 sec
#  [-----------------96%----------------  ] 1927 of 2000 complete in 2270.6 sec
#  [-----------------96%----------------  ] 1929 of 2000 complete in 2272.5 sec
#  [-----------------96%----------------  ] 1930 of 2000 complete in 2274.1 sec
#  [-----------------96%----------------  ] 1931 of 2000 complete in 2275.7 sec
#  [-----------------96%----------------  ] 1932 of 2000 complete in 2277.3 sec
#  [-----------------96%----------------  ] 1933 of 2000 complete in 2278.0 sec
#  [-----------------96%----------------  ] 1934 of 2000 complete in 2278.8 sec
#  [-----------------96%----------------  ] 1935 of 2000 complete in 2279.6 sec
#  [-----------------96%----------------  ] 1936 of 2000 complete in 2280.3 sec
#  [-----------------96%----------------  ] 1938 of 2000 complete in 2281.2 sec
#  [-----------------97%----------------  ] 1940 of 2000 complete in 2282.1 sec
#  [-----------------97%----------------  ] 1941 of 2000 complete in 2282.8 sec
#  [-----------------97%----------------  ] 1942 of 2000 complete in 2283.6 sec
#  [-----------------97%----------------  ] 1943 of 2000 complete in 2285.3 sec
#  [-----------------97%----------------  ] 1944 of 2000 complete in 2286.9 sec
#  [-----------------97%----------------  ] 1945 of 2000 complete in 2287.7 sec
#  [-----------------97%----------------  ] 1946 of 2000 complete in 2288.5 sec
#  [-----------------97%----------------  ] 1947 of 2000 complete in 2289.3 sec
#  [-----------------97%----------------- ] 1948 of 2000 complete in 2289.9 sec
#  [-----------------97%----------------- ] 1949 of 2000 complete in 2291.5 sec
#  [-----------------97%----------------- ] 1950 of 2000 complete in 2292.3 sec
#  [-----------------97%----------------- ] 1951 of 2000 complete in 2293.8 sec
#  [-----------------97%----------------- ] 1952 of 2000 complete in 2295.4 sec
#  [-----------------97%----------------- ] 1953 of 2000 complete in 2297.0 sec
#  [-----------------97%----------------- ] 1954 of 2000 complete in 2298.6 sec
#  [-----------------97%----------------- ] 1955 of 2000 complete in 2300.2 sec
#  [-----------------97%----------------- ] 1956 of 2000 complete in 2301.8 sec
#  [-----------------97%----------------- ] 1957 of 2000 complete in 2303.4 sec
#  [-----------------97%----------------- ] 1958 of 2000 complete in 2304.2 sec
#  [-----------------97%----------------- ] 1959 of 2000 complete in 2305.0 sec
#  [-----------------98%----------------- ] 1960 of 2000 complete in 2306.7 sec
#  [-----------------98%----------------- ] 1961 of 2000 complete in 2307.4 sec
#  [-----------------98%----------------- ] 1962 of 2000 complete in 2309.1 sec
#  [-----------------98%----------------- ] 1963 of 2000 complete in 2309.9 sec
#  [-----------------98%----------------- ] 1964 of 2000 complete in 2310.7 sec
#  [-----------------98%----------------- ] 1965 of 2000 complete in 2311.5 sec
#  [-----------------98%----------------- ] 1966 of 2000 complete in 2312.3 sec
#  [-----------------98%----------------- ] 1967 of 2000 complete in 2313.1 sec
#  [-----------------98%----------------- ] 1968 of 2000 complete in 2313.9 sec
#  [-----------------98%----------------- ] 1969 of 2000 complete in 2314.7 sec
#  [-----------------98%----------------- ] 1970 of 2000 complete in 2315.6 sec
#  [-----------------98%----------------- ] 1971 of 2000 complete in 2316.4 sec
#  [-----------------98%----------------- ] 1972 of 2000 complete in 2317.2 sec
#  [-----------------98%----------------- ] 1973 of 2000 complete in 2318.8 sec
#  [-----------------98%----------------- ] 1974 of 2000 complete in 2320.4 sec
#  [-----------------98%----------------- ] 1975 of 2000 complete in 2321.3 sec
#  [-----------------98%----------------- ] 1976 of 2000 complete in 2322.9 sec
#  [-----------------98%----------------- ] 1977 of 2000 complete in 2324.4 sec
#  [-----------------98%----------------- ] 1978 of 2000 complete in 2326.1 sec
#  [-----------------98%----------------- ] 1979 of 2000 complete in 2327.7 sec
#  [-----------------99%----------------- ] 1980 of 2000 complete in 2329.3 sec
#  [-----------------99%----------------- ] 1981 of 2000 complete in 2330.8 sec
#  [-----------------99%----------------- ] 1982 of 2000 complete in 2332.4 sec
#  [-----------------99%----------------- ] 1983 of 2000 complete in 2333.2 sec
#  [-----------------99%----------------- ] 1984 of 2000 complete in 2334.0 sec
#  [-----------------99%----------------- ] 1985 of 2000 complete in 2335.6 sec
#  [-----------------99%----------------- ] 1986 of 2000 complete in 2337.3 sec
#  [-----------------99%----------------- ] 1987 of 2000 complete in 2338.9 sec
#  [-----------------99%----------------- ] 1988 of 2000 complete in 2340.5 sec
#  [-----------------99%----------------- ] 1989 of 2000 complete in 2341.3 sec
#  [-----------------99%----------------- ] 1990 of 2000 complete in 2343.0 sec
#  [-----------------99%----------------- ] 1991 of 2000 complete in 2343.8 sec
#  [-----------------99%----------------- ] 1992 of 2000 complete in 2344.5 sec
#  [-----------------99%----------------- ] 1993 of 2000 complete in 2345.4 sec
#  [-----------------99%----------------- ] 1994 of 2000 complete in 2346.2 sec
#  [-----------------99%----------------- ] 1995 of 2000 complete in 2346.9 sec
#  [-----------------99%----------------- ] 1996 of 2000 complete in 2347.7 sec
#  [-----------------99%----------------- ] 1997 of 2000 complete in 2348.5 sec
#  [-----------------99%----------------- ] 1998 of 2000 complete in 2349.3 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 2350.5 sec
#  [-----------------100%-----------------] 2001 of 2000 complete in 2351.3 sec

# %%
pm.traceplot(hierarchical_trace[500:]);

# %% [markdown]
# The marginal posteriors in the left column are highly informative. `mu_a` tells us the group mean (log) radon levels. `mu_b` tells us that having no basement decreases radon levels significantly (no mass above zero). We can also see by looking at the marginals for `a` that there is quite some differences in radon levels between counties; the different widths are related to how much measurements we have per county, the more, the higher our confidence in that parameter estimate.

# %% [markdown]
# #Posterior Predictive Check
# ##The Root Mean Square Deviation
# To find out which of the models works better we can calculate the Root Mean Square Deviaton (RMSD). This posterior predictive check revolves around recreating the data based on the parameters found at different moments in the chain. The recreated or predicted values are subsequently compared to the real data points, the model that predicts data points closer to the original data is considered the better one. Thus, the lower the RMSD the better.
#
# When computing the RMSD (code not shown) we get the following result:
#
#   * individual/non-hierarchical model: 0.13
#   * hierarchical model: 0.08
#
# As can be seen above the hierarchical model performs a lot better than the non-hierarchical model in predicting the radon values. Following this, we'll plot some examples of county's showing the true radon values, the hierarchial predictions and the non-hierarchical predictions.

# %%
selection = ['CASS', 'CROW WING', 'FREEBORN']
fig, axis = plt.subplots(1, 3, figsize=(12, 6), sharey=True, sharex=True)
axis = axis.ravel()
for i, c in enumerate(selection):
    c_data = data.ix[data.county == c]
    c_data = c_data.reset_index(drop = True)
    z = list(c_data['county_code'])[0]

    xvals = np.linspace(-0.2, 1.2)
    for a_val, b_val in zip(indiv_traces[c]['alpha'][500::10], indiv_traces[c]['beta'][500::10]):
        axis[i].plot(xvals, a_val + b_val * xvals, 'b', alpha=.1)
    axis[i].plot(xvals, indiv_traces[c]['alpha'][500::10].mean() + indiv_traces[c]['beta'][500::10].mean() * xvals, 
                 'b', alpha=1, lw=2., label='individual')
    for a_val, b_val in zip(hierarchical_trace['alpha'][500::10][z], hierarchical_trace['beta'][500::10][z]):
        axis[i].plot(xvals, a_val + b_val * xvals, 'g', alpha=.1)
    axis[i].plot(xvals, hierarchical_trace['alpha'][500::10][z].mean() + hierarchical_trace['beta'][500::10][z].mean() * xvals, 
                 'g', alpha=1, lw=2., label='hierarchical')
    axis[i].scatter(c_data.floor + np.random.randn(len(c_data))*0.01, c_data.log_radon, 
                    alpha=1, color='k', marker='.', s=80, label='original data')
    axis[i].set_xticks([0,1])
    axis[i].set_xticklabels(['basement', 'no basement'])
    axis[i].set_ylim(-1, 4)
    axis[i].set_title(c)
    if not i%3:
        axis[i].legend()
        axis[i].set_ylabel('log radon level')

# %% [markdown]
# In the above plot we have the data points in black of three selected counties. The thick lines represent the mean estimate of the regression line of the individual (blue) and hierarchical model (in green). The thinner lines are regression lines of individual samples from the posterior and give us a sense of how variable the estimates are.
#
# When looking at the county 'CASS' we see that the non-hierarchical estimation is strongly biased: as this county's data contains only households with a basement the estimated regression produces the non-sensical result of a giant negative slope meaning that we would expect negative radon levels in a house without basement!
#
# Moreover, in the example county's 'CROW WING' and 'FREEBORN' the non-hierarchical model appears to react more strongly than the hierarchical model to the existance of outliers in the dataset. Assuming that there should be a higher amount of radon gas measurable in households with basements opposed to those without, the county 'CROW WING''s non-hierachical model seems off. Having the group-distribution constrain the coefficients we get meaningful estimates in all cases as we apply what we learn from the group to the individuals and vice-versa.

# %% [markdown]
# # Shrinkage
# Shrinkage describes the process by which our estimates are "pulled" towards the group-mean as a result of the common group distribution -- county-coefficients very far away from the group mean have very low probability under the normality assumption. In the non-hierachical model every county is allowed to differ completely from the others by just using each county's data, resulting in a model more prone to outliers (as shown above).

# %%
hier_a = hierarchical_trace['alpha'][500:].mean(axis=0)
hier_b = hierarchical_trace['beta'][500:].mean(axis=0)
indv_a = [indiv_traces[c]['alpha'][500:].mean() for c in county_names]
indv_b = [indiv_traces[c]['beta'][500:].mean() for c in county_names]

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, xlabel='Intercept', ylabel='Floor Measure', 
                     title='Hierarchical vs. Non-hierarchical Bayes', 
                     xlim=(0, 3), ylim=(-3, 3))

ax.scatter(indv_a,indv_b, s=26, alpha=0.4, label = 'non-hierarchical')
ax.scatter(hier_a,hier_b, c='red', s=26, alpha=0.4, label = 'hierarchical')
for i in range(len(indv_b)):  
    ax.arrow(indv_a[i], indv_b[i], hier_a[i] - indv_a[i], hier_b[i] - indv_b[i], 
             fc="k", ec="k", length_includes_head=True, alpha=0.4, head_width=.04)
ax.legend();

# %% [markdown]
# In the shrinkage plot above we show the coefficients of each county's non-hierarchical posterior mean (blue) and the hierarchical posterior mean (red). To show the effect of shrinkage on a single coefficient-pair (alpha and beta) we connect the blue and red points belonging to the same county by an arrow. Some non-hierarchical posteriors are so far out that we couldn't display them in this plot (it makes the axes to wide). Interestingly, all hierarchical posteriors of the floor-measure seem to be around -0.6 indicating that having a basement in almost all county's is a clear indicator for heightend radon levels. The intercept (which we take for type of soil) appears to differ among county's. This information would have been difficult to find when just the non-hierarchial model had been used.

# %% [markdown]
# # Summary
#
# In this post, co-authored by Danne Elbers, we showed how a multi-level hierarchical Bayesian model gives the best of both worlds when we have multiple sets of measurements we expect to have similarity. The naive approach either pools all data together and ignores the individual differences, or treats each set as completely separate leading to noisy estimates as shown above. By placing a group distribution on the individual sets we can learn about each set and the group simultaneously. Probabilistic Programming in PyMC then makes Bayesian estimation of this model trivial.
#
#
# ##References
#   * [The Inference Button: Bayesian GLMs made easy with PyMC3](http://twiecki.github.io/blog/2013/08/12/bayesian-glms-1/)
#   * [This world is far from Normal(ly distributed): Bayesian Robust Regression in PyMC3](http://twiecki.github.io/blog/2013/08/27/bayesian-glms-2/)
#   * [Chris Fonnesbeck repo containing a more extensive analysis](https://github.com/fonnesbeck/multilevel_modeling/)
#   * [Shrinkage in multi-level hierarchical models](http://doingbayesiandataanalysis.blogspot.com/2012/11/shrinkage-in-multi-level-hierarchical.html) by John Kruschke
#   * Gelman, A.; Carlin; Stern; and Rubin, D., 2007, "Replication data for: Bayesian Data Analysis, Second Edition",
#   * Gelman, A., & Hill, J. (2006). Data Analysis Using Regression and Multilevel/Hierarchical Models (1st ed.). Cambridge University Press.
#   * Gelman, A. (2006). Multilevel (Hierarchical) modeling: what it can and cannot do. Technometrics, 48(3), 432–435.
