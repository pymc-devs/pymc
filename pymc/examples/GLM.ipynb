# %% [markdown]
# # Bayesian GLMs

# %%
import matplotlib.pyplot as plt
import numpy as np
from pymc import  *
import patsy
import theano
import pandas as pd
from collections import defaultdict
from statsmodels.formula.api import glm as glm_sm
import statsmodels.api as sm

# %%
def glm(formula, data, 
        intercept_prior=None, 
        regressor_prior=None, 
        init=True, init_vals=None, family=None, 
        link_func=None, # TODO: Replace with theano identity
	model=None):
    """Create GLM coefficients.

    Parameters
    ----------
    formula : str
        Patsy linear model descriptor.
    data : array
        Labeled array (e.g. pandas DataFrame, recarray).
    intercept_prior : pymc distribution
        Prior to use for the intercept.
	Default: Normal.dist(mu=0, tau=1.0E-12)
    regressor_prior : pymc distribution
        Prior to use for the regressor(s).
	Default: Normal.dist(mu=0, tau=1.0E-12)
    init : bool
        Whether to set the starting values via statsmodels
        Default: True
    init_vals : dict
        Set starting values externally: parameter -> value
        Default: None
    family : statsmodels.family
        Link function to pass to statsmodels (init has to be True).
	See `statsmodels.api.families`
        Default: identity
    link_func : theano tensor
        Link function to apply to output.
        Default: identity

    Output
    ------
    (y_est, coeffs) : Estimate for y, list of coefficients

    Example
    -------
    # Logistic regression
    y_est, coeffs = glm('male ~ height + weight', 
                        htwt_data, family=sm.families.Binomial(), 
                        link_func=theano.tensor.nnet.sigmoid)
    y_data = Bernoulli('y', y_est, observed=data.male)
    """
    if intercept_prior is None:
        intercept_prior = Normal.dist(mu=0, tau=1.0E-12)
    if regressor_prior is None:
        regressor_prior = Normal.dist(mu=0, tau=1.0E-12)

    # Build patsy design matrix and get regressor names.
    _, dmatrix = patsy.dmatrices(formula, data)
    reg_names = dmatrix.design_info.column_names

    if init_vals is None and init:
        try:
            from statsmodels.formula.api import glm as glm_sm
	except ImportError:
	    raise ImportError("Can't initialize -- statsmodels not found. Set init=False and run find_MAP().")
        init_vals = glm_sm(formula, data, family=family).fit().params
    else:
        init_vals = defaultdict(lambda: None)
    
    # Create individual coefficients
    model = modelcontext(model)
    coeffs = []
    intercept_prior.testval = init_vals['Intercept']
    coeff = model.Var(reg_names[0], intercept_prior)
    coeffs.append(coeff)
    for reg_name in reg_names[1:]:
	regressor_prior.testval = init_vals[reg_name]
        coeff = model.Var(reg_name, regressor_prior)
        coeffs.append(coeff)

    y_est = theano.dot(np.asarray(dmatrix), theano.tensor.stack(*coeffs)).reshape((1, -1))

    if link_func is None:
        return y_est, coeffs
    else:
        return link_func(y_est), coeffs

def plot_posterior_predictive(trace):
    for rand_loc in np.random.randint(0, len(trace), 30):
        rand_sample = trace[rand_loc]
        plt.plot([0, 1], [rand_sample['Intercept'], 
                          rand_sample['Intercept'] + rand_sample['x']], lw=.2, c='k')
    plt.title('Posterior predictive')

# %% [markdown]
# Simple example
# ==============
#
# Lets generate some data with known slope and intercept and fit a simple linear GLM.

# %%
size = 50
true_intercept = 1
true_slope = 2

x = np.linspace(0, 1, size)
y = true_intercept + x*true_slope + np.random.normal(scale=.5, size=size)

# %%
with Model() as model:
    y_est, coeffs = glm('y ~ x', {'x': x, 'y': y})
    sigma = Uniform('sigma', 0, 20)
    y_data = Normal('y', mu=y_est, sd=sigma, observed=y)
    start = find_MAP(vars=[sigma])
    step = Slice(model.vars)
    trace = sample(2000, step, start)

plt.figure(figsize=(5, 5))
plt.plot(x, y, 'x')
plot_posterior_predictive(trace)
# Out:
#  [--------         23%                  ] 471 of 2000 complete in 0.5 sec
#  [-----------------46%                  ] 927 of 2000 complete in 1.0 sec
#  [-----------------69%------            ] 1387 of 2000 complete in 1.5 sec
#  [-----------------91%--------------    ] 1835 of 2000 complete in 2.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 2.2 sec

# %% [markdown]
# Robust GLM
# ==========
#
# Lets try the same model but with a few outliers in the data.

# %%
x_out = np.append(x, [.1, .15, .2])
y_out = np.append(y, [8, 6, 9])
with Model() as model:
    y_est, coeffs = glm('y ~ x', {'x': x_out, 'y': y_out})
    sigma = Uniform('sigma', 0, 20)
    y_data = Normal('y', mu=y_est, sd=sigma, observed=y_out)
    start = find_MAP(vars=[sigma])
    step = Slice(model.vars)
    trace = sample(2000, step, start)

plt.figure(figsize=(5, 5))
plt.plot(x_out, y_out, 'x')
plot_posterior_predictive(trace)
# Out:
#  [-----------      30%                  ] 619 of 2000 complete in 0.5 sec
#  [-----------------60%--                ] 1204 of 2000 complete in 1.0 sec
#  [-----------------89%--------------    ] 1791 of 2000 complete in 1.5 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 1.7 sec

# %% [markdown]
# Because the normal distribution does not have a lot of mass in the tails, an outlier will affect the fit strongly.
#
# Instead, we can use the student T distribution which has heavier tails and is more robust towards outliers. As the gradient of the T distribution is very slow to compute we use Slice sampling instead of NUTS here.

# %%
with Model() as model_robust:
    y_est, coeffs = glm('y ~ x', {'x': x, 'y': y})
    sigma = Uniform('sigma', 0, 20)
    y_data = T('y', mu=y_est, lam=sigma**-2, nu=1, observed=y)
    start = find_MAP(vars=[sigma])
    step = Slice(model_robust.vars)
    trace = sample(2000, step, start)

plt.figure(figsize=(5, 5))
plt.plot(x_out, y_out, 'x')
plot_posterior_predictive(trace)
# Out:
#  [---------        24%                  ] 489 of 2000 complete in 0.5 sec
#  [-----------------47%                  ] 944 of 2000 complete in 1.0 sec
#  [-----------------70%------            ] 1404 of 2000 complete in 1.5 sec
#  [-----------------93%---------------   ] 1878 of 2000 complete in 2.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 2.1 sec

# %% [markdown]
# # Hierarchical GLM

# %%
sat_data = pd.read_csv('Guber1999data.txt')

# %%
with Model() as model_sat:
    grp_mean = Normal('grp_mean', mu=0, sd=10)
    grp_sd = Uniform('grp_sd', 0, 200) 

    # Define priors for intercept and slope
    intercept = Normal.dist(mu=sat_data.sat_t.mean(), sd=sat_data.sat_t.std())
    slope = Normal.dist(mu=grp_mean, sd=grp_sd)

    y_est, coeffs = glm('sat_t ~ spend + stu_tea_rat + salary + prcnt_take', 
                        sat_data,
    	                intercept_prior=intercept, 
                        regressor_prior=slope)
    
    sigma = Uniform('sigma', 0, 100)
    y_data = Normal('y', mu=y_est, sd=sigma, 
                    observed=sat_data.sat_t)
    start = find_MAP(vars=[grp_mean, grp_sd, sigma])
    step = NUTS(model_sat.vars, start)
    trace_sat = sample(2000, step, start)
# Out:
#  [                  0%                  ] 8 of 2000 complete in 0.5 sec
#  [                  0%                  ] 14 of 2000 complete in 1.0 sec
#  [                  1%                  ] 20 of 2000 complete in 1.6 sec
#  [                  1%                  ] 29 of 2000 complete in 2.1 sec
#  [                  2%                  ] 44 of 2000 complete in 2.6 sec
#  [-                 2%                  ] 55 of 2000 complete in 3.2 sec
#  [-                 3%                  ] 64 of 2000 complete in 3.7 sec
#  [-                 3%                  ] 76 of 2000 complete in 4.2 sec
#  [-                 5%                  ] 100 of 2000 complete in 4.8 sec
#  [--                5%                  ] 112 of 2000 complete in 5.3 sec
#  [--                5%                  ] 119 of 2000 complete in 5.9 sec
#  [--                6%                  ] 129 of 2000 complete in 6.4 sec
#  [--                7%                  ] 148 of 2000 complete in 7.0 sec
#  [---               8%                  ] 162 of 2000 complete in 7.6 sec
#  [---               8%                  ] 177 of 2000 complete in 8.1 sec
#  [---               9%                  ] 197 of 2000 complete in 8.6 sec
#  [----             10%                  ] 213 of 2000 complete in 9.1 sec
#  [----             11%                  ] 224 of 2000 complete in 9.7 sec
#  [----             11%                  ] 236 of 2000 complete in 10.3 sec
#  [----             12%                  ] 249 of 2000 complete in 10.9 sec
#  [-----            13%                  ] 264 of 2000 complete in 11.4 sec
#  [-----            14%                  ] 282 of 2000 complete in 11.9 sec
#  [-----            14%                  ] 294 of 2000 complete in 12.5 sec
#  [-----            15%                  ] 306 of 2000 complete in 13.0 sec
#  [------           16%                  ] 323 of 2000 complete in 13.5 sec
#  [------           16%                  ] 338 of 2000 complete in 14.0 sec
#  [------           17%                  ] 352 of 2000 complete in 14.5 sec
#  [------           18%                  ] 362 of 2000 complete in 15.1 sec
#  [-------          19%                  ] 380 of 2000 complete in 15.6 sec
#  [-------          19%                  ] 393 of 2000 complete in 16.2 sec
#  [-------          20%                  ] 408 of 2000 complete in 16.7 sec
#  [-------          20%                  ] 419 of 2000 complete in 17.2 sec
#  [--------         21%                  ] 433 of 2000 complete in 17.8 sec
#  [--------         22%                  ] 448 of 2000 complete in 18.3 sec
#  [--------         23%                  ] 467 of 2000 complete in 18.8 sec
#  [---------        24%                  ] 482 of 2000 complete in 19.3 sec
#  [---------        24%                  ] 499 of 2000 complete in 19.9 sec
#  [---------        25%                  ] 511 of 2000 complete in 20.4 sec
#  [----------       26%                  ] 532 of 2000 complete in 21.0 sec
#  [----------       27%                  ] 549 of 2000 complete in 21.5 sec
#  [----------       28%                  ] 565 of 2000 complete in 22.0 sec
#  [----------       28%                  ] 574 of 2000 complete in 22.5 sec
#  [-----------      29%                  ] 589 of 2000 complete in 23.0 sec
#  [-----------      30%                  ] 614 of 2000 complete in 23.7 sec
#  [------------     31%                  ] 633 of 2000 complete in 24.2 sec
#  [------------     32%                  ] 651 of 2000 complete in 24.7 sec
#  [------------     33%                  ] 666 of 2000 complete in 25.2 sec
#  [------------     34%                  ] 682 of 2000 complete in 25.7 sec
#  [-------------    34%                  ] 697 of 2000 complete in 26.3 sec
#  [-----------------72%-------           ] 1451 of 2000 complete in 51.9 sec
#  [-----------------73%-------           ] 1467 of 2000 complete in 52.4 sec
#  [-----------------73%--------          ] 1479 of 2000 complete in 52.9 sec
#  [-----------------75%--------          ] 1503 of 2000 complete in 53.5 sec
#  [-----------------76%--------          ] 1526 of 2000 complete in 54.0 sec
#  [-----------------77%---------         ] 1545 of 2000 complete in 54.5 sec
#  [-----------------78%---------         ] 1562 of 2000 complete in 55.0 sec
#  [-----------------78%---------         ] 1574 of 2000 complete in 55.5 sec
#  [-----------------79%----------        ] 1595 of 2000 complete in 56.1 sec
#  [-----------------80%----------        ] 1612 of 2000 complete in 56.6 sec
#  [-----------------81%-----------       ] 1634 of 2000 complete in 57.1 sec
#  [-----------------82%-----------       ] 1652 of 2000 complete in 57.6 sec
#  [-----------------83%-----------       ] 1669 of 2000 complete in 58.2 sec
#  [-----------------84%-----------       ] 1682 of 2000 complete in 58.7 sec
#  [-----------------84%------------      ] 1697 of 2000 complete in 59.3 sec
#  [-----------------85%------------      ] 1711 of 2000 complete in 59.8 sec
#  [-----------------86%------------      ] 1735 of 2000 complete in 60.3 sec
#  [-----------------87%-------------     ] 1746 of 2000 complete in 60.8 sec
#  [-----------------88%-------------     ] 1763 of 2000 complete in 61.3 sec
#  [-----------------88%-------------     ] 1777 of 2000 complete in 61.9 sec
#  [-----------------89%--------------    ] 1793 of 2000 complete in 62.5 sec
#  [-----------------90%--------------    ] 1808 of 2000 complete in 63.0 sec
#  [-----------------91%--------------    ] 1822 of 2000 complete in 63.5 sec
#  [-----------------91%--------------    ] 1837 of 2000 complete in 64.0 sec
#  [-----------------92%---------------   ] 1850 of 2000 complete in 64.5 sec
#  [-----------------93%---------------   ] 1862 of 2000 complete in 65.0 sec
#  [-----------------94%---------------   ] 1882 of 2000 complete in 65.5 sec
#  [-----------------94%---------------   ] 1892 of 2000 complete in 66.1 sec
#  [-----------------95%----------------  ] 1909 of 2000 complete in 66.6 sec
#  [-----------------96%----------------  ] 1924 of 2000 complete in 67.2 sec
#  [-----------------97%----------------  ] 1945 of 2000 complete in 67.7 sec
#  [-----------------98%----------------- ] 1964 of 2000 complete in 68.2 sec
#  [-----------------98%----------------- ] 1979 of 2000 complete in 68.8 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 69.3 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 69.3 sec

# %%
plt.figsize(10, 10)
traceplot(trace_sat);

# %%
from pandas.tools.plotting import scatter_matrix
trace_df = pd.DataFrame({name: trace.vals[0] for name, trace in trace_sat.samples.iteritems()})
scatter_matrix(trace_df, figsize=(12,12));

# %%
tdf_gain = 5.
with Model() as model_sat:
    grp_mean = Normal('grp_mean', mu=0, sd=10)
    grp_prec = Gamma('grp_prec', alpha=1, beta=.1, testval=1.)
    #grp_sd = Uniform('grp_sd', 0, 100, testval=5)
    grp_df_raw = Uniform('grp_df', 0, 1, testval=0.5)
    grp_df = 1 - tdf_gain * theano.tensor.log((1-grp_df_raw))
    slope = T.dist(mu=grp_mean, lam=grp_prec, nu=grp_df)
    intercept = Normal.dist(mu=sat_data.sat_t.mean(), sd=sat_data.sat_t.std())
    y_est, coeffs = glm('sat_t ~ spend + stu_tea_rat + salary + prcnt_take', sat_data,
                        intercept_prior=intercept, regressor_prior=slope)
    
    sigma = Uniform('sigma', 0, 100)
    y_data = Normal('y', mu=y_est, sd=sigma, observed=sat_data.sat_t)
    start = find_MAP(vars=[grp_mean, grp_prec, sigma])
    print start
    step = NUTS([grp_mean, grp_prec, sigma] + coeffs, start)
    step2 = Slice([grp_df_raw])
    trace_sat = sample(2000, [step, step2], start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-3cf0958d1b7f> in <module>()
#      17     step = NUTS([grp_mean, grp_prec, sigma] + coeffs, start)
#      18     step2 = Slice([grp_df_raw])
# ---> 19     trace_sat = sample(2000, [step, step2], start)
#
# /home/whyking/tools/pymc/pymc/pymc/sample.pyc in sample(draws, step, start, trace, progressbar, model, random_seed)
#      67
#      68     for i in xrange(draws):
# ---> 69         point = step.step(point)
#      70         trace = trace.record(point)
#      71         if progressbar:
#
# /home/whyking/tools/pymc/pymc/pymc/step_methods/compound.pyc in step(point)
#      13     def step(point):
#      14         for method in methods:
# ---> 15             point = method.step(point)
#      16         return point
#      17     return locals()
#
# /home/whyking/tools/pymc/pymc/pymc/step_methods/arraystep.pyc in step(self, point)
#      22             inputs += [point]
#      23
# ---> 24         apoint = self.astep(bij.map(point), *inputs)
#      25         return bij.rmap(apoint)
#      26
#
# /home/whyking/tools/pymc/pymc/pymc/step_methods/nuts.pyc in astep(self, q0, logp, dlogp)
#     103
#     104             if v == -1:
# --> 105                 qn,pn,_,_, q1,n1,s1,a,na = buildtree(H, qn,pn,u, v,j,e, Emax, q0, p0)
#     106             else:
#     107                 _,_,qp,pp, q1,n1,s1,a,na = buildtree(H, qp,pp,u, v,j,e, Emax, q0, p0)
#
# /home/whyking/tools/pymc/pymc/pymc/step_methods/nuts.pyc in buildtree(H, q, p, u, v, j, e, Emax, q0, p0)
#     130 def buildtree(H, q, p, u, v, j,e, Emax, q0, p0):
#     131     if j == 0:
# --> 132         q1, p1 = leapfrog(H, q, p, 1, v*e)
#     133         E = energy(H, q1,p1)
#     134         E0 = energy(H, q0,p0)
#
# /home/whyking/tools/pymc/pymc/pymc/step_methods/hmc.pyc in leapfrog(H, q, p, n, e)
#      92     _, dlogp, pot = H
#      93
# ---> 94     p = p - (e/2) * -dlogp(q) # half momentum update
#      95
#      96     for i in range(n):
#
# ValueError: operands could not be broadcast together with shapes (9) (8)
# {'salary': array(1.6379171742714003), 'grp_mean': array(-0.27471331694807516), 'sigma': array(31.0238282316056), 'spend': array(4.4625941754929155), 'grp_prec': array(0.0970719778269859), 'Intercept': array(1045.9715355315898), 'grp_df': array(0.5), 'prcnt_take': array(-2.904480507097369), 'stu_tea_rat': array(-3.6242322678594405)}

# %% [markdown]
# # Logistic Regression

# %%
htwt_data = pd.read_csv('HtWt.csv').drop('Unnamed: 0', axis=1)
htwt_data.head()
# Out:
#    male  height  weight
# 0     0    63.2   168.7
# 1     0    68.7   169.8
# 2     0    64.8   176.6
# 3     0    67.9   246.8
# 4     1    68.9   151.6

# %%
m = glm_sm('male ~ height + weight', htwt_data, family=sm.families.Binomial()).fit()
print m.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   male   No. Observations:                   70
# Model:                            GLM   Df Residuals:                       67
# Model Family:                Binomial   Df Model:                            2
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -28.298
# Date:                Mon, 10 Jun 2013   Deviance:                       56.597
# Time:                        10:27:24   Pearson chi2:                     62.8
# No. Iterations:                     7
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -45.2059     10.887     -4.152      0.000       -66.545   -23.867
# height         0.6571      0.164      4.018      0.000         0.337     0.978
# weight         0.0096      0.011      0.892      0.376        -0.012     0.031
# ==============================================================================

# %%
with Model() as model_htwt:
    y_est, coeffs = glm('male ~ height + weight', htwt_data, family=sm.families.Binomial(), link_func=theano.tensor.nnet.sigmoid)
    y_data = Bernoulli('y', y_est, observed=htwt_data.male)
    step = NUTS(model_htwt.vars, model_htwt.test_point)
    trace_htwt = sample(5000, step, model_htwt.test_point)
# Out:
#  [                  0%                  ] 10 of 5000 complete in 0.5 sec
#  [                  0%                  ] 20 of 5000 complete in 1.0 sec
#  [                  0%                  ] 33 of 5000 complete in 1.6 sec
#  [                  1%                  ] 61 of 5000 complete in 2.1 sec
#  [                  1%                  ] 78 of 5000 complete in 2.8 sec
#  [                  1%                  ] 88 of 5000 complete in 3.3 sec
#  [                  2%                  ] 108 of 5000 complete in 3.8 sec
#  [-                 2%                  ] 138 of 5000 complete in 4.3 sec
#  [-                 3%                  ] 159 of 5000 complete in 4.8 sec
#  [-                 3%                  ] 185 of 5000 complete in 5.5 sec
#  [-                 4%                  ] 202 of 5000 complete in 6.0 sec
#  [-                 4%                  ] 221 of 5000 complete in 6.6 sec
#  [-                 4%                  ] 234 of 5000 complete in 7.2 sec
#  [--                5%                  ] 265 of 5000 complete in 7.8 sec
#  [--                5%                  ] 288 of 5000 complete in 8.3 sec
#  [--                6%                  ] 310 of 5000 complete in 8.8 sec
#  [--                6%                  ] 323 of 5000 complete in 9.3 sec
#  [--                6%                  ] 341 of 5000 complete in 9.8 sec
#  [--                7%                  ] 361 of 5000 complete in 10.3 sec
#  [--                7%                  ] 388 of 5000 complete in 10.9 sec
#  [---               8%                  ] 415 of 5000 complete in 11.4 sec
#  [---               9%                  ] 452 of 5000 complete in 11.9 sec
#  [---               9%                  ] 468 of 5000 complete in 12.4 sec
#  [---              10%                  ] 502 of 5000 complete in 13.0 sec
#  [---              10%                  ] 522 of 5000 complete in 13.5 sec
#  [----             10%                  ] 544 of 5000 complete in 14.1 sec
#  [----             11%                  ] 561 of 5000 complete in 14.6 sec
#  [----             11%                  ] 589 of 5000 complete in 15.2 sec
#  [----             12%                  ] 612 of 5000 complete in 15.7 sec
#  [----             12%                  ] 631 of 5000 complete in 16.2 sec
#  [-----            13%                  ] 661 of 5000 complete in 16.7 sec
#  [-----            13%                  ] 682 of 5000 complete in 17.2 sec
#  [-----            14%                  ] 712 of 5000 complete in 17.7 sec
#  [-----            14%                  ] 734 of 5000 complete in 18.3 sec
#  [-----            15%                  ] 762 of 5000 complete in 18.8 sec
#  [-----            15%                  ] 775 of 5000 complete in 19.3 sec
#  [-----------------61%---               ] 3063 of 5000 complete in 70.1 sec
#  [-----------------61%---               ] 3088 of 5000 complete in 70.6 sec
#  [-----------------62%---               ] 3111 of 5000 complete in 71.1 sec
#  [-----------------62%---               ] 3133 of 5000 complete in 71.6 sec
#  [-----------------63%----              ] 3161 of 5000 complete in 72.1 sec
#  [-----------------63%----              ] 3188 of 5000 complete in 72.6 sec
#  [-----------------64%----              ] 3210 of 5000 complete in 73.2 sec
#  [-----------------64%----              ] 3231 of 5000 complete in 73.7 sec
#  [-----------------65%----              ] 3258 of 5000 complete in 74.2 sec
#  [-----------------65%----              ] 3273 of 5000 complete in 74.7 sec
#  [-----------------65%-----             ] 3297 of 5000 complete in 75.2 sec
#  [-----------------66%-----             ] 3318 of 5000 complete in 75.8 sec
#  [-----------------67%-----             ] 3350 of 5000 complete in 76.3 sec
#  [-----------------67%-----             ] 3368 of 5000 complete in 76.8 sec
#  [-----------------67%-----             ] 3391 of 5000 complete in 77.4 sec
#  [-----------------68%-----             ] 3421 of 5000 complete in 77.9 sec
#  [-----------------68%------            ] 3443 of 5000 complete in 78.4 sec
#  [-----------------69%------            ] 3461 of 5000 complete in 78.9 sec
#  [-----------------69%------            ] 3486 of 5000 complete in 79.5 sec
#  [-----------------70%------            ] 3504 of 5000 complete in 80.0 sec
#  [-----------------70%------            ] 3531 of 5000 complete in 80.6 sec
#  [-----------------71%-------           ] 3558 of 5000 complete in 81.1 sec
#  [-----------------71%-------           ] 3576 of 5000 complete in 81.6 sec
#  [-----------------72%-------           ] 3601 of 5000 complete in 82.1 sec
#  [-----------------72%-------           ] 3624 of 5000 complete in 82.7 sec
#  [-----------------73%-------           ] 3651 of 5000 complete in 83.2 sec
#  [-----------------73%-------           ] 3671 of 5000 complete in 83.7 sec
#  [-----------------73%-------           ] 3684 of 5000 complete in 84.2 sec
#  [-----------------74%--------          ] 3707 of 5000 complete in 84.7 sec
#  [-----------------74%--------          ] 3723 of 5000 complete in 85.3 sec
#  [-----------------74%--------          ] 3748 of 5000 complete in 85.8 sec
#  [-----------------75%--------          ] 3769 of 5000 complete in 86.3 sec
#  [-----------------75%--------          ] 3795 of 5000 complete in 86.8 sec
#  [-----------------76%--------          ] 3813 of 5000 complete in 87.4 sec
#  [-----------------76%---------         ] 3837 of 5000 complete in 87.9 sec
#  [-----------------77%---------         ] 3855 of 5000 complete in 88.4 sec
#  [-----------------77%---------         ] 3876 of 5000 complete in 88.9 sec
#  [-----------------78%---------         ] 3905 of 5000 complete in 89.5 sec
#  [-----------------78%---------         ] 3933 of 5000 complete in 90.0 sec
#  [-----------------79%----------        ] 3954 of 5000 complete in 90.5 sec
#  [-----------------79%----------        ] 3968 of 5000 complete in 91.0 sec
#  [-----------------79%----------        ] 3993 of 5000 complete in 91.5 sec
#  [-----------------80%----------        ] 4025 of 5000 complete in 92.1 sec
#  [-----------------80%----------        ] 4039 of 5000 complete in 92.6 sec
#  [-----------------81%----------        ] 4064 of 5000 complete in 93.1 sec
#  [-----------------81%-----------       ] 4087 of 5000 complete in 93.6 sec
#  [-----------------82%-----------       ] 4112 of 5000 complete in 94.1 sec
#  [-----------------82%-----------       ] 4137 of 5000 complete in 94.7 sec
#  [-----------------83%-----------       ] 4162 of 5000 complete in 95.2 sec
#  [-----------------83%-----------       ] 4176 of 5000 complete in 95.7 sec
#  [-----------------84%-----------       ] 4202 of 5000 complete in 96.3 sec
#  [-----------------84%------------      ] 4225 of 5000 complete in 96.8 sec
#  [-----------------84%------------      ] 4238 of 5000 complete in 97.3 sec
#  [-----------------85%------------      ] 4258 of 5000 complete in 97.8 sec
#  [-----------------85%------------      ] 4276 of 5000 complete in 98.4 sec
#  [-----------------86%------------      ] 4300 of 5000 complete in 98.9 sec
#  [-----------------86%------------      ] 4329 of 5000 complete in 99.4 sec
#  [-----------------87%-------------     ] 4352 of 5000 complete in 100.0 sec
#  [-----------------87%-------------     ] 4375 of 5000 complete in 100.5 sec
#  [-----------------87%-------------     ] 4394 of 5000 complete in 101.0 sec
#  [-----------------88%-------------     ] 4417 of 5000 complete in 101.5 sec
#  [-----------------88%-------------     ] 4443 of 5000 complete in 102.1 sec
#  [-----------------89%-------------     ] 4465 of 5000 complete in 102.6 sec
#  [-----------------89%--------------    ] 4487 of 5000 complete in 103.2 sec
#  [-----------------90%--------------    ] 4507 of 5000 complete in 103.7 sec
#  [-----------------90%--------------    ] 4531 of 5000 complete in 104.2 sec
#  [-----------------91%--------------    ] 4560 of 5000 complete in 104.7 sec
#  [-----------------91%--------------    ] 4582 of 5000 complete in 105.2 sec
#  [-----------------92%---------------   ] 4607 of 5000 complete in 105.8 sec
#  [-----------------92%---------------   ] 4629 of 5000 complete in 106.3 sec
#  [-----------------93%---------------   ] 4652 of 5000 complete in 106.8 sec
#  [-----------------93%---------------   ] 4674 of 5000 complete in 107.3 sec
#  [-----------------93%---------------   ] 4696 of 5000 complete in 107.9 sec
#  [-----------------94%---------------   ] 4732 of 5000 complete in 108.4 sec
#  [-----------------94%----------------  ] 4748 of 5000 complete in 109.0 sec
#  [-----------------95%----------------  ] 4776 of 5000 complete in 109.5 sec
#  [-----------------95%----------------  ] 4795 of 5000 complete in 110.0 sec
#  [-----------------96%----------------  ] 4821 of 5000 complete in 110.5 sec
#  [-----------------96%----------------  ] 4848 of 5000 complete in 111.0 sec
#  [-----------------97%----------------- ] 4869 of 5000 complete in 111.6 sec
#  [-----------------97%----------------- ] 4890 of 5000 complete in 112.1 sec
#  [-----------------98%----------------- ] 4910 of 5000 complete in 112.7 sec
#  [-----------------98%----------------- ] 4927 of 5000 complete in 113.2 sec
#  [-----------------99%----------------- ] 4955 of 5000 complete in 113.7 sec
#  [-----------------99%----------------- ] 4977 of 5000 complete in 114.2 sec
#  [-----------------100%-----------------] 5000 of 5000 complete in 114.7 sec
#  [-----------------100%-----------------] 5000 of 5000 complete in 114.7 sec

# %%
trace_df = pd.DataFrame({name: np.asarray(trace.vals)[:,0] for name, trace in trace_htwt.samples.iteritems()})
scatter_matrix(trace_df, figsize=(8, 8));
print "P(weight < 0) = ", (trace_df['weight'] < 0).mean()
# Out:
# P(weight < 0) =  0.171
