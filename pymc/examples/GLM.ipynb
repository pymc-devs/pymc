# %% [markdown]
# # Bayesian GLMs

# %%
import matplotlib.pyplot as plt
import numpy as np
from pymc import  *
import patsy
import theano
import pandas as pd
from collections import defaultdict
from statsmodels.formula.api import glm as glm_sm
import statsmodels.api as sm
from pandas.tools.plotting import scatter_matrix

# %%
def linear_component(formula, data, 
                     intercept_prior=None, 
                     regressor_prior=None, 
                     init=True, init_vals=None, family=None, 
                     model=None):
    """Create GLM coefficients.

    Parameters
    ----------
    formula : str
        Patsy linear model descriptor.
    data : array
        Labeled array (e.g. pandas DataFrame, recarray).
    intercept_prior : pymc distribution
        Prior to use for the intercept.
	Default: Normal.dist(mu=0, tau=1.0E-12)
    regressor_prior : pymc distribution
        Prior to use for the regressor(s).
	Default: Normal.dist(mu=0, tau=1.0E-12)
    init : bool
        Whether to set the starting values via statsmodels
        Default: True
    init_vals : dict
        Set starting values externally: parameter -> value
        Default: None
    family : statsmodels.family
        Link function to pass to statsmodels (init has to be True).
	See `statsmodels.api.families`
        Default: identity

    Output
    ------
    (y_est, coeffs) : Estimate for y, list of coefficients

    Example
    -------
    # Logistic regression
    y_est, coeffs = glm('male ~ height + weight', 
                        htwt_data, family=sm.families.Binomial(), 
                        link_func=theano.tensor.nnet.sigmoid)
    y_data = Bernoulli('y', y_est, observed=data.male)
    """
    if intercept_prior is None:
        intercept_prior = Normal.dist(mu=0, tau=1.0E-12)
    if regressor_prior is None:
        regressor_prior = Normal.dist(mu=0, tau=1.0E-12)

    # Build patsy design matrix and get regressor names.
    _, dmatrix = patsy.dmatrices(formula, data)
    reg_names = dmatrix.design_info.column_names

    if init_vals is None and init:
        try:
            from statsmodels.formula.api import glm as glm_sm
	except ImportError:
	    raise ImportError("Can't initialize -- statsmodels not found. Set init=False and run find_MAP().")
        init_vals = glm_sm(formula, data, family=family).fit().params
    else:
        init_vals = defaultdict(lambda: None)

    # Create individual coefficients
    model = modelcontext(model)
    coeffs = []
    intercept_prior.testval = init_vals['Intercept']
    coeff = model.Var(reg_names[0], intercept_prior)
    coeffs.append(coeff)
    for reg_name in reg_names[1:]:
	regressor_prior.testval = init_vals[reg_name]
        coeff = model.Var(reg_name, regressor_prior)
        coeffs.append(coeff)

    y_est = theano.dot(np.asarray(dmatrix), theano.tensor.stack(*coeffs)).reshape((1, -1))

    return y_est, coeffs

class LinkFunction(object):
    def __init__(self, theano_link=None, sm_link=None):
	if theano_link is not None:
            self.theano = theano_link
	if sm_link is not None:
	    self.sm = sm_link

class Identity(LinkFunction):
    theano = lambda self, x: x
    sm = sm.families.links.identity

class Logit(LinkFunction):
    theano = theano.tensor.nnet.sigmoid
    sm = sm.families.links.logit


class Family(object):
    def __init__(self, link=None, sm_family=None, likelihood_dist=None):
        if link is not None:
	    self.link = link
	if sm_family is not None:
	    self.sm_family_cls = sm_family
	if likelihood_dist is not None:
	    self.likelihood_dist = likelihood_dist
	
    def likelihood(self, y_est, y_data, model=None):
	return self.likelihood_dist('y', self.link.theano(y_est), observed=y_data)

    def sm_family(self):
	return self.sm_family(self.link.sm())
    
class NormalFamily(Family):
    sm_family = sm.families.Gaussian
    link = Identity()
    
    def likelihood(self, y_est, y_data, model=None):
	sigma = Uniform('sigma', 0, 100)
	y_obs = Normal('y', mu=self.link.theano(y_est), sd=sigma, observed=y_data)
	return y_obs

class TFamily(Family):
    sm_family = sm.families.Gaussian
    link = Identity()

    def likelihood(self, y_est, y_data, model=None):
	sigma = Uniform('sigma', 0, 100)
	y_obs = T('y', mu=self.link.theano(y_est), lam=sigma**-2, nu=1, observed=y_data)
	return y_obs

class BinomialFamily(Family):
    link = Logit()
    sm_family = sm.families.Binomial
    likelihood_dist = Bernoulli

# link_func -> (theano_link, sm_link)
link_funcs = {
   'identity': (lambda x: x, sm.families.links.identity),
   'logit': (theano.tensor.nnet.sigmoid, sm.families.links.logit),
   'inverse_power': (theano.tensor.inv, sm.families.links.inverse_power),
   'log': (theano.tensor.log, sm.families.links.log)
}

def glm(*args, **kwargs):
    family = kwargs.pop('family', NormalFamily())
    
    formula = args[0]
    data = args[1]
    y_data = np.asarray(patsy.dmatrices(formula, data)[0]).T
    model = modelcontext(kwargs.get('model'))

    kwargs['family'] = family.sm_family()
    y_est, coeffs = linear_component(*args, **kwargs)
    family.likelihood(y_est, y_data)
    
    non_init_vars = set(model.vars).difference(set(coeffs))
    start = find_MAP(vars=non_init_vars)
    return start

def trace_to_dataframe(trace):
    return pd.DataFrame({name: np.squeeze(trace.vals)
			 for name, trace in trace_sat.samples.iteritems()})

def plot_posterior_predictive(trace):
    for rand_loc in np.random.randint(0, len(trace), 30):
        rand_sample = trace[rand_loc]
        plt.plot([0, 1], [rand_sample['Intercept'], 
                          rand_sample['Intercept'] + rand_sample['x']], lw=.2, c='k')
    plt.title('Posterior predictive')

# %% [markdown]
# Simple example
# ==============
#
# Lets generate some data with known slope and intercept and fit a simple linear GLM.

# %%
size = 50
true_intercept = 1
true_slope = 2

x = np.linspace(0, 1, size)
y = true_intercept + x*true_slope + np.random.normal(scale=.5, size=size)

# %%
with Model() as model:
    start = glm('y ~ x', dict(x=x, y=y))
    step = Slice(model.vars)
    trace = sample(2000, step, start)

plt.figure(figsize=(5, 5))
plt.plot(x, y, 'x')
plot_posterior_predictive(trace)
# Out:
#  [---------        23%                  ] 474 of 2000 complete in 0.5 sec
#  [-----------------47%                  ] 955 of 2000 complete in 1.0 sec
#  [-----------------72%-------           ] 1448 of 2000 complete in 1.5 sec
#  [-----------------96%----------------  ] 1935 of 2000 complete in 2.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 2.1 sec

# %% [markdown]
# Robust GLM
# ==========
#
# Lets try the same model but with a few outliers in the data.

# %%
x_out = np.append(x, [.1, .15, .2])
y_out = np.append(y, [8, 6, 9])
with Model() as model:
    start = glm('y ~ x', dict(x=x_out, y=y_out))
    step = Slice(model.vars)
    trace = sample(2000, step, start)

plt.figure(figsize=(5, 5))
plt.plot(x_out, y_out, 'x')
plot_posterior_predictive(trace)
# Out:
#  [-----------      31%                  ] 630 of 2000 complete in 0.5 sec
#  [-----------------62%---               ] 1247 of 2000 complete in 1.0 sec
#  [-----------------94%----------------  ] 1898 of 2000 complete in 1.5 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 1.6 sec

# %% [markdown]
# Because the normal distribution does not have a lot of mass in the tails, an outlier will affect the fit strongly.
#
# Instead, we can use the student T distribution which has heavier tails and is more robust towards outliers. As the gradient of the T distribution is very slow to compute we use Slice sampling instead of NUTS here.

# %%
with Model() as model_robust:
    start = glm('y ~ x', dict(x=x_out, y=y_out), family=TFamily())
    step = Slice(model_robust.vars)
    trace = sample(2000, step, start)

plt.figure(figsize=(5, 5))
plt.plot(x_out, y_out, 'x')
plot_posterior_predictive(trace)
# Out:
#  [---------        24%                  ] 483 of 2000 complete in 0.5 sec
#  [-----------------47%                  ] 952 of 2000 complete in 1.0 sec
#  [-----------------71%-------           ] 1434 of 2000 complete in 1.5 sec
#  [-----------------94%---------------   ] 1892 of 2000 complete in 2.0 sec
#  [-----------------100%-----------------] 2000 of 2000 complete in 2.1 sec

# %% [markdown]
# # Hierarchical GLM

# %%
sat_data = pd.read_csv('data/Guber1999data.txt')

# %%
with Model() as model_sat:
    grp_mean = Normal('grp_mean', mu=0, sd=10)
    grp_sd = Uniform('grp_sd', 0, 200)

    # Define priors for intercept and slope
    intercept = Normal.dist(mu=sat_data.sat_t.mean(), sd=sat_data.sat_t.std())
    slope = Normal.dist(mu=grp_mean, sd=grp_sd)

    start = glm('sat_t ~ spend + stu_tea_rat + salary + prcnt_take', 
                sat_data,
    	        intercept_prior=intercept, 
                regressor_prior=slope)
    
    step = NUTS(model_sat.vars, start)
    trace_sat = sample(2000, step, start)
# Out:
#  [                  0%                  ] 9 of 2000 complete in 0.5 sec
#  [                  1%                  ] 21 of 2000 complete in 1.1 sec
#  [                  1%                  ] 30 of 2000 complete in 1.6 sec
#  [                  2%                  ] 42 of 2000 complete in 2.3 sec
#  [-                 2%                  ] 56 of 2000 complete in 2.8 sec
#  [-                 3%                  ] 68 of 2000 complete in 3.4 sec
#  [-                 4%                  ] 82 of 2000 complete in 3.9 sec
#  [-                 4%                  ] 95 of 2000 complete in 4.5 sec
#  [--                5%                  ] 107 of 2000 complete in 5.0 sec
#  [--                5%                  ] 119 of 2000 complete in 5.5 sec
#  [--                6%                  ] 133 of 2000 complete in 6.0 sec
#  [--                7%                  ] 151 of 2000 complete in 6.5 sec
#  [---               8%                  ] 171 of 2000 complete in 7.0 sec
# ...

# %%
plt.figsize(10, 10)
traceplot(trace_sat);

# %%
scatter_matrix(trace_to_dataframe(trace_sat), figsize=(12,12));

# %%
with Model() as model_sat:
    grp_mean = Normal('grp_mean', mu=0, sd=10)
    grp_prec = Gamma('grp_prec', alpha=1, beta=.1, testval=1.)
    slope = T.dist(mu=grp_mean, lam=grp_prec, nu=1)
    intercept = Normal.dist(mu=sat_data.sat_t.mean(), sd=sat_data.sat_t.std())
    start = glm('sat_t ~ spend + stu_tea_rat + salary + prcnt_take', sat_data,
                intercept_prior=intercept, regressor_prior=slope)
    step = NUTS(model_sat.vars, start)
    trace_sat = sample(2000, step, start)
# Out:
# Intercept      1045.971536
# spend             4.462594
# stu_tea_rat      -3.624232
# salary            1.637917
# prcnt_take       -2.904481
# dtype: float64
#  [                  0%                  ] 7 of 2000 complete in 0.8 sec
#  [                  0%                  ] 16 of 2000 complete in 1.3 sec
#  [                  0%                  ] 17 of 2000 complete in 1.8 sec
#  [                  1%                  ] 22 of 2000 complete in 2.4 sec
#  [                  1%                  ] 25 of 2000 complete in 3.0 sec
#  [                  1%                  ] 29 of 2000 complete in 3.6 sec
#  [                  1%                  ] 33 of 2000 complete in 4.4 sec
#  [                  1%                  ] 36 of 2000 complete in 4.9 sec
#  [                  1%                  ] 37 of 2000 complete in 5.7 sec
#  [                  2%                  ] 40 of 2000 complete in 6.2 sec
#  [                  2%                  ] 50 of 2000 complete in 6.8 sec
# ...

# %%
scatter_matrix(trace_to_dataframe(trace_sat), figsize=(12,12));

# %%
tdf_gain = 5.
with Model() as model_sat:
    grp_mean = Normal('grp_mean', mu=0, sd=10)
    grp_prec = Gamma('grp_prec', alpha=1, beta=.1, testval=1.)
    #grp_sd = Uniform('grp_sd', 0, 100, testval=5)
    #grp_df_raw = Uniform('grp_df', 0, 1, testval=0.5)
    #grp_df = 1 - tdf_gain * theano.tensor.log((1-grp_df_raw))
    slope = T.dist(mu=grp_mean, lam=grp_prec, nu=1) #grp_df)
    intercept = Normal.dist(mu=sat_data.sat_t.mean(), sd=sat_data.sat_t.std())
    start = glm('sat_t ~ spend + stu_tea_rat + salary + prcnt_take', sat_data,
                intercept_prior=intercept, regressor_prior=slope)
    print start
    trace_sat = sample(2000, step, start)
    #step = NUTS([grp_mean, grp_prec, sigma] + coeffs, start)
    #step2 = Slice([grp_df_raw])
    #trace_sat = sample(2000, [step, step2], start)
# Out:
# Intercept      1045.971536
# spend             4.462594
# stu_tea_rat      -3.624232
# salary            1.637917
# prcnt_take       -2.904481
# dtype: float64
# {'salary': array(1.6379171742714262), 'grp_mean': array(-1.486596332956722), 'spend': array(4.462594175492855), 'grp_prec': array(0.13433015782234242), 'Intercept': array(1045.9715355315893), 'sigma': array(31.023828503047824), 'prcnt_take': array(-2.904480507097373), 'stu_tea_rat': array(-3.624232267859453)}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-666bc0e2296b> in <module>()
#      11                 intercept_prior=intercept, regressor_prior=slope)
#      12     print start
# ---> 13     trace_sat = sample(2000, step, start)
#      14     #step = NUTS([grp_mean, grp_prec, sigma] + coeffs, start)
#      15     #step2 = Slice([grp_df_raw])
#
# ...

# %% [markdown]
# # Logistic Regression

# %%
htwt_data = pd.read_csv('data/HtWt.csv').drop('Unnamed: 0', axis=1)
htwt_data.head()
# Out:
#    male  height  weight
# 0     0    63.2   168.7
# 1     0    68.7   169.8
# 2     0    64.8   176.6
# 3     0    67.9   246.8
# 4     1    68.9   151.6

# %%
m = glm_sm('male ~ height + weight', htwt_data, family=sm.families.Binomial()).fit()
print m.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   male   No. Observations:                   70
# Model:                            GLM   Df Residuals:                       67
# Model Family:                Binomial   Df Model:                            2
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -28.298
# Date:                Mon, 10 Jun 2013   Deviance:                       56.597
# Time:                        10:27:24   Pearson chi2:                     62.8
# No. Iterations:                     7
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -45.2059     10.887     -4.152      0.000       -66.545   -23.867
# height         0.6571      0.164      4.018      0.000         0.337     0.978
# ...

# %%
with Model() as model_htwt:
    start = glm('male ~ height + weight', htwt_data, family=BinomialFamily())
    step = NUTS(model_htwt.vars, model_htwt.test_point)
    trace_htwt = sample(5000, step, model_htwt.test_point)
# Out:
#  [                  0%                  ] 8 of 5000 complete in 0.7 sec
#  [                  0%                  ] 18 of 5000 complete in 1.3 sec
#  [                  0%                  ] 30 of 5000 complete in 1.8 sec
#  [                  0%                  ] 41 of 5000 complete in 2.4 sec
#  [                  1%                  ] 57 of 5000 complete in 2.9 sec
#  [                  1%                  ] 86 of 5000 complete in 3.4 sec
#  [                  2%                  ] 104 of 5000 complete in 3.9 sec
#  [                  2%                  ] 115 of 5000 complete in 4.5 sec
#  [                  2%                  ] 125 of 5000 complete in 5.0 sec
#  [-                 2%                  ] 143 of 5000 complete in 5.5 sec
#  [-                 3%                  ] 156 of 5000 complete in 6.0 sec
#  [-                 3%                  ] 173 of 5000 complete in 6.6 sec
#  [-                 3%                  ] 194 of 5000 complete in 7.2 sec
# ...

# %%
scatter_matrix(trace_to_dataframe(trace_htwt), figsize=(8, 8));
print "P(weight < 0) = ", (trace_df['weight'] < 0).mean()
