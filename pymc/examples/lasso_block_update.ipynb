# %% [markdown]
# Sometimes, it is very useful to update a set of parameters together. For example, variables that are highly correlated are often good to update together. In PyMC 3 block updating is simple, as example will demonstrate.
#
# Here we have a LASSO regression model where the two coefficients are strongly correlated. Normally, we would define the coefficient parameters as a single random variable, but here we define them separately to show how to do block updates.
#
# First we generate some fake data.

# %%
from matplotlib.pylab import *
from pymc import * 
import numpy as np 

d = np.random.normal(size=(3, 30))
d1 = d[0] + 4
d2 = d[1] + 4
yd = .2*d1 +.3*d2 + d[2]

# %% [markdown]
# Then define the random variables.

# %%
lam = 3

with Model() as model:
    s = Exponential('s', 1)
    tau = Uniform('tau', 0, 1000)
    b = lam * tau
    m1 = Laplace('m1', 0, b)
    m2 = Laplace('m2', 0, b)
    
    p = d1*m1 + d2*m2
    
    y = Normal('y', p, s**-2, observed = yd)

# %% [markdown]
# For most samplers, including Metropolis and HamiltonianMC, simply pass a list of variables to sample as a block. This works with both scalar and array parameters.

# %%
with model: 
    start = find_MAP()
    
    step1 = Metropolis([m1, m2])
    
    step2 = Slice([s, tau])
    
    trace = sample(10000, [step1, step2])
# Out:
#  [--                5%                  ] 549 of 10000 complete in 0.5 sec
#  [----             10%                  ] 1092 of 10000 complete in 1.0 sec
#  [------           16%                  ] 1619 of 10000 complete in 1.5 sec
#  [--------         21%                  ] 2145 of 10000 complete in 2.0 sec
#  [----------       26%                  ] 2686 of 10000 complete in 2.5 sec
#  [------------     32%                  ] 3227 of 10000 complete in 3.0 sec
#  [--------------   37%                  ] 3787 of 10000 complete in 3.5 sec
#  [---------------- 43%                  ] 4337 of 10000 complete in 4.0 sec
#  [-----------------48%                  ] 4864 of 10000 complete in 4.5 sec
#  [-----------------53%                  ] 5398 of 10000 complete in 5.0 sec
#  [-----------------59%--                ] 5950 of 10000 complete in 5.5 sec
#  [-----------------65%----              ] 6510 of 10000 complete in 6.0 sec
#  [-----------------70%------            ] 7063 of 10000 complete in 6.5 sec
#  [-----------------76%--------          ] 7608 of 10000 complete in 7.0 sec
#  [-----------------81%-----------       ] 8176 of 10000 complete in 7.5 sec
#  [-----------------87%-------------     ] 8711 of 10000 complete in 8.0 sec
#  [-----------------92%---------------   ] 9275 of 10000 complete in 8.5 sec
#  [-----------------98%----------------- ] 9820 of 10000 complete in 9.0 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 9.2 sec

# %%
traceplot(trace);

# %%
hexbin(trace[m1],trace[m2], gridsize = 50)

# %%
with model:
    print approx_hess(start, [s])
# Out:
# [[ 56.65853952]]
