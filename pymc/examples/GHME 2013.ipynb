# %%
import pandas as pd
from pymc import * 
from pymc.distributions.timeseries import *

# %% [markdown]
# Data
# ----

# %%
data = pd.read_csv('data/pancreatitis/input_data.csv')
countries = ['CYP', 'DNK', 'ESP', 'FIN','GBR', 'ISL']
data = data[data.area.isin(countries)]

age = data['age'] = np.array(data.age_start + data.age_end)/2
rate = data.value = data.value*1000
group, countries = pd.factorize(data.area, order=countries)


ncountries = len(countries)

# %%
figsize(15,10)
for i, country in enumerate(countries):
    subplot(2,3,i+1)
    title(country)
    d = data[data.area == country]
    plot(d.age, d.value, '.')

# %% [markdown]
# Model Specification
# -------------------

# %%
nknots = 10
knots = np.linspace(data.age_start.min(),data.age_end.max(), nknots)


def interpolate(x0,y0, x, group):
    x = np.array(x)
    group = np.array(group)
    
    idx = np.searchsorted(x0, x)
    dl = np.array(x - x0[idx - 1])
    dr = np.array(x0[idx] - x)
    d=dl+dr
    wl = dr/d

    return wl*y0[idx-1, group] + (1-wl)*y0[idx, group]
    

with Model() as model:
    coeff_sd = T('coeff_sd', 10, 1, 5**-2)
        
    y = GaussianRandomWalk('y', sd=coeff_sd, shape = (nknots, ncountries))
    
    p = interpolate(knots, y, age, group)
    
    sd = T('sd', 10, 2, 5)
    
    vals = Normal('vals', p, sd=sd, observed = rate)

# %% [markdown]
# Model Fitting
# -------------

# %%
with model:
    s = find_MAP( vars=[sd, y])
    
    step = NUTS(scaling = s)
    trace = sample(100, step, s)
    
    s = trace[-1]
    
    step = NUTS(scaling = s)
    trace = sample(3000, step, s)
# Out:
#  [------           17%                  ] 17 of 100 complete in 0.5 sec
#  [-----------      30%                  ] 30 of 100 complete in 1.1 sec
#  [---------------- 44%                  ] 44 of 100 complete in 1.6 sec
#  [-----------------58%--                ] 58 of 100 complete in 2.2 sec
#  [-----------------70%------            ] 70 of 100 complete in 2.7 sec
#  [-----------------90%--------------    ] 90 of 100 complete in 3.2 sec
#  [-----------------100%-----------------] 100 of 100 complete in 3.5 sec
#  [                  1%                  ] 30 of 3000 complete in 0.5 sec
#  [-                 2%                  ] 80 of 3000 complete in 1.0 sec
#  [-                 4%                  ] 129 of 3000 complete in 1.5 sec
#  [--                6%                  ] 181 of 3000 complete in 2.0 sec
#  [--                7%                  ] 231 of 3000 complete in 2.5 sec
#  [---               9%                  ] 290 of 3000 complete in 3.0 sec
#  [----             11%                  ] 346 of 3000 complete in 3.5 sec
#  [-----            13%                  ] 397 of 3000 complete in 4.0 sec
#  [-----            14%                  ] 449 of 3000 complete in 4.5 sec
#  [------           16%                  ] 504 of 3000 complete in 5.0 sec
#  [-------          18%                  ] 560 of 3000 complete in 5.5 sec
#  [-------          20%                  ] 613 of 3000 complete in 6.1 sec
#  [--------         22%                  ] 670 of 3000 complete in 6.6 sec
#  [---------        24%                  ] 720 of 3000 complete in 7.1 sec
#  [---------        25%                  ] 778 of 3000 complete in 7.6 sec
#  [----------       27%                  ] 826 of 3000 complete in 8.1 sec
#  [-----------      29%                  ] 875 of 3000 complete in 8.6 sec
#  [-----------      30%                  ] 919 of 3000 complete in 9.1 sec
#  [------------     32%                  ] 971 of 3000 complete in 9.7 sec
#  [-------------    34%                  ] 1027 of 3000 complete in 10.2 sec
#  [-------------    36%                  ] 1080 of 3000 complete in 10.7 sec
#  [--------------   37%                  ] 1133 of 3000 complete in 11.2 sec
#  [---------------  39%                  ] 1187 of 3000 complete in 11.7 sec
#  [---------------  41%                  ] 1243 of 3000 complete in 12.2 sec
#  [---------------- 43%                  ] 1290 of 3000 complete in 12.7 sec
#  [---------------- 44%                  ] 1341 of 3000 complete in 13.2 sec
#  [-----------------46%                  ] 1397 of 3000 complete in 13.7 sec
#  [-----------------48%                  ] 1452 of 3000 complete in 14.2 sec
#  [-----------------50%                  ] 1503 of 3000 complete in 14.7 sec
#  [-----------------51%                  ] 1558 of 3000 complete in 15.2 sec
#  [-----------------53%                  ] 1611 of 3000 complete in 15.7 sec
#  [-----------------55%-                 ] 1666 of 3000 complete in 16.2 sec
#  [-----------------57%-                 ] 1721 of 3000 complete in 16.7 sec
#  [-----------------59%--                ] 1773 of 3000 complete in 17.2 sec
#  [-----------------60%---               ] 1829 of 3000 complete in 17.7 sec
#  [-----------------62%---               ] 1883 of 3000 complete in 18.2 sec
#  [-----------------64%----              ] 1938 of 3000 complete in 18.7 sec
#  [-----------------66%-----             ] 1992 of 3000 complete in 19.2 sec
#  [-----------------68%-----             ] 2048 of 3000 complete in 19.7 sec
#  [-----------------70%------            ] 2104 of 3000 complete in 20.2 sec
#  [-----------------71%-------           ] 2153 of 3000 complete in 20.7 sec
#  [-----------------73%-------           ] 2208 of 3000 complete in 21.2 sec
#  [-----------------75%--------          ] 2255 of 3000 complete in 21.8 sec
#  [-----------------77%---------         ] 2310 of 3000 complete in 22.3 sec
#  [-----------------78%---------         ] 2366 of 3000 complete in 22.8 sec
#  [-----------------80%----------        ] 2421 of 3000 complete in 23.3 sec
#  [-----------------82%-----------       ] 2478 of 3000 complete in 23.8 sec
#  [-----------------84%------------      ] 2534 of 3000 complete in 24.3 sec
#  [-----------------86%------------      ] 2590 of 3000 complete in 24.8 sec
#  [-----------------87%-------------     ] 2636 of 3000 complete in 25.3 sec
#  [-----------------89%-------------     ] 2677 of 3000 complete in 25.8 sec
#  [-----------------91%--------------    ] 2732 of 3000 complete in 26.3 sec
#  [-----------------92%---------------   ] 2787 of 3000 complete in 26.8 sec
#  [-----------------94%---------------   ] 2839 of 3000 complete in 27.3 sec
#  [-----------------96%----------------  ] 2896 of 3000 complete in 27.8 sec
#  [-----------------98%----------------- ] 2950 of 3000 complete in 28.3 sec
#  [-----------------100%-----------------] 3000 of 3000 complete in 28.8 sec

# %%
figsize(20,12)
for i, country in enumerate(countries):
    subplot(2,3,i+1)
    title(country)
    
    d = data[data.area == country]
    plot(d.age, d.value, '.')
    plot(knots, trace[y][::5,:,i].T, color ='r', alpha =.01);
    
    ylim(0,rate.max())

# %%
figsize(15, 6)
traceplot(trace[100:], vars = [coeff_sd]);
