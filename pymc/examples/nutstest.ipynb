# %%
from matplotlib.pylab import *
from pymc import *
import numpy as np 
from numpy.random import normal, beta
import theano 


with Model() as model:
    x = T('x', mu = 0., lam = 1., nu =30.)
    step = NUTS()
    trace = sample(5000, step)
# Out:
#  [----             12%                  ] 622 of 5000 complete in 0.5 sec
#  [-------          19%                  ] 954 of 5000 complete in 1.0 sec
#  [------------     32%                  ] 1621 of 5000 complete in 1.5 sec
#  [-----------------45%                  ] 2262 of 5000 complete in 2.0 sec
#  [-----------------56%-                 ] 2808 of 5000 complete in 2.5 sec
#  [-----------------70%------            ] 3516 of 5000 complete in 3.0 sec
#  [-----------------83%-----------       ] 4182 of 5000 complete in 3.5 sec
#  [-----------------97%----------------- ] 4872 of 5000 complete in 4.0 sec
#  [-----------------100%-----------------] 5000 of 5000 complete in 4.1 sec

# %%
traceplot(trace)
print np.std(trace[x])
# Out:
# 0.988387135529
